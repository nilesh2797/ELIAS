# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

def PLOG(msg, attr='yellow'):
    print(_c(f'\n<<{"-"*(50-(len(msg)+1)//2)} {msg} {"-"*(50-len(msg)//2)}>>', attr=attr), flush=True)
# Out:
# /tmp/ipykernel_155508/959448426.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# command = " --dataset ShoppingAds-100K \
#             --maxlen 32 \
#             --net elias \
#             --stage 1 \
#             --loss joint \
#             --xc-lr 1e-1 \
#             --enc-lr 1e-5 \
#             --bsz 1024 \
#             --W-accum-steps 10 \
#             --no-amp-encode \
#             --cmat-seed -1 \
#             --device cuda:11 \
#             --joint-loss-gamma 0 \
#             --clf-dim 0"

command = " --dataset amazon-670k \
            --expname Stage-1-0 \
            --num-epochs 0"

# %% [markdown]
# ## Initialize

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
from nns import exact_search
from resources import _c, printacc, read_sparse_mat, get_text, _filter, XCMetrics, get_free_gpu
from dl_base import ToD, PreTokBertDataset, XCCollator, TransformerInputLayer, FixedDataset, csr_to_pad_tensor, dedup_tensor
from nets import *
from losses import *

import json, socket, sys, os
import numpy as np
import pandas as pd
from tqdm import tqdm
import scipy.sparse as sp
from sklearn.preprocessing import normalize
import xclib.data.data_utils as data_utils
from xclib.utils.sparse import retain_topk
import xclib.evaluation.xc_metrics as xc_metrics

import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers
from transformers import AutoModel, AutoTokenizer
transformers.set_seed(42)

import pecos
from pecos.xmc import Indexer, LabelEmbeddingFactory
from pecos.xmc.xlinear.model import XLinearModel
# Out:
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib

# %%
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--project', default='ELIAS')
parser.add_argument('--expname', default='')
parser.add_argument('--dataset', required=True)
parser.add_argument('--maxlen', type=int, default=32, help='max seq length for transformer')
parser.add_argument('--net', default='ELIAS')
parser.add_argument('--stage', type=int, default=1)
parser.add_argument('--loss', default='joint')
parser.add_argument('--loss-with-logits', action='store_true', default=False)
parser.add_argument('--joint-loss-gamma', type=float, default=0.05)
parser.add_argument('--tf', default='distilbert-base-uncased')
parser.add_argument('--tf-pooler', default='cls')

parser.add_argument('--C', type=int, default=0)
parser.add_argument('--max-leaf', type=int, default=100)
parser.add_argument('--beam', type=int, default=20)
parser.add_argument('--alpha', type=int, default=10)
parser.add_argument('--beta-gain', type=float, default=1.5)
parser.add_argument('--K', type=int, default=2000)
parser.add_argument('--kappa', type=int, default=1000)
# parser.add_argument('--beam-loss-gamma', type=float, default=0)

parser.add_argument('--warmup', type=float, default=0.1, help='warmup steps percentage')
parser.add_argument('--W-accum-steps', type=int, default=1)
parser.add_argument('--no-amp-encode', dest='amp_encode', action='store_false', help='do not use amp for encoder')
parser.add_argument('--clf-dim', type=int, default=0)
parser.add_argument('--bottleneck', type=int, default=0)
parser.add_argument('--norm-embs', action='store_true', help='Normalize encoder embeddings', default=False)
parser.add_argument('--dropout', type=float, default=0.5)
parser.add_argument('--xc-lr', type=float, default=0.01)
parser.add_argument('--dense-lr', type=float, default=-1.0)
parser.add_argument('--enc-lr', type=float, default=5e-5)
parser.add_argument('--bsz', type=int, default=128)
parser.add_argument('--num-epochs', type=int, default=25)
parser.add_argument('--eval-interval', type=int, default=3)
parser.add_argument('--use-swa', dest='use_swa', action='store_true')
parser.add_argument('--swa-step', type=int, default=1000)
parser.add_argument('--swa-start', type=int, default=8)

parser.add_argument('--embs-dir', default='')
parser.add_argument('--save', action='store_true', help='save model and score mat', default=False)
parser.add_argument('--resume-path', help='continue training from previous checkpoint', default='')
parser.add_argument('--cmat-file', help='saved cluster matrix npz file', default='')
parser.add_argument('--cmat-seed', help='initial cluster matrix seed', default=-1, type=int)
parser.add_argument('--A-init-file', help='saved candidates npz file', default='')
parser.add_argument('--save-embs', action='store_true', default=False)
parser.add_argument('--gen-A-init', action='store_true', help='generate an initialization for A with final model', default=False)
parser.add_argument('--ranker', action='store_true', default=False)
parser.add_argument('--ranker-alpha', type=float, default=0.5)
parser.add_argument('--ranker-topk', type=int, default=100)
parser.add_argument('--score-calibrate', action='store_true', default=False)

parser.add_argument('--device', default='cuda:0')
parser.set_defaults(amp_encode=True)
parser.set_defaults(use_swa=False)

args = parser.parse_args(command.split())
if args.expname != '' and args.num_epochs == 0:
    args.__dict__ = json.load(open(f'Results/{args.project}/{args.dataset}/{args.expname}/args.json'))
    parser.set_defaults(**args.__dict__)
    args = parser.parse_args(command.split())
    
args.use_grad_scaler = (args.amp_encode)
args.hostname = socket.gethostname()

cmat_seed_suffix = '' if args.cmat_seed < 0 == '' else f'-{args.cmat_seed}'
args.netname = args.net if args.net == 'fcnet' else f'{args.net}-{args.stage}-leaf{args.max_leaf}-beam{args.beam}{cmat_seed_suffix}'
args.expname = nb_name.split('.')[0]

args.dense_lr = args.xc_lr if args.dense_lr < 0 else args.dense_lr
args.tf = None if args.tf.lower() == 'none' else args.tf
args.embs_dim = 768

args.DATA_DIR = DATA_DIR = f'Datasets/{args.dataset}'
args.OUT_DIR = OUT_DIR = f'Results/{args.project}/{args.dataset}/{args.expname}'
os.makedirs(OUT_DIR, exist_ok=True)
print(f'expname: {_c(args.expname, attr="blue")}, dataset: {_c(args.dataset, attr="blue")}')

args.cmat_file = f'{DATA_DIR}/cmat-{args.C}x{args.max_leaf}{cmat_seed_suffix}.npz' if args.cmat_file == '' else args.cmat_file

if not os.path.exists(args.A_init_file):
    args.A_init_file = f'{os.path.dirname(args.resume_path)}/A_init.npz'
# Out:
# expname: ELIAS, dataset: amazon-670k

# %% [markdown]
# ## Load data

# %%
Y = [x.strip() for x in open(f'{DATA_DIR}/raw/Y.txt').readlines()]
# trnX = [x.strip() for x in open(f'{DATA_DIR}/raw/trn_X.txt').readlines()]
# tstX = [x.strip() for x in open(f'{DATA_DIR}/raw/tst_X.txt').readlines()]

trn_X_Y = sp.load_npz(f'{DATA_DIR}/Y.trn.npz')
tst_X_Y = sp.load_npz(f'{DATA_DIR}/Y.tst.npz')
trn_Y_X = trn_X_Y.T.tocsr()

args.numy = trn_X_Y.shape[1]
args.C = int(2**np.ceil(np.log2(args.numy/args.max_leaf)))
tst_filter_mat = None
if os.path.exists('%s/tst_filter_labels.txt'%(DATA_DIR)):
    temp = np.fromfile('%s/tst_filter_labels.txt'%(DATA_DIR), sep=' ').astype(int)
    temp = temp.reshape(-1, 2).T
    tst_filter_mat = sp.coo_matrix((np.ones(temp.shape[1]), (temp[0], temp[1])), tst_X_Y.shape).tocsr()
    
if "amazon" in args.dataset.lower(): A = 0.6; B = 2.6
elif "wiki" in args.dataset.lower() and "wikiseealso" not in args.dataset.lower(): A = 0.5; B = 0.4
else : A = 0.55; B = 1.5
inv_prop = xc_metrics.compute_inv_propesity(trn_X_Y, A, B)

# %%
# trn_nnz = trn_X_Y.getnnz(1)
# trn_sample = np.argsort(trn_nnz)[-1000000:]

trn_sample = None

# %%
if args.tf is not None:
    args.token_type = 'bert-base-uncased'
    if 'roberta' in args.tf: args.token_type = 'roberta-base'
    trn_dataset = PreTokBertDataset(f'{DATA_DIR}/{args.token_type}-{args.maxlen}', trn_X_Y, args.maxlen, doc_type='trn', sample=trn_sample)
    tst_dataset = PreTokBertDataset(f'{DATA_DIR}/{args.token_type}-{args.maxlen}', tst_X_Y, args.maxlen, doc_type='tst')
else:
    if args.embs_dir is None:
        args.embs_dir = f'Datasets/{args.dataset}/embs/XRL-batch-bce'
    trn_embs = np.load(f'{args.embs_dir}/trn_embs.npy')
    tst_embs = np.load(f'{args.embs_dir}/tst_embs.npy')
    trn_dataset = FixedDataset(trn_embs, trn_X_Y)
    tst_dataset = FixedDataset(tst_embs, tst_X_Y)

# trn_dataset.labels = trn_Y_X
trn_loader = torch.utils.data.DataLoader(
    trn_dataset,
    batch_size=args.bsz,
    num_workers=4,
    collate_fn=XCCollator(trn_X_Y.shape[1], trn_dataset),
    shuffle=True,
    pin_memory=True)

tst_loader = torch.utils.data.DataLoader(
    tst_dataset,
    batch_size=args.bsz*2,
    num_workers=4,
    collate_fn=XCCollator(trn_X_Y.shape[1], tst_dataset),
    shuffle=False,
    pin_memory=True)

# %%
A1 = sp.load_npz(f'Results/ELIAS/amazon-670k/Stage-1-0/A_init.npz')
A2 = sp.load_npz(f'Results/ELIAS/amazon-670k/Stage-1-0/A_init.orig.npz')

# %%
temp = _filter(A1, A2)
# Out:
# /home/nilesh/miniconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ### Cluster utils

# %%
args.cmat_file = f'{DATA_DIR}/cmat-{args.nr_splits}x{args.max_leaf}.npz'
cmat = sp.load_npz(args.cmat_file)

cmat.resize(args.nr_splits, args.numy)
c_tst_X_Y = tst_X_Y.dot(cmat.T)
c_tst_X_Y.data[:] = 1.0

# cmat.resize(args.nr_splits+1, args.numy+1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_29941/3638266750.py in <module>
# ----> 1 args.cmat_file = f'{DATA_DIR}/cmat-{args.nr_splits}x{args.max_leaf}.npz'
#       2 cmat = sp.load_npz(args.cmat_file)
#       3
#       4 cmat.resize(args.nr_splits, args.numy)
#       5 c_tst_X_Y = tst_X_Y.dot(cmat.T)
#
# AttributeError: 'Namespace' object has no attribute 'nr_splits'

# %%
qbst_trn_X_Xf = sp.load_npz(f'{DATA_DIR}/X_qbst.trn.npz')

# %%
trn_X_Xf = sp.load_npz(f'{DATA_DIR}/X.trn.npz')

# %%
normalize(qbst_trn_X_Xf, axis=1, copy=False)
# Out:
# <286541251x33121061 sparse matrix of type '<class 'numpy.float32'>'
# 	with 5724552126 stored elements in Compressed Sparse Row format>

# %%
new_cmats = {}
# %time label_feat = LabelEmbeddingFactory.create(trn_X_Y.astype(np.float32), qbst_trn_X_Xf.astype(np.float32), method="pifa")
# for seed in [0]:
#     %time cluster_chain = Indexer.gen(label_feat, indexer_type="hierarchicalkmeans", nr_splits=args.C, max_leaf_size=args.max_leaf, seed=seed)
new_cmats[seed] = cluster_chain.chain[-1].T

# %%
for seed, mat in new_cmats.items():
    sp.save_npz(f'{DATA_DIR}/qbst-cmat-{args.C}x{args.max_leaf}-{seed}.npz', mat)

# %%
if False:
    trn_X_Xf = normalize(read_sparse_mat(f'{DATA_DIR}/trn_X_Xf.txt', use_xclib=False), copy=False)
    trn_embs = normalize(np.load(f'{DATA_DIR}/embs/XRL-batch-bce/trn_embs.npy'), copy=False)
    trn_X_Xf = sp.hstack((trn_X_Xf, trn_embs)).tocsr()

    new_cmats = {}
    label_feat = LabelEmbeddingFactory.create(trn_X_Y, trn_X_Xf.astype(np.float32), method="pifa")
    for seed in [0, 1, 2]:
        # %time cluster_chain = Indexer.gen(label_feat, indexer_type="hierarchicalkmeans", nr_splits=args.nr_splits, max_leaf_size=args.max_leaf, seed=seed)
        new_cmats[seed] = cluster_chain.chain[-1].T

    new_cmat = sp.vstack(new_cmats.values())
    sp.save_npz(f'{OUT_DIR}/new_cmat.npz', new_cmat)

    args.nr_splits = new_cmat.shape[0]
    for seed, mat in new_cmats.items():
        sp.save_npz(f'{DATA_DIR}/cmat-{args.nr_splits}x{args.max_leaf}-{seed}.npz', mat)

# %% [markdown]
# ## Architecture and Loss definitions

# %%
class ELIAS(Net):
    def __init__(self, args, rand_init=True):
        super(ELIAS, self).__init__(args)
    
        self.stage = args.stage
        self.beam = args.beam
        self.max_trn_cluster = self.beam+10
        self.numy = args.numy
        self.loss_with_logits = args.loss_with_logits
        self.tau = 1
        self.alpha = args.alpha
        self.beta = int(args.max_leaf*args.beta_gain)
        self.K = args.K
        self.C = args.C
        self.max_leaf = args.max_leaf
        self.embs_dim = args.embs_dim
        self.clf_dim = args.clf_dim if args.clf_dim > 0 else args.embs_dim
        
        self.w1 = nn.Linear(self.embs_dim, args.C+1)
        self.transform = nn.Linear(self.embs_dim, self.clf_dim) if (self.embs_dim != self.clf_dim) else nn.Identity()
        self.w_leaf = SparseLinear(args.numy+1, self.clf_dim)

        self.bow_fts = normalize(sp.load_npz(f'{args.DATA_DIR}/X.trn.npz'), copy=False).astype(np.float32)
        self.OUT_DIR = args.OUT_DIR
        self.cmat_seed = args.cmat_seed
        if os.path.exists(args.A_init_file):
            A_init = sp.load_npz(args.A_init_file)
            temp = csr_to_pad_tensor(A_init, args.numy)
            self.A_nz_inds = temp['inds'].to(args.device)
#             self.A_nz_vals = nn.Parameter(torch.rand(*self.A_nz_inds.shape)) if rand_init else nn.Parameter(res['vals'].float())
            init_vals = temp['vals'].float() / torch.clamp(temp['vals'].float().max(dim=1).values.reshape(-1, 1), min=1e-8)
            init_vals += 0.2*torch.rand(*self.A_nz_inds.shape)
            self.A_nz_vals = nn.Parameter(init_vals)
        
        self.no_swa = lambda n: (n == 'A_nz_vals')
        
    def retain_topk(self, K, clean=False):
        with torch.no_grad():
            self.A_norm_nz_vals = torch.clamp(self.beta*F.softmax(self.A_nz_vals/self.tau, dim=-1), min=0, max=1)
            self.A_nz_vals.data, sorted_inds = self.A_nz_vals.topk(K)
            self.A_nz_inds = self.A_nz_inds.gather(1, sorted_inds)
            self.A_norm_nz_vals = self.A_norm_nz_vals.gather(1, sorted_inds)
            
            if clean:
                self.A_nz_vals.data[:] = 1
                self.A_norm_nz_vals[:] = 1
                
    def update(self, epoch=-1, trn_dataset=None, **kwargs):    
        if self.stage == 1:
            if self.cmat_seed > -1 and (epoch == 0 or epoch == 5):
                print(f'Updating clusters at epoch {epoch}...')
                trn_embs = normalize(self.get_embs(trn_dataset), copy=False).astype(np.float32)
                cluster_embs = sp.hstack((self.bow_fts, trn_embs)).tocsr()
                    
                label_feat = LabelEmbeddingFactory.create(trn_dataset.labels, cluster_embs, method="pifa")
                cmat = Indexer.gen(label_feat, 
                                   indexer_type="hierarchicalkmeans", 
                                   nr_splits=self.C, 
                                   max_leaf_size=self.max_leaf, 
                                   seed=self.cmat_seed).chain[-1].T
                cmat.resize(self.C+1, self.numy+1)
                sp.save_npz(f'{self.OUT_DIR}/cmat.npz', cmat)
                temp = csr_to_pad_tensor(cmat, self.numy)
                self.A_nz_inds = temp['inds'].to(self.get_device())
                self.A_nz_vals = temp['vals'].to(self.get_device())
                self.parent = torch.tensor(cmat.argmax(0)).ravel().to(self.get_device())
                self.parent[self.numy] = self.C

        with torch.no_grad():
            self.A_norm_nz_vals = torch.clamp(self.beta*F.softmax(self.A_nz_vals/self.tau, dim=-1), min=0, max=1).to(self.get_device())
            self.parent = torch.zeros((self.numy+1, ), dtype=torch.long, device=self.get_device())
            parent_val = torch.zeros((self.numy+1, ), device=self.get_device())
            for c in range(self.A_norm_nz_vals.shape[0]):
                cy = self.A_nz_inds[c]
                self.parent[cy] = torch.where(parent_val[cy] < self.A_norm_nz_vals[c], torch.full(cy.shape, c, device=self.get_device()), self.parent[cy])
                parent_val[cy] = torch.max(parent_val[cy], self.A_norm_nz_vals[c])

    def forward(self, b, K=0):
        b = self.ToD(b)
        embs = self.encode(b)
        bsz = embs.shape[0]
        K = max(self.beam, K)
        
        out1 = torch.clamp(self.alpha*F.softmax(self.w1(embs), dim=1), min=0, max=1)[:, :-1]
        out1_topk_vals, out1_topk_inds = torch.topk(out1, K, dim=1)
    
        if self.training:
            if self.A_nz_vals.requires_grad:
                self.A_norm_nz_vals = torch.clamp(self.beta*F.softmax(self.A_nz_vals/self.tau, dim=-1), min=0, max=1)
            if self.w1.weight.requires_grad:
                # add parent clusters in shortlisted clusters
                out1_pos_inds = self.parent[b['y']['inds']]
                out1_topk_inds = torch.hstack((out1_topk_inds, out1_pos_inds))
                out1_topk_vals = torch.hstack((out1_topk_vals, b['y']['vals']))

                out1_topk_inds, rearranged_inds = dedup_tensor(out1_topk_inds, replace_val=self.C, return_indices=True)
                out1_topk_vals = out1_topk_vals.gather(1, rearranged_inds)
                if self.max_trn_cluster > 0 and self.max_trn_cluster < out1_topk_vals.shape[1]:
                    sampled_inds = torch.multinomial(out1_topk_vals, self.max_trn_cluster)
                    out1_topk_inds = out1_topk_inds.gather(1, sampled_inds)
                pad_mask = (out1_topk_inds == self.C)
                out1_topk_inds[pad_mask] = torch.randint(0, self.C, (pad_mask.sum(), ), device=pad_mask.device)
        out1_topk_vals = out1.gather(1, out1_topk_inds)
        
        topk_C_vals = self.A_norm_nz_vals[out1_topk_inds.flatten()]
        topk_C_vals *= out1_topk_vals.reshape(-1, 1)
        topk_C_vals = topk_C_vals.reshape(bsz, -1)
        
        topk_C_inds = self.A_nz_inds[out1_topk_inds.flatten()].reshape(bsz, -1)
        topk_C_vals, sort_inds = torch.sort(topk_C_vals, descending=True)
        topk_C_inds = topk_C_inds.gather(1, sort_inds)
        
        topk_C_inds, rearranged_inds = dedup_tensor(topk_C_inds, self.numy, return_indices=True)
        topk_C_vals = topk_C_vals.gather(1, rearranged_inds)
        topk_C_vals[topk_C_inds == self.numy] = 0 # handle pad index
        
        shorty_vals, sorted_inds = topk_C_vals.topk(min(self.K, topk_C_vals.shape[-1]))
        shorty_inds = topk_C_inds.gather(1, sorted_inds)
                
        out2 = self.w_leaf(self.transform(embs), shorty_inds)
        out2 = out2 if self.loss_with_logits else torch.sigmoid(out2)
        out = (out2 + shorty_vals) if self.loss_with_logits else (out2 * shorty_vals)

        return (out, shorty_inds, topk_C_vals, topk_C_inds) if self.training else (out, shorty_inds)

# %%
class JointLoss(nn.Module):
    def __init__(self, args, reduction='mean'):
        super(JointLoss, self).__init__()
        self.numy = args.numy
        self.gamma = args.joint_loss_gamma
        if args.loss_with_logits:
            self.criterion = torch.nn.BCEWithLogitsLoss(reduction=reduction)
        else:
            self.criterion = torch.nn.BCELoss(reduction=reduction)

    def forward(self, model, b):
        out, shorty, topk_C_vals, topk_C_inds = model(b)
        
        yfull = torch.zeros((out.shape[0], self.numy+1), device=out.device).scatter_(1, b['y']['inds'], 1)
        yfull[:, -1] = 0.0
        
        targets  = torch.gather(yfull, 1, shorty)
        loss_precision = self.criterion(out, targets)
        
        targets = yfull.gather(1, topk_C_inds)
        targets, target_inds = targets.topk(targets.sum(dim=-1).max().long())
        topk_C_vals = topk_C_vals.gather(1, target_inds)
        topk_C_vals[targets < 1e-5] = 0
        loss_recall = self.criterion(topk_C_vals, targets)
        
        loss = loss_precision + self.gamma*loss_recall
        
        del b, out, yfull, targets
        return loss

# %%
NETS['elias'] = ELIAS
LOSSES['joint'] = JointLoss

# %% [markdown]
# ## Setup

# %%
# args.A_init_file = f'{OUT_DIR}/candidates.npz'
# args.A_init_file = f'Results/ELIAS/ShoppingAds-100K/Stage-1-0/cmat.npz'
# args.A_init_file = f'{DATA_DIR}/cmat-{args.C}x{args.max_leaf}-0.npz'
# args.A_init_file = f'Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0/A_init.npz'

# %%
net = NETS[args.net](args)
criterion = LOSSES[args.loss](args)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
net
# Out:
# ELIAS(
#   (encoder): TransformerInputLayer(
#     (transformer): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (w1): Linear(in_features=768, out_features=8193, bias=True)
#   (transform): Identity()
#   (w_leaf): SparseLinear()
# )

# %%
# net.load_state_dict(torch.load(f'Results/ELIAS/amazon-670k/Stage-1-0/model.pt', map_location='cpu'), strict=False)

# %%
net.to(args.device);
net.update()

# %%
emb_mu = np.zeros((args.numy, args.embs_dim))
bow_fts = normalize(sp.load_npz(f'{DATA_DIR}/X.trn.npz'), copy=False)
bow_mu = trn_X_Y.T.tocsr().dot(bow_fts)
trn_embs = np.zeros((trn_X_Y.shape[0], args.embs_dim))

# %%
net.eval()
with torch.no_grad():
    for b in tqdm(trn_loader, desc='Computing embs mu'):
        b = net.ToD(b)
        b_ids = b['ids']
        embs = net.encode(b).detach()
        all_b_ids = b_ids.detach().cpu().numpy()
        all_embs = embs.detach().cpu().numpy()
        trn_embs[all_b_ids] = all_embs
        
        batch_X_Y = trn_X_Y[all_b_ids]
        all_batch_Y = np.unique(batch_X_Y.indices)
        batch_X_Y = batch_X_Y[:, all_batch_Y]
        batch_Y_mu = batch_X_Y.T.tocsr().dot(all_embs)
        emb_mu[all_batch_Y] += batch_Y_mu
# Out:
# Computing embs mu: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 958/958 [05:20<00:00,  2.99it/s]

# %%
combined_mu = normalize(sp.hstack([bow_mu, emb_mu]), copy=False).astype(np.float32)
cmat = Indexer.gen(combined_mu, 
                   indexer_type="hierarchicalkmeans", 
                   nr_splits=args.C, 
                   max_leaf_size=args.max_leaf, 
                   seed=args.cmat_seed).chain[-1].T
# sp.save_npz(f'{args.OUT_DIR}/cmat.npz')

# %%
cmat.indices
# Out:
# array([  2630,   4602,   6461, ..., 657588, 657589, 657590], dtype=int32)

# %% [markdown]
# abs(cmat.indices - temp_cmat.indices).sum()

# %%
temp_cmat = sp.load_npz(f'Results/ELIAS/amazon-670k/Stage-1-0/cmat.temp.npz')

# %%
temp_cmat.indices
# Out:
# array([   760,   3764,   4781, ..., 652718, 655277, 662163], dtype=int32)

# %%
orig_cmat = sp.load_npz(f'Results/ELIAS/amazon-670k/Stage-1-0/cmat.npz')

# %%
orig_cmat.indices
# Out:
# array([254247, 257041, 257177, ..., 613973, 633280, 648644], dtype=int32)

# %%
trn_embs = normalize(net.get_embs(trn_dataset), copy=False).astype(np.float32)
cluster_embs = sp.hstack((net.bow_fts, trn_embs)).tocsr()

label_feat = LabelEmbeddingFactory.create(trn_dataset.labels, cluster_embs, method="pifa")
net_cmat = Indexer.gen(label_feat, 
                   indexer_type="hierarchicalkmeans", 
                   nr_splits=net.C, 
                   max_leaf_size=net.max_leaf, 
                   seed=net.cmat_seed).chain[-1].T

# %%
# MUFIN_DIR = '/mnt/disks/disk2/anshumitts/XC/results/ShoppingAds-10M-v2/MufinTextXC/v_default_run_d=128/module3'
# encoder_state_dict = torch.load(f'{MUFIN_DIR}/encoder.pkl', map_location='cpu')
# encoder_state_dict = {f'encoder.transformer.{".".join(k.split(".")[2:])}': v for k, v in encoder_state_dict.items()}

# net.load_state_dict(encoder_state_dict, strict=False)

# %%
if args.resume_path != '':
    state_dict = torch.load(f'{LOAD_DIR}/model.pt', map_location='cpu')
    new_state_dict = {k: v for k, v in state_dict.items() if 'C' not in k and 'w_leaf' not in k}
    print(net.load_state_dict(new_state_dict, strict=False))

# %%
# args.load_path=''
# args.load_path = 'Results/ELIAS/ShoppingAds-10M-v2/Stage-2-0-no-swa/model.pt'
args.load_path='Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0-qbst/model.pt'
# args.load_path='Results/ELIAS/ShoppingAds-100K/Stage-1-0/model.pt'
# args.load_path = f'Resu'

if args.load_path != '':
    print(net.load_state_dict(torch.load(args.load_path, map_location='cpu'), strict=True))
# Out:
# <All keys matched successfully>

# %%
args.clf_dim
# Out:
# 64

# %%
net.to(args.device)
net.update()

# %%
net.beam = 20
net.K = 2000
net.beam, net.K
# Out:
# (20, 2000)

# %%
score_mat = net.predict(tst_loader, K=700);
# Out:
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 931/931 [02:06<00:00,  7.38it/s]

# %%
from resources import recall

# %%
recall(score_mat, tst_X_Y, [10,20,50,100,200,300,500,700])
# Out:
# {'R@10': 31.645324469786974,
#  'R@20': 42.655996452956494,
#  'R@50': 57.939536680568246,
#  'R@100': 68.4861022375928,
#  'R@200': 77.31670919478695,
#  'R@300': 81.47963980877768,
#  'R@500': 85.56164244656284,
#  'R@700': 87.59075225227345}

# %%
XCMetrics(score_mat, tst_X_Y, inv_prop)
# Out:
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 7.15	5.28	4.35	7.15	12.07	14.46	7.23	15.33	20.9	31.0	41.88	67.66
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 7.15 5.28 4.35 7.15 12.07 14.46 7.23 15.33 20.9 31.0 41.88 67.66
#          P@1   P@3   P@5  nDCG@1  nDCG@3  nDCG@5  PSP@1  PSP@3  PSP@5  R@10  \
# Method  7.15  5.28  4.35    7.15   12.07   14.46   7.23  15.33   20.9  31.0
#
#          R@20  R@100  MRR@10
# Method  41.88  67.66   13.45

# %%
def _no_decay(n,p):
    if n.startswith('encoder'):
        return any([x in n.lower() for x in ['bias', 'layernorm', 'layer_norm']])
    return True

def _is_enc_param(n,p):
    return n.startswith('encoder')

def _is_xc_param(n,p):
    return any((x == args.numy or x == (args.numy+1)) for x in p.shape) or n == 'A_nz_vals'

def _is_dense_param(n,p):
    return (not _is_enc_param(n,p)) and (not _is_xc_param(n,p))

optim_wrap = {
    'enc': {'class': torch.optim.AdamW, 'params': [], 'f': _is_enc_param, 'accum_steps': 1, 'args': {'lr': args.enc_lr}},
    'xc' : {'class': torch.optim.AdamW, 'params': [], 'f': _is_xc_param, 'accum_steps': args.W_accum_steps, 'args': {'lr': args.xc_lr}},
    'dense': {'class': torch.optim.AdamW, 'params': [], 'f': _is_dense_param, 'accum_steps': args.W_accum_steps, 'args': {'lr': args.dense_lr}}
    }

for n,p in net.named_parameters():
    for k in optim_wrap.keys():
        if p.requires_grad and optim_wrap[k]['f'](n,p):
            optim_wrap[k]['params'].append((n, p))

optims = {}
for k, v in optim_wrap.items():
    grouped_params = [{'params': [p for n,p in v['params'] if _no_decay(n,p)], 'weight_decay': 0}, 
                      {'params': [p for n,p in v['params'] if not _no_decay(n,p)], 'weight_decay': 0.01}]
    if len(v['params']) > 0: optims[k] = v['class'](grouped_params, **v['args'])

for k in optim_wrap.keys():
    print(_c(f'{k} parameters ({optim_wrap[k]["args"]}, accum: {optim_wrap[k]["accum_steps"]}): ', attr='bold blue'), [p[0] for p in optim_wrap[k]['params']])
# Out:
# enc parameters ({'lr': 1e-05}, accum: 1):  ['encoder.transformer.embeddings.word_embeddings.weight', 'encoder.transformer.embeddings.position_embeddings.weight', 'encoder.transformer.embeddings.LayerNorm.weight', 'encoder.transformer.embeddings.LayerNorm.bias', 'encoder.transformer.transformer.layer.0.attention.q_lin.weight', 'encoder.transformer.transformer.layer.0.attention.q_lin.bias', 'encoder.transformer.transformer.layer.0.attention.k_lin.weight', 'encoder.transformer.transformer.layer.0.attention.k_lin.bias', 'encoder.transformer.transformer.layer.0.attention.v_lin.weight', 'encoder.transformer.transformer.layer.0.attention.v_lin.bias', 'encoder.transformer.transformer.layer.0.attention.out_lin.weight', 'encoder.transformer.transformer.layer.0.attention.out_lin.bias', 'encoder.transformer.transformer.layer.0.sa_layer_norm.weight', 'encoder.transformer.transformer.layer.0.sa_layer_norm.bias', 'encoder.transformer.transformer.layer.0.ffn.lin1.weight', 'encoder.transformer.transformer.layer.0.ffn.lin1.bias', 'encoder.transformer.transformer.layer.0.ffn.lin2.weight', 'encoder.transformer.transformer.layer.0.ffn.lin2.bias', 'encoder.transformer.transformer.layer.0.output_layer_norm.weight', 'encoder.transformer.transformer.layer.0.output_layer_norm.bias', 'encoder.transformer.transformer.layer.1.attention.q_lin.weight', 'encoder.transformer.transformer.layer.1.attention.q_lin.bias', 'encoder.transformer.transformer.layer.1.attention.k_lin.weight', 'encoder.transformer.transformer.layer.1.attention.k_lin.bias', 'encoder.transformer.transformer.layer.1.attention.v_lin.weight', 'encoder.transformer.transformer.layer.1.attention.v_lin.bias', 'encoder.transformer.transformer.layer.1.attention.out_lin.weight', 'encoder.transformer.transformer.layer.1.attention.out_lin.bias', 'encoder.transformer.transformer.layer.1.sa_layer_norm.weight', 'encoder.transformer.transformer.layer.1.sa_layer_norm.bias', 'encoder.transformer.transformer.layer.1.ffn.lin1.weight', 'encoder.transformer.transformer.layer.1.ffn.lin1.bias', 'encoder.transformer.transformer.layer.1.ffn.lin2.weight', 'encoder.transformer.transformer.layer.1.ffn.lin2.bias', 'encoder.transformer.transformer.layer.1.output_layer_norm.weight', 'encoder.transformer.transformer.layer.1.output_layer_norm.bias', 'encoder.transformer.transformer.layer.2.attention.q_lin.weight', 'encoder.transformer.transformer.layer.2.attention.q_lin.bias', 'encoder.transformer.transformer.layer.2.attention.k_lin.weight', 'encoder.transformer.transformer.layer.2.attention.k_lin.bias', 'encoder.transformer.transformer.layer.2.attention.v_lin.weight', 'encoder.transformer.transformer.layer.2.attention.v_lin.bias', 'encoder.transformer.transformer.layer.2.attention.out_lin.weight', 'encoder.transformer.transformer.layer.2.attention.out_lin.bias', 'encoder.transformer.transformer.layer.2.sa_layer_norm.weight', 'encoder.transformer.transformer.layer.2.sa_layer_norm.bias', 'encoder.transformer.transformer.layer.2.ffn.lin1.weight', 'encoder.transformer.transformer.layer.2.ffn.lin1.bias', 'encoder.transformer.transformer.layer.2.ffn.lin2.weight', 'encoder.transformer.transformer.layer.2.ffn.lin2.bias', 'encoder.transformer.transformer.layer.2.output_layer_norm.weight', 'encoder.transformer.transformer.layer.2.output_layer_norm.bias', 'encoder.transformer.transformer.layer.3.attention.q_lin.weight', 'encoder.transformer.transformer.layer.3.attention.q_lin.bias', 'encoder.transformer.transformer.layer.3.attention.k_lin.weight', 'encoder.transformer.transformer.layer.3.attention.k_lin.bias', 'encoder.transformer.transformer.layer.3.attention.v_lin.weight', 'encoder.transformer.transformer.layer.3.attention.v_lin.bias', 'encoder.transformer.transformer.layer.3.attention.out_lin.weight', 'encoder.transformer.transformer.layer.3.attention.out_lin.bias', 'encoder.transformer.transformer.layer.3.sa_layer_norm.weight', 'encoder.transformer.transformer.layer.3.sa_layer_norm.bias', 'encoder.transformer.transformer.layer.3 ...
# xc parameters ({'lr': 0.1}, accum: 10):  ['A_nz_vals', 'w_leaf.weight', 'w_leaf.bias']
# dense parameters ({'lr': 0.1}, accum: 10):  ['w1.weight', 'w1.bias']

# %%
total_steps = {k: len(trn_loader)*args.num_epochs/optim_wrap[k]['accum_steps'] for k in optims.keys()}
schedulers = {k: transformers.get_linear_schedule_with_warmup(optim, num_warmup_steps=int(args.warmup*total_steps[k]), num_training_steps=total_steps[k]) for k, optim in optims.items()}

# %%
with open(f'{OUT_DIR}/args.json', 'w') as f:
    json.dump(args.__dict__, f, indent=2)

# %%
args
# Out:
# Namespace(A_init_file='Results/ELIAS/ShoppingAds-100K/Stage-1-0/cmat.npz', C=1024, DATA_DIR='Datasets/ShoppingAds-100K', K=2000, OUT_DIR='Results/ELIAS/ShoppingAds-100K/ELIAS', W_accum_steps=10, alpha=10, amp_encode=False, beam=20, beta_gain=1.5, bottleneck=0, bsz=1024, clf_dim=0, cmat_file='Datasets/ShoppingAds-100K/cmat-0x100--1.npz', cmat_seed=-1, dataset='ShoppingAds-100K', dense_lr=0.1, device='cuda:11', dropout=0.5, embs_dim=768, embs_dir='', enc_lr=1e-05, eval_interval=3, expname='ELIAS', gen_A_init=False, hostname='mloa-gpunode-4', joint_loss_gamma=0.0, kappa=1000, load_path='', loss='joint', loss_with_logits=False, max_leaf=100, maxlen=32, net='elias', netname='elias-1-leaf100-beam20--1', norm_embs=False, num_epochs=25, numy=100000, project='ELIAS', ranker=False, ranker_alpha=0.5, ranker_topk=100, resume_path='', save=False, save_embs=False, score_calibrate=False, stage=1, swa_start=8, swa_step=1000, tf='distilbert-base-uncased', tf_pooler='cls', token_type='bert-base-uncased', use_grad_scaler=False, use_swa=False, warmup=0.1, xc_lr=0.1)

# %% [markdown]
# ## *Training Loop*

# %%
best_ndcg = -1
scaler = torch.cuda.amp.GradScaler()
# net.forward = convert_outputs_to_fp32(torch.cuda.amp.autocast(enabled=args.use_grad_scaler)(net.forward))

for epoch in range(args.num_epochs):
    if hasattr(net, 'update'):
        # print(f'update at epoch: {epoch}')
        net.update(epoch=epoch, trn_dataset=trn_dataset)
    net.train()
       
    if args.use_swa and epoch == args.swa_start:
        net.swa_init()
        
    cum_loss = 0; ctr = 0
    for optim in optims.values(): optim.zero_grad()
    t = tqdm(trn_loader, desc='Epoch: 0, Loss: 0.0', leave=True)
    for i, b in enumerate(t):
        loss = criterion(net, b)
        scaler.scale(loss.float()).backward() if args.use_grad_scaler else loss.backward()
        
        if args.use_swa and i % args.swa_step == 0:
            net.swa_step()
            
        for k in optims.keys():
            if i%optim_wrap[k]["accum_steps"] == 0:
                scaler.step(optims[k]) if args.use_grad_scaler else optims[k].step();
                if args.use_grad_scaler: scaler.update()
                schedulers[k].step(); 
                optims[k].zero_grad()

        cum_loss += loss.item()
        ctr += 1
        t.set_description('Epoch: %d/%d, Loss: %.4E'%(epoch, args.num_epochs, (cum_loss/ctr)), refresh=True)
        
    print(f'mean loss after epoch {epoch}/{args.num_epochs}: {"%.4E"%(cum_loss/ctr)}', flush=True)
    if epoch%args.eval_interval == 0 or epoch == (args.num_epochs-1):
        score_mat = net.predict(tst_loader)
        if tst_filter_mat is not None: _filter(score_mat, tst_filter_mat, copy=False)
        metrics = XCMetrics(score_mat, tst_X_Y, inv_prop, method=f'Ep {epoch}', disp=True)
        metrics['loss'] = ["%.4E"%(cum_loss/ctr)]
        metrics.to_csv(open(f'{OUT_DIR}/metrics.tsv', 'a+'), sep='\t', header=(epoch==0))

        if metrics.loc[f'Ep {epoch}']['nDCG@5'] > best_ndcg:
            best_ndcg = metrics.loc[f'Ep {epoch}']['nDCG@5']
            print(_c(f'Found new best model with nDCG@5: {"%.2f"%best_ndcg}\n', attr='blue'))

            if args.save:
                sp.save_npz(f'{OUT_DIR}/score_mat.npz', score_mat)
                net.save_model(f'{OUT_DIR}/model.pt')
    sys.stdout.flush()
# Out:
# Epoch: 0/25, Loss: 2.1063E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [26:36<00:00,  4.40it/s]
# mean loss after epoch 0/25: 2.1063E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:42<00:00,  7.14it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.16	0.08	0.05	0.16	0.2	0.21	0.16	0.22	0.24	0.27	0.3	0.58
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.16 0.08 0.05 0.16 0.2 0.21 0.16 0.22 0.24 0.27 0.3 0.58
#
# Found new best model with nDCG@5: 0.21
# Epoch: 1/25, Loss: 4.4788E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [26:39<00:00,  4.39it/s]
# mean loss after epoch 1/25: 4.4788E-03
# Epoch: 2/25, Loss: 6.6858E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:18<00:00,  4.28it/s]
# mean loss after epoch 2/25: 6.6858E-03
# Epoch: 3/25, Loss: 6.7583E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:27<00:00,  4.26it/s]
# mean loss after epoch 3/25: 6.7583E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.25it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.16	0.08	0.06	0.16	0.2	0.22	0.16	0.22	0.28	0.4	0.46	0.56
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.16 0.08 0.06 0.16 0.2 0.22 0.16 0.22 0.28 0.4 0.46 0.56
#
# Found new best model with nDCG@5: 0.22
# Epoch: 4/25, Loss: 6.7698E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:35<00:00,  4.24it/s]
# mean loss after epoch 4/25: 6.7698E-03
# Epoch: 5/25, Loss: 6.8418E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:37<00:00,  4.23it/s]
# mean loss after epoch 5/25: 6.8418E-03
# Epoch: 6/25, Loss: 6.7724E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:34<00:00,  4.24it/s]
# mean loss after epoch 6/25: 6.7724E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.28it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.15	0.09	0.06	0.15	0.21	0.24	0.15	0.25	0.31	0.39	0.44	0.58
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.15 0.09 0.06 0.15 0.21 0.24 0.15 0.25 0.31 0.39 0.44 0.58
#
# Found new best model with nDCG@5: 0.24
# Epoch: 7/25, Loss: 6.8156E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:30<00:00,  4.25it/s]
# mean loss after epoch 7/25: 6.8156E-03
# Epoch: 8/25, Loss: 6.8548E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:39<00:00,  4.23it/s]
# mean loss after epoch 8/25: 6.8548E-03
# Epoch: 9/25, Loss: 6.8730E-03: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:39<00:00,  4.23it/s]
# mean loss after epoch 9/25: 6.8730E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.23it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.19	0.09	0.06	0.19	0.23	0.25	0.19	0.25	0.3	0.35	0.38	0.4
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.19 0.09 0.06 0.19 0.23 0.25 0.19 0.25 0.3 0.35 0.38 0.4
#
# Found new best model with nDCG@5: 0.25
# Epoch: 10/25, Loss: 6.7769E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:35<00:00,  4.24it/s]
# mean loss after epoch 10/25: 6.7769E-03
# Epoch: 11/25, Loss: 6.8547E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:36<00:00,  4.24it/s]
# mean loss after epoch 11/25: 6.8547E-03
# Epoch: 12/25, Loss: 6.7534E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:37<00:00,  4.23it/s]
# mean loss after epoch 12/25: 6.7534E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.26it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.21	0.1	0.07	0.21	0.26	0.27	0.21	0.29	0.32	0.37	0.39	0.4
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.21 0.1 0.07 0.21 0.26 0.27 0.21 0.29 0.32 0.37 0.39 0.4
#
# Found new best model with nDCG@5: 0.27
# Epoch: 13/25, Loss: 6.9066E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:34<00:00,  4.24it/s]
# mean loss after epoch 13/25: 6.9066E-03
# Epoch: 14/25, Loss: 6.8891E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:36<00:00,  4.23it/s]
# mean loss after epoch 14/25: 6.8891E-03
# Epoch: 15/25, Loss: 6.8819E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:38<00:00,  4.23it/s]
# mean loss after epoch 15/25: 6.8819E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.25it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.23	0.1	0.07	0.23	0.27	0.29	0.23	0.3	0.33	0.37	0.39	0.4
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.23 0.1 0.07 0.23 0.27 0.29 0.23 0.3 0.33 0.37 0.39 0.4
#
# Found new best model with nDCG@5: 0.29
# Epoch: 16/25, Loss: 6.8600E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:38<00:00,  4.23it/s]
# mean loss after epoch 16/25: 6.8600E-03
# Epoch: 17/25, Loss: 6.8267E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:38<00:00,  4.23it/s]
# mean loss after epoch 17/25: 6.8267E-03
# Epoch: 18/25, Loss: 6.8095E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:35<00:00,  4.24it/s]
# mean loss after epoch 18/25: 6.8095E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.25it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.22	0.1	0.07	0.22	0.27	0.29	0.22	0.31	0.34	0.37	0.39	0.4
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.22 0.1 0.07 0.22 0.27 0.29 0.22 0.31 0.34 0.37 0.39 0.4
# Epoch: 19/25, Loss: 6.9286E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:38<00:00,  4.23it/s]
# mean loss after epoch 19/25: 6.9286E-03
# Epoch: 20/25, Loss: 6.8331E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:43<00:00,  4.22it/s]
# mean loss after epoch 20/25: 6.8331E-03
# Epoch: 21/25, Loss: 6.8648E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:41<00:00,  4.22it/s]
# mean loss after epoch 21/25: 6.8648E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.25it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.25	0.11	0.07	0.25	0.29	0.31	0.25	0.32	0.35	0.39	0.4	0.41
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.25 0.11 0.07 0.25 0.29 0.31 0.25 0.32 0.35 0.39 0.4 0.41
#
# Found new best model with nDCG@5: 0.31
# Epoch: 22/25, Loss: 6.8859E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:42<00:00,  4.22it/s]
# mean loss after epoch 22/25: 6.8859E-03
# Epoch: 23/25, Loss: 6.8989E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:41<00:00,  4.22it/s]
# mean loss after epoch 23/25: 6.8989E-03
# Epoch: 24/25, Loss: 6.7447E-03: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 7016/7016 [27:37<00:00,  4.23it/s]
# mean loss after epoch 24/25: 6.7447E-03
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:41<00:00,  7.26it/s]
# P@1	P@3	P@5	nDCG@1	nDCG@3	nDCG@5	PSP@1	PSP@3	PSP@5	R@10	R@20	R@100
# 0.22	0.11	0.07	0.22	0.28	0.29	0.22	0.31	0.35	0.39	0.4	0.42
#
# P@1 P@3 P@5 nDCG@1 nDCG@3 nDCG@5 PSP@1 PSP@3 PSP@5 R@10 R@20 R@100
# 0.22 0.11 0.07 0.22 0.28 0.29 0.22 0.31 0.35 0.39 0.4 0.42

# %% [markdown]
# ## Evaluate best model

# %%
DIR = OUT_DIR

args.__dict__ = json.load(open(f'{DIR}/args.json'))
net.load_state_dict(torch.load(f'{DIR}/model.pt'))

# %%
score_mat = net.predict(tst_loader, K=100)

_filter(score_mat, tst_filter_mat, copy=False)
XCMetrics(score_mat, tst_X_Y, inv_prop)

# %%
rec = xc_metrics.recall(score_mat, tst_X_Y, k=2000)
{k+1: rec[k]*100 for k in [0, 9, 19, 49, 99, 199, 499, 999, 1999]}

# %% [markdown]
# ## Initialize A

# %%
net.train()

with torch.no_grad():
    for b in tqdm(tst_loader):
        b = net.ToD(b)
        out = net(b)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 466/466 [01:42<00:00,  4.57it/s]

# %%
args.device = 'cuda:11'

# %%
net.to(args.device);
net.update()

# %%
dataset = trn_dataset; Y_X = trn_X_Y.T.tocsr(); bsz = 4096; kappa = 1000
net.eval()
net.swa_swap_params()
total = len(dataset)
M_indices = []; M_values = []

with torch.no_grad():
    for ctr in tqdm(range(0, total, bsz), leave=True, desc='Encoding'):
        b = net.ToD({'xfts': dataset.get_fts(range(ctr, min(ctr+bsz, total)))})
        embs = net.encode(b).detach()
        res = torch.mm(embs, net.w1.weight.T) + net.w1.bias.reshape(1, -1)
        res = torch.clamp(net.alpha*F.softmax(res, dim=1), min=0, max=1)
        temp = res.topk(net.beam, dim=1)
        M_indices.append(temp.indices.cpu())
        M_values.append(temp.values.cpu())
        del b
net.swa_swap_params()
# Out:
# Encoding: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1754/1754 [06:10<00:00,  4.73it/s]

# %%
M_indices = torch.vstack(M_indices)
M_values = torch.vstack(M_values)

# M_indices = M_indices[:, :20]
# M_values = M_values[:, :20]

numx = M_indices.shape[0]
K = M_indices.shape[1]
data_bin = np.ones(numx * K) 
data_val = M_values.reshape(-1).cpu().numpy()
inds = M_indices.reshape(-1).cpu().numpy()
indptr = np.arange(0, numx*K + 1, K)
shape = (M_indices.shape[0], net.w1.weight.shape[0])

M_bin = sp.csr_matrix((data_bin, inds, indptr), shape)
M_val = sp.csr_matrix((data_val, inds, indptr), shape)
C_bin = Y_X.dot(M_bin)
C_val = Y_X.dot(M_val)

CT_bin = C_bin.T.tocsr()
CT_val = C_val.T.tocsr()

CT_bin_topk = retain_topk(CT_bin, k=kappa)
CT_val_topk = retain_topk(CT_val, k=kappa)
A_init = CT_bin_topk + CT_val_topk
A_init.sum_duplicates()

# %%
A_init.getnnz(1)
# Out:
# array([1175, 1280, 1083, ..., 1268, 1200,    0], dtype=int32)

# %%
Y = [x.strip() for x in open(f'Datasets/ShoppingAds-100K/raw/Y.txt').readlines()]

# %%
print(get_text(A_init.shape[0]-2, Y, A_init, sep='\n'))
# Out:
# 1023 :
# cds|O|469769397|US|en|947935433 , 10 pack Dewalt 20v tool Holder BLACK / YELLOW(194.29, 68248)
# cds|C|6467954|US|en|436b92c3ff8f5c1d:en_US , KD Tools 3624 2- Ton Ratcheting Puller | Auto Tool World(185.39, 77691)
# cds|C|6467954|US|en|5bfa797477184b6a:en_US , RYOBI ONE+ 18V Cordless 10-Tool Combo Kit w/ 3 Batteries, Charger, LINK Rolling Tool Box, Standard Tool Box, & Medium Tool Box(183.24, 74261)
# cds|C|6467954|US|en|1622d5226c19773b:en_US , Apollo Precision Tools Dt0204 71-Piece Household Tool Kit(182.04, 10677)
# cds|C|6467954|US|en|ed4050bc8420b610:en_US , DEWALT 1/4 in. and 3/8 in. Drive Mechanics Tool Set with Toughsystem Trays (131-Piece)(181.91, 36722)
# cds|C|6467954|US|en|f9ee5a3fab800928:en_US , ONE+ 18V Cordless MultiTool with 2.0 Ah Battery and Charger P343B-PSK005(181.76, 5009)
# cds|C|6467954|US|en|ff335312e0391692:en_US , GEARWRENCH 2 Ton 3-1/2 in. 2 or 3 Jaw Reversible Internal/External Pullers(181.49, 35517)
# cds|C|6467954|US|en|029398d94249a971:en_US , DEWALT 20-Volt MAX Cordless Died Cable Crimping Tool with (2) 20-Volt 4.0Ah Batteries, Charger & Case(179.74, 68525)
# cds|O|5817554|US|en|40-C2243 , Spear removing / Opening Demounting Tool for Sankey D & S System(176.36, 71468)
# cds|C|6467954|US|en|0da211e28778f133:en_US , Hart 5-piece Multi-tool Blade Set For Wood, Metal, Drywall, Grout 1686(176.06, 41106)
# cds|C|6467954|US|en|a8feb1df9d829ecb:en_US , Master Appliance 35084 SAE 22 to 10 AWG Ratcheting Master Full Cycle Terminal Crimper(175.57, 82905)
# cds|C|6467954|US|en|ca670dd2f3755cdf:en_US , JobSmart Fence Tool with Hammer, JS2017102(172.81, 12627)
# cds|C|6467954|US|en|13884596639ffc68:en_US , Paladin Tools PA1389 1300 HDTV Universal Crimp Tool with Die(168.33, 79506)
# cds|C|6467954|US|en|8084d2ff1b8bdcdf:en_US , Klein Tool Nylon Tie Tensioning Tool with Auto-Cutoff(166.17, 9763)
# cds|C|6467954|US|en|d2fed5039c1b6142:en_US , Ideal 30-3429 Smart-Grip Multi-Crimp Tool(165.38, 74622)
# cds|C|6467954|US|en|4b7404bbbb468ae2:en_US , Crescent 193610CVSMN 10" Heavy Duty Fence Tool(163.59, 16633)
# cds|C|6467954|US|en|5bb3553386b6f8d1:en_US , Makita HB350 1-3/8 in. 10 Amp Corded Magnetic Drill(163.11, 88114)
# cds|O|6296724|US|en|114369497614 , E5 Quick Change Tool Post For 200-400mm Lathe 8"-16" Multifix E(162.71, 61126)
# cds|O|132533|US|en|156443 , Ryobi 039028007054 Auxiliary Handle(162.69, 72170)
# cds|C|6467954|US|en|82b285826a327c15:en_US , DEWALT 22 oz. Steel Framing Hammer(162.02, 11524)
# cds|C|6467954|US|en|277ef016cf908523:en_US , Milwaukee Oscillating Tool Blade: 1 3/8 in Blade Wd, 1 1/2 in Blade Lg, Straight Cutting, 1 Pieces, Milwaukee Model: 49-25-1501(161.51, 83244)
# cds|C|6467954|US|en|e48ed360dc1f5488:en_US , DEWALT 20-Volt MAX XR Li-Ion Cordless Brushless Drill/Impact Combo Kit (2-Tool) w/ 20-V Brushless 6-1/2 in. Circ Saw(Tool-Only)(160.63, 51918)
# cds|C|6467954|US|en|f5f34c2c07c26f2f:en_US , DeWalt N435687 Belt Hook Clip Kit for DCF620 DCF620B DCF622 Drywall Screwgun(160.33, 74286)
# cds|O|8949|US|en|8608889 , Gardener's Lifetime Long T-handle Lawn Edger(159.55, 98609)
# cds|C|6467954|US|en|c83e5a192bf6670c:en_US , Dyson Dc40 Dc41 Dc65 Combination Tool 920753-01, Gray(157.93, 53042)
# cds|C|6467954|US|en|4499e48385ddb500:en_US , DeWalt 5140001-90 Outer Flange(156.84, 65583)
# cds|C|6467954|US|en|3a3da43ebe90c686:en_US , Bones Bearing Puller Tool(156.28, 74927)
# cds|C|6467954|US|en|2eb5e8e74fc0c7ea:en_US , AJC Shingle Slate Ripper(156.26, 44931)
# cds|C|6467954|US|en|5f63deb4f5691d85:en_US , DeWalt TStak Flat Top Organizer Storage Box DWST17807(155.62, 26466)
# cds|C|6467954|US|en|f9776255608ff34e:en_US , PSI Woodworking CLTSET58 Straight Bar 3pc Toolrest Set, 5/8" Diameter Post (15.875mm)(155.34, 78752)
# cds|C|6467954|US|en|123f685194cbc2bc:en_US , FEIN Cordless Multimaster 12V AMM 300 PLUS Start(155.26, 48647)
# cds|O|8969059|US|en|LL-U10601 , UtiliCarryWallet 11-In-1 Multi-Tool (1/CD) -by Lucky Line(153.68, 51741)
# cds|O|469769397|US|en|934658362 , 10 pack Craftsman 20v 20 Volt Max Tool holder Tool Mount Tool Hanger(153.40, 8347)
# cds|O|8927679|US|en|801800 , Stainless Steel Garden Pocket Tool(153.16, 37227)
# cds|C|6467954|US|en|f0062157a252c52f:en_US , Astro Pneumatic 9589 4 Pc. Door Panel & Upholstery Tool Set by National Tool Warehouse(153.13, 62373)
# cds|C|6467954|US|en|e8e5b5f751a94a30:en_US , 16 Wrench Holder Organizer Storage Rack Tray Toolbox Sorter Wall JSP Brand (Red)(150.86, 23567)
# cds|C|6467954|US|en|1829c5b07e22ce7c:en_US , Vevor Magnetic Drill Magnetic Base Drill 750w Mag Drill 0.5" Max Boring Diameter(150.74, 44366)
# cds|C|6467954|US|en|0862569a899f683a:en_US , CALIDAKA Saw Slot Adjuster Mortise and Tenon Tool Movable Measuring Block Making Seam Adjustment Controller Table Woodworking Tool Mortise Measuring(150.63, 24134)
# cds|C|6467954|US|en|8611375503ffec67:en_US , Dewalt DWE4997NVS 2-inch (50mm) Brushless Variable Speed Paddle Switch Die Grinder w/ No Lock-On(150.34, 19014)
# cds|O|101702933|US|en|254359212372 , Snap-on Gmtk General Mechanic's Maintenance Military Tool Set Kit 8(150.31, 95506)
# cds|C|6467954|US|en|19fc3d124e04bfb2:en_US , Bearing Packer - Plastic PTW1218(150.24, 35625)
# cds|C|6467954|US|en|ac29922143886fde:en_US , RYOBI ONE+ 18V Cordless 2-Tool Combo Kit W/ Drill/Driver, Circ Saw, (2) Batteries, Charger, Bag, & Drill/Drive Kit (40-Piece) power tool set, power(149.83, 76267)
# cds|C|6467954|US|en|295fc0f960cdd9d9:en_US , 2 Pieces Automatic Rebar Tie Wire Twister, Rebar Tie Wire Twister Tool, Rebar Wire Twister Pull Tie Wire Twister, Concrete Metal Wire Twisting Fence(149.38, 12054)
# cds|C|6467954|US|en|87192eef21c738ee:en_US , Essentials Purple Floral Garden Hand Tools Set with Cultivator, Trowel, Pruner and Bonus Gloves, Size: Trowel-10.63 inch x 2.95 inch x 1.3 inch ;(149.17, 88804)
# cds|C|6467954|US|en|4f32ba3060b3fd5e:en_US , Xcelite Tca100Stn General Hand Tool Kit,no. Of Pcs. 89(149.08, 61221)
# cds|C|6467954|US|en|614f8afeba197cd0:en_US , Dynamite T1107 Dynamite Ultimate E-clip Tool 1.5mm-5mm(148.23, 35717)
# cds|C|6467954|US|en|7b4f7ee9ed77739e:en_US , ROCKWELL Sonicrafter Carbide Grit Rasp | RW8924(147.28, 23941)
# cds|C|6467954|US|en|feae634b66ec8905:en_US , Gerber SUSPENSION-NXT multi-tool(147.19, 64727)
# cds|C|6467954|US|en|4c6bff95c5d451fc:en_US , 63 inch Adjustable Garden Rake for Leaf - Collect Loose Debris Among Delicate Plants Lawns and Yards Best Expandable Head rake for Leaves Small to(146.64, 26213)
# cds|C|6467954|US|en|3db5520fa71bfff4:en_US , Ken-tool Lock Ring Remover,30 In,11/16 In Stk,Stl Model: 33223(145.65, 92380)
# cds|C|6467954|US|en|3149cd9383f45333:en_US , Tool Holder Magnetic Panel Carlyle Tools(144.72, 84291)
# cds|C|6467954|US|en|c889e00a8757dee8:en_US , Ryobi 18-Volt One+ Cordless 5-Tool Combo Kit with (2) 1.5 Ah Compact Lithium-Ion Batteries, Charger, and Bag(144.63, 96301)
# cds|C|6467954|US|en|35ded39bc0802ba4:en_US , OEM Tools 27119 Bearing Race Installer Set(144.05, 74663)
# cds|C|6467954|US|en|9e4069c5d9e555e9:en_US , Longacre 78295 Digital C/C Gauge w/AccuLevel & Quick Set Adapter(143.59, 10840)
# cds|O|6020949|US|en|cp-26pc-tl-kt%2B965833 , Design Your Own 26 Piece Deluxe Home Tool Kit(143.58, 4120)
# cds|C|6467954|US|en|b3e4ad9d60e66b66:en_US , Ace 2-1/2 in. W Steel Stiff Paint Scraper(143.52, 96062)
# cds|C|6467954|US|en|caba7f034664f752:en_US , Eaton Fuller Transmission Countershaft Front Bearing Puller RR1012TR-3 - Oni Tools(143.10, 87568)
# cds|O|10900|US|en|191200 , Ferrule Blaster Ferrule Puller(142.72, 27234)
# cds|C|6467954|US|en|450756d910dd42a7:en_US , Warrior 2 Amp Variable Speed Oscillating Multi-Tool(142.71, 97974)
# cds|C|6467954|US|en|4bea0648624f7051:en_US , DEWALT 20-Volt MAX Cordless 4-1/2 in. to 5 in. Grinder with (25) Metal and Stainless Cutting Wheels DCG412BW8062W25(142.41, 1137)
# cds|C|6467954|US|en|42f7b5399e9d160a:en_US , RYOBI Impact Rated Driving Kit With (8-pc) with Impact Rated Driving Kit (70-pc)(142.41, 64709)
# cds|C|6467954|US|en|13a3485e292476d2:en_US , RDX Carbide Tool Grinder(142.06, 94857)
# cds|C|6467954|US|en|6a794c2f73fbd298:en_US , Saker Deburring Tool Pro-Deburring Drill Bit,Deburring Tool for Metal,Remove Burr Steel Tools Quick Release Shank Fits 1/8' (3mm) to 3/4' (19mm)(141.70, 29257)
# cds|C|6467954|US|en|cdff87e625f826ae:en_US , DEWALT DG5132 Heavy-Duty Yoke-Style Suspenders(141.35, 22116)
# cds|C|6467954|US|en|351b6274eedcebf5:en_US , Cruz Tools Fender Mount Tool Kit - DMX2(141.09, 6887)
# cds|C|6467954|US|en|3313c52f3e00f3c4:en_US , Marshalltown Heavy-Duty Road Rake, Model RED802920(141.05, 46468)
# cds|C|6467954|US|en|256c2a2584cdf19f:en_US , Wooden top for roller cabinets chrono a(141.04, 25654)
# cds|C|6467954|US|en|5885ad953e75a637:en_US , Gerber 1732 Armbar Slim Drive Bronze(139.46, 55400)
# cds|C|6467954|US|en|4035ae60a4db9f15:en_US , Westcott Weeder Tool, Die-Cut Cartridges, White, for Craft, 1-Count(139.24, 24932)
# cds|C|6467954|US|en|956ab6458338ba8c:en_US , BOSCH Power Tools Combo Kit GXL12V-310B22 - 12V Max 3-Tool Set with 3/8 In. Drill/Driver, Pocket Reciprocating Saw and LED Worklight(139.13, 95464)
# cds|C|6467954|US|en|3688547b0b7a8656:en_US , Biker's Choice Roll-Up Tool Kit 151522(138.52, 29785)
# cds|C|6467954|US|en|53b3384cb31c9ff8:en_US , Milwaukee M18 Magnetic Drill — With 2 Batteries, 18 Volt, Model 2787-22HD(138.42, 25518)
# cds|C|6467954|US|en|e07f6546b3abbefb:en_US , PT-6400-C 3376015 Cylinder Liner Puller Assembly Tool Alt(137.73, 65103)
# cds|C|6467954|US|en|62d7477628016a55:en_US , Zurn P1321-12-CT 12-inch Cartridge Removal Tool(137.71, 77369)
# cds|O|133112864|US|en|TK25/60 , Tool Kit - Chain Breaker & Puller For 25-60 Chain(137.71, 24843)
# cds|C|6467954|US|en|76252ff6cf114cb8:en_US , Garage Storage Organization Tool Storage Rack,Garden Hose Holder,Heavy Duty Tool Organizers Garage Wall Mount Hooks, Space Saving Max 300 lbs Garden(136.89, 2737)
# cds|O|6901112|US|en|70004 , ACME C-Clamp Prop Puller(136.76, 78900)
# cds|C|6467954|US|en|781722a4321445c6:en_US , Valve Lash Wrench - 1/2 in Wrench - Adapter Bushings Included - Aluminum - Black Anodize - Kit(136.75, 76066)
# cds|C|6467954|US|en|c15927331466b80b:en_US , Maxfit Steel Driving Bit Set (30-Piece) with Sleeve(136.43, 28330)
# cds|C|6467954|US|en|16f7e9306ef76033:en_US , Dorman - HELP Windshield Wiper Arm Tool 49023(136.01, 94049)
# cds|C|6467954|US|en|708ad02f3e83496f:en_US , Wrecking Bar 45 In. Steel Rocker Dual Claw Head Nail Screw Remover(135.76, 50605)
# cds|C|6467954|US|en|4583aab00eeebccb:en_US , Heavy-Duty Nail/Screw Removing Pliers(135.26, 18204)
# cds|C|6467954|US|en|f2ea8ef21c53d290:en_US , DEWALT 14-Piece Screwdriver Guide Set | DW2097 | Acme Tools(135.04, 5790)
# cds|O|112466508|US|en|7794 , Renishaw OTS Optical Transmission 3D Touch-Trigger Tool Setter for Machining Centers(134.94, 26357)
# cds|O|162826539|US|en|607958712fb5a56fa003676e , 65MM Bench Drill To Square Tenon Machine Converter Chuck Holder Modified Tenoning Eyelet Accessories with Reducing Sleeve (40/53/55/58/60 Optioanal)(134.68, 21523)
# cds|O|507161872|US|en|185046063672 , Hitachi Chain Mortiser Bc21sa Single Phase 100 V 50/60 Hz 1140 W(134.68, 57874)
# cds|C|6467954|US|en|0357e8d91a63bd5a:en_US , Engine Camshaft Checking Fixture Kit w/Dial Indicator; 0 to 1.000 Inch Range 66830 Proform(134.62, 31719)
# cds|C|6467954|US|en|d17dfb0d3c806a1f:en_US , Milescraft Orbiter Multi-Angle Drill Attachment(134.05, 64551)
# cds|C|6467954|US|en|8b24f66f7c088b7a:en_US , Tekton 90192 Comb. Wrench Set,1/4-1" 8-22Mm,30Pcs.(133.95, 16194)
# cds|C|6467954|US|en|013a9ff627d856d8:en_US , Apollo 1 PEX Quick Pinch Clamp Tool Black/Yellow 1 pc., Size: 5.5 x 15.25 x 6.5(133.77, 59477)
# cds|C|6467954|US|en|3164e1a33163d793:en_US , Cricut Weeding Tool Kit | Michaels(133.58, 8348)
# cds|C|6467954|US|en|68848591e911f82d:en_US , Westward Rolling Tool Cabinet: Gloss Red, 28 3/4 in W x 18 1/10 in D x 33 7/8 in H, Red, 5 Drawers Model: 48RJ74(133.41, 49292)
# cds|C|6467954|US|en|e2fc2a4a68c3ad91:en_US , Dewalt Angle Grinder: 13 A Current, 8,500 RPM Max. Speed, Trigger, 7 in Wheel Dia Model: DWE43840CN(133.24, 49877)
# cds|C|6467954|US|en|93b8f54b5e854b12:en_US , Arsenal General Construction Tool Apron in Gray | 13694(133.06, 3698)
# cds|C|6467954|US|en|84439d24f07c0990:en_US , BOSCH 4-1/2 Inch Angle Grinder GWS8-45(133.05, 26053)
# cds|C|6467954|US|en|b7fa1b5f5fe164a8:en_US , GERBER MP600 Multi-Plier, Needle Nose, Bladeless, Black [30-000952](132.82, 66601)
# cds|C|6467954|US|en|e61f67cd5e150516:en_US , STANLEY COLORmaxx STMT71653 Mechanics Tool Set, Chrome Vanadium Steel, Silver, Chrome, 145-Piece(132.79, 72384)
# cds|C|6467954|US|en|58431f3c96d04f85:en_US , Lodesol Flexible Magnetic Tool Holder 12.5"x9.5" Mp4835(132.46, 59289)
# cds|O|131363368|US|en|shopify_US_1537997252_5446580356 , GuaSha Professional Tool-3(132.19, 84609)
# cds|C|6467954|US|en|1a2aeacf6bf2da97:en_US , Threading & Tapping attachment-lathe tailstock die holder set Machine Tools ((MT2))(131.80, 90480)
# cds|C|6467954|US|en|1267938aea96f857:en_US , Universal Black Finish Steel Adjustable Face Spanner Wrench Pin Pliers For Round Nuts with Drilled Holes (3mm)(131.69, 80620)
# cds|O|142382492|US|en|BM30003 , 7mm Preset Torque Wrench, Hex Size 3/4", Preset Torque 14 in lbs(131.43, 5794)
# cds|O|1228374|US|en|HDP-155.00 , WireJewelry Hammer Handpiece for Eurotool Flex Shaft System(131.27, 8356)
# cds|C|6467954|US|en|aec03882fe6457e2:en_US , Pittsburgh 6 In. T-Bevel(131.17, 77494)
# cds|C|6467954|US|en|e4c86e9646bfc4c1:en_US , DEWALT 20-Volt MAX Cordless 1/4 in. Impact Driver, (1) 20-Volt 3.0Ah Battery & Charger(131.11, 68166)
# cds|C|6467954|US|en|1ab044e7c5c53221:en_US , 18v Octane Angle Grinder Brushless Cordless 4-1/2 In. Lithium-ion 1.5(130.97, 75611)
# cds|C|6467954|US|en|1acf9c84bd9f409a:en_US , Lisle 3/8 in. x 16 in. Short Installer Adapter for 38850 Pulley Puller(130.62, 74063)
# cds|C|6467954|US|en|fbcea7b975138c17:en_US , Workpro 16 inch Top Wide Mouth Tool Bag with Water Proof Rubber Base, Multi-Compartment, 46 Pockets, For Tool Organizer & Storage, W081122a(130.38, 72165)
# cds|C|6467954|US|en|c5785b1dbfb882d3:en_US , Dewalt DCW100K Portable Stick & TIG Welder 1 Tig Welder(130.30, 67764)
# cds|O|121825104|US|en|shopify_US_2112141262945_19844992761953 , AFW Rigging Pliers 5"(129.68, 92890)
# cds|O|6607559|US|en|BGSS-102 , Bench Grinder Safety Scale(129.59, 92136)
# cds|C|6467954|US|en|30a5e6197e3d77aa:en_US , DEWALT DW 23PC Titanium Drill Bit Set(129.02, 19509)
# cds|C|6467954|US|en|bdf5445a27d7c783:en_US , Granite Design Talon 2 Units(127.64, 66718)
# cds|C|6467954|US|en|2cd5a35f6ea2dbf7:en_US , OTC 7470 INJECTOR TIMING TOOL SET,(127.57, 97889)
# cds|C|6467954|US|en|c322fa447b1352bc:en_US , GEARWRENCH GW Series 72" x 25" 20 Drawer Roller Cabinet Black - Red(127.46, 24889)
# cds|C|6467954|US|en|ac23abc11b8bda08:en_US , Dremel 2050-11 Stylo+ Versatile Craft & Hobby Tool With 11 Accessories - each(126.57, 42833)
# cds|C|6467954|US|en|c1989ca8473d3985:en_US , Quad Logic Wheel Bearing Installer/Remover Tool Rear Only Polaris RZR 800 2010-2014(126.36, 84654)
# cds|C|6467954|US|en|fdd7272ce55aab37:en_US , Mayhew Pro 1-1/4 in. W Blade 0.498 in. Dia. Body Pneumatic Hammer(125.99, 86671)
# cds|C|6467954|US|en|d5c115781c35a6fa:en_US , Spear & Jackson 94-370R Eclipse Saw Tooth Setter, Red(125.93, 69519)
# cds|O|8009538|US|en|12202768 , Global CNC Industries Turret & VDI Tool Holders; Type: BMT Live Tooling ; Clamping System: 73mm X 70mm ; Tool Axis: Axial ; Through Coolant: Yes(125.81, 73962)
# cds|C|6467954|US|en|aeecb73c936fefd4:en_US , Marshalltown 10.25-in Zinc Plated Steel Moulding Pry Bar | MPB-L(125.59, 24765)
# cds|C|6467954|US|en|1595befdc07af4ea:en_US , Burgon and Ball Deluxe Gardening Tool Set(125.57, 7441)
# cds|C|6467954|US|en|5712060d10889134:en_US , Diamabrush ZMSTBLD25R10 Coatings/Mastic Removal Replacement Blades Counter Clockwise for 16-inch and 19-inch Tools, 25 Grit, 10 Blades(125.29, 86367)
# cds|C|6467954|US|en|b8cfbf83b61c826a:en_US , Brand Lisle Exhaust Pipe Rubber Hanger Support / Removal Pliers Tool(125.23, 43251)
# cds|C|6467954|US|en|2bc0c96ca13234e3:en_US , Park Tool | Spa-1 and Spa-2 Pin Spanners Spa-1, Green(125.20, 48485)
# cds|O|116927301|US|en|46SO-DD-HS-COY , Direct Draw Hammer Sheath(124.94, 58267)
# cds|C|6467954|US|en|98164e4daad9711b:en_US , Ganasan Contour Gauge With Lock|10+5 Inch Construction Rulers Measure Tool For Corners And Contoured Handyman Diy Woodworking Tools Construction Carpe(124.94, 46112)
# cds|O|116927301|US|en|46HH-AHBH-2-W/M , AIMS Hammer/Hatchet Belt Holder with Magnet(124.86, 75331)
# cds|C|6467954|US|en|a071e8cc74fe93fd:en_US , Baileigh PH-24A Pneumatic Operated Planishing Hammer, 24 Inch Throat Depth(124.76, 27612)
# cds|O|348908|US|en|MOP0021-X001-Y001 , Motion Pro Damper Rod Fork Tool-Dirtbike Damper Rod Fork Tool(124.22, 93908)
# cds|O|5642721|US|en|J1853 , Detroit Diesel Injector Timing Tool(124.09, 57729)
# cds|C|6467954|US|en|65b25a39e5c4f54f:en_US , Dare Chain Grab Puller and Tightener - 2456(124.05, 92048)
# cds|C|6467954|US|en|142887eb503e24dd:en_US , S & G Tool Aid Sgt-18915 Terminal Crimper Kits(123.98, 58602)
# cds|C|6467954|US|en|696d78a67acc3318:en_US , 71161161090, FEIN ASCM 18 QM 4-speed Cordless Drill/Driver(123.72, 61736)
# cds|C|6467954|US|en|433b9c7f33a78c62:en_US , RYOBI ONE+ 18V Cordless 18-Gauge AirStrike Brad Nailer with Compression Drive 3/8 in. Crown Stapler (Tools Only)(123.52, 8934)
# cds|C|6467954|US|en|9f01f143a82ab53e:en_US , Bosch Angle Grinder: 13 A Current, 11,500 RPM Max. Speed, Slide, (1) Bare Tool, (1) Wheel Guard Model: GWS13-50TG(123.31, 35297)
# cds|C|6467954|US|en|248117fb790429ce:en_US , 1" Drain Tube Flaring Tool Flanging Tool 8PCS Fastener for Boat Marine Plumbing Replaces 520290-1(122.91, 20026)
# cds|C|6467954|US|en|7377d95feee8ba58:en_US , DeWalt DWMC150 35-Degree Pneumatic Metal Connector Nailer(122.59, 78593)
# cds|C|6467954|US|en|b8870882995fa430:en_US , OTC 5035 Truck Clutch AdjusTment Gauge Set(122.22, 29973)
# cds|C|6467954|US|en|9290c08d3669c9a1:en_US , Mibro Adjustable Tap Wrench, 302871(122.12, 13813)
# cds|C|6467954|US|en|6ac83166efd2d546:en_US , Ring Bending Tool Repair Bracelet Bender Copper Silver Gold Strip Bending Tool(121.10, 24890)
# cds|O|114193152|US|en|B01FJQ14NQ , Glamorway 6Pcs Clay Sculpture Sculpting Tool Mini Ribbon Cutter Metal Tools Set Carving Art(120.81, 9263)
# cds|C|6467954|US|en|2e2b351c821f7757:en_US , Anvil 51 in. Wood Handle Steel 14-Tine Bow Rake(120.77, 10443)
# cds|C|6467954|US|en|c54d15acf555bf6c:en_US , Hyper Tough 38-pc Stubby Tool Set: Wrench Ratcheting Screwdriver Bits(120.73, 25849)
# cds|C|6467954|US|en|8af282d29380cbe6:en_US , Fiskars 18" Demolition Hammer - Dead Blow Hammers(120.48, 68684)
# cds|C|6467954|US|en|8a427d05df121059:en_US , Dremel Straight Router Bit - 654(120.15, 75210)
# cds|C|6467954|US|en|4c1a695c8ca8c170:en_US , Gear Wrench Hose Grip Double-X Pliers - 3/4", 82019(120.08, 69944)
# cds|C|6467954|US|en|96791657c58bb5d4:en_US , Husky Multi-angle Pipe Wrench 1003 005 294 (e10017225)(120.03, 33939)
# cds|C|6467954|US|en|b3acdb35cc28d2a4:en_US , Dremel Drill Press Rotary Tool Workstation For Woodworking Jewelry(120.01, 54218)
# cds|C|6467954|US|en|c477dd7a336f7200:en_US , Toolbag DMM(119.98, 60398)
# cds|C|6467954|US|en|4fc1dc570584ccac:en_US , TEKTON 7 -in Diagonal Cutting Pliers PCT00007 | PCT00007-D(119.60, 56757)
# cds|C|6467954|US|en|de0cce42ccb305d1:en_US , Steelman 79435 Heavy-Duty Tire Valve Stem Puller/Installer, Green(119.50, 96562)
# cds|C|6467954|US|en|174454ad543bbd4f:en_US , Steck Studlever Dent Puller(119.34, 20279)
# cds|C|6467954|US|en|e283b08b64582d08:en_US , Bosch 1Inch SDS-plus Rotary Hammer, Pistol Grip, Chuck Size 1 in, Volts 120, Amps 8, Model GBH2-26(119.21, 82051)
# cds|C|6467954|US|en|4366ec51109e1f88:en_US , Bosch Black Oxide Impact Tough Drill Bit Set (9-Piece)(118.99, 43090)
# cds|C|6467954|US|en|a40241d506179181:en_US , DEWALT DWST08205-DWST08202-DWST08201-DWST08204-DWST08210 ToughSystem Workshop Deluxe Mobile Bundle Kit(118.94, 21630)
# cds|O|101830283|US|en|472571036932_173855230431 , Craftsman Ratchet Wrench 1/4 3/8 1/2 Teardrop 75t 84t Teeth Brand(118.79, 33230)
# cds|C|6467954|US|en|04c299e2ff14352e:en_US , DEWALT 3/4" Sds-Max Ground Rod Driver - 324DW5847 - Power Tool & Equipment Accessories - Concrete & Masonry Drill Bits(118.70, 51670)
# cds|O|7308165|US|en|TDPP112+or+TDPP113 , Tire Changing Tool (5" or 6")(118.60, 19565)
# cds|O|10798|US|en|shopify_US_2057445572697_21364897775705 , Gemplers Extra-Wide, Long-Handled Tool Rack(118.60, 74049)
# cds|C|6467954|US|en|6ea698546dbc6ff0:en_US , Dremel EZ726-01 EZ Lock Sanding & Polishing Kit for Rotary Tool, 8 Piece (Dremel EZ726-01)(118.45, 40092)
# cds|C|6467954|US|en|f5b61290af5983d2:en_US , Craftool Strap Cutter Replacement Blades 3081-00 By Tandy Leather(118.44, 84667)
# cds|C|6467954|US|en|b8c48e090f01d320:en_US , DeWalt DW2735 Drill Flip Drive Set(118.13, 93097)
# cds|C|6467954|US|en|d924cd552a10bda7:en_US , RZX 16" RIVET NUT TOOL Hand Blind Riveter ,RIVNUT Riveting Tools with Nut Setting System totally 12mandrels M3 M4 M5,m6,m8,m10 M12, 10-24, 1/4-20 , 5(117.95, 70399)
# cds|O|142898678|US|en|2298357 , Rack Lat Pulldown / Row Attachment - Light Commercial/Residential Power Rack | Bells of Steel(117.83, 74068)
# cds|O|545697639|US|en|880 , CH-22 Manual Tire Changer(117.25, 45313)
# cds|C|6467954|US|en|e6dd3d7be28f199f:en_US , Universal Sharpening Station, Multifunctional Sharpener Professional Knife & Chisel & HSS Drill Electric Multitask Sharpening Machine(117.06, 61680)
# cds|C|6467954|US|en|f60950a66f18e230:en_US , OZ-Puller Post Clamp(116.92, 75145)
# cds|C|6467954|US|en|d2b14df38583ca3d:en_US , Estwing 8-Pocket Leather Electrician's Tool Pouch for Work and Tool Belts, Flashlight Loop, Tape Chain, Pliers Pockets, 3-inch Tunnel Loop(116.81, 43789)
# cds|C|6467954|US|en|9a42ae6cb0f3df2b:en_US , Oni Tools Input Shaft Bearing Puller Tool Kit for Eaton Fuller 1 3/4” & 2” Shafts and Ultra Shift Plus Transmission Bearing 4308011(116.77, 31833)
# cds|C|6467954|US|en|57c89a643c6541fa:en_US , Wrench Set Full Polish Chrome(116.41, 4104)
# cds|C|6467954|US|en|e1603a356b46d445:en_US , MAKITA 18V X2 (36V) LXT Lithium‐Ion Brushless Cordless 21" Self Propelled Lawn Mower, Tool Only Teal | XML08Z | Acme Tools(116.11, 96832)
# cds|C|6467954|US|en|09b1e9fbb3df5043:en_US , Vevor Lawn Mower Blade Grinder 1/2 Hp Bench Blade Sharpener 8" Grinding Wheel(115.89, 33779)
# cds|C|6467954|US|en|6592b45d5cf97c1c:en_US , 100 Pcs Rubber Grinding Heads,3mm Shank Polishing Tip Mounted Point Bufing Wheel for Dremel Rotary Tools(115.71, 86494)
# cds|C|6467954|US|en|1597ded244b6d4e4:en_US , Leatherman Skeletool Multi-Tool Coyote Tan, Clamshell Packaging Full Size, General Purpose 832201(115.44, 50429)
# cds|C|6467954|US|en|b8b07b9b85be016b:en_US , CRAFTSMAN 2000 Series 26.5-in W x 37.5-in H 5-Drawer Steel Rolling Tool Cabinet (Black) | CMST98268BK(115.30, 58056)
# cds|O|6296724|US|en|133439388719 , Sears Craftsman Commercial Electric Drill Heavy Duty Reversible 1/2(115.27, 32104)
# cds|C|6467954|US|en|7cbc63dc75585062:en_US , RYOBI 3 in. Carbide Cut Off Wheel Set (6-Piece)(115.25, 96997)
# cds|C|6467954|US|en|252f3328ff28ddc8:en_US , PSB/Purdy 140900230 Carbide Scraper ~ 2 - 1/2"(115.12, 55240)
# cds|C|6467954|US|en|147651e0457eafbe:en_US , Crescent 24 in. Chain Wrench(114.68, 70196)
# cds|C|6467954|US|en|019a29c6109b5c6a:en_US , Makita XSF03R 18V LXT Lithium-Ion COMPACT Brushless Cordless Drywall Screwdriver Kit (2.0Ah)(114.62, 99958)
# cds|C|6467954|US|en|565bf57c7d24765f:en_US , Dead On Dos22m 22-ounce 18-inch Steel Milled Face Hammer(114.44, 83400)
# cds|C|6467954|US|en|cb5b3838ff9f8589:en_US , Milwaukee 48-22-1928 5" HARDLINE Fixed Blade Knife(114.25, 62062)
# cds|C|6467954|US|en|63474ab23d9dca08:en_US , Edger Blade - Echo 720237001(114.22, 14897)
# cds|C|6467954|US|en|85e97db70cb24959:en_US , Hercules 10 in. Tool Tote with 22 Pockets(113.99, 345)
# cds|C|6467954|US|en|0730b093ef4f25fd:en_US , Homax Drywall Corner Taping Easy Seamer Tool, Plastic, Yellow, Size: 7.6 x 4.5 x 1.9(113.82, 45490)
# cds|C|6467954|US|en|cfdd073da3dd9594:en_US , Ridge Tool Company Manual Threading/Metal Cases, For 12R, Holds 9 Die Heads, 1/EA, #97375 | AFT Fasteners(113.72, 64437)
# cds|C|6467954|US|en|70c0dc20368a2657:en_US , Bauer Tools 1895c-b(113.65, 84524)
# cds|C|6467954|US|en|e623761846d11c8f:en_US , Klein Tools Bull-Pin And Bolt Bags, 3 Compartments, 10 In X 5 In, Canvas - 1 Ea (409-5416)(113.63, 52335)
# cds|O|9202400|US|en|10598 , Irritec Drip Clip Punch/Installation Tool(113.60, 80657)
# cds|C|6467954|US|en|8279924a0a2f2cd2:en_US , Workington Portable Carpenter Metal Tool Box with Latch, Small Parts Box, Sockets Storage Box Organizer 4002(113.49, 90489)
# cds|O|12768591|US|en|898325253 , Pink tool belt incl. pink tool(113.35, 3192)
# cds|O|4214520|US|en|91082068 , Speedway Racing Tire Needler Prep Tool(113.28, 8727)
# cds|C|6467954|US|en|17b099866ffe7fd4:en_US , Crescent Z2 Auto-Bite Tongue and Groove Plier Set (3-Piece)(113.20, 84040)
# cds|C|6467954|US|en|05c509ee40d8889d:en_US , Berry's Superior Bullet Puller(112.94, 83538)
# cds|O|100872875|US|en|21730 , Jacknob 8935, Toilet Partition One Way Screw Removers, Can Remove Sizes: 6-14 by WoodworkerExpress.com(112.93, 59106)
# cds|C|6467954|US|en|b23a623a78b49903:en_US , Gerber Gator Combo Axe and Knife(112.73, 61212)
# cds|C|6467954|US|en|2d127c08cdecc34b:en_US , Gordon Lock-Back Utility Knife(112.64, 6087)
# cds|C|6467954|US|en|20ebe6b121a6ff15:en_US , End Cutting Pliers Nail Puller End Nippers For Zipper Install Stops(112.38, 32993)
# cds|C|6467954|US|en|2e71242c84fbf954:en_US , Milwaukee Lineman's Underground Knife(112.11, 9080)
# cds|C|6467954|US|en|4d4147965dcbf799:en_US , Machinist Clamping Kit, 42 Piece(111.75, 92657)
# cds|C|6467954|US|en|3ae907620849385c:en_US , Epicurean Magnetic Knife Holders(111.23, 57461)
# cds|C|6467954|US|en|e1019aa76bf0cc50:en_US , JEGS 5-Drawer Tool Box Cart | Smooth Ball Bearing Glides | Over 700 LBS Capacity | Red Powder Coated Finish | Includes Drawer Liners(111.23, 68202)
# cds|C|6467954|US|en|8487eb6bb8d6c647:en_US , RYOBI ONE+ 18V Brushless Cordless 1/4 in. Extended Reach Ratchet with (1) 2.0 Ah Battery and Charger(110.93, 5581)
# cds|O|348908|US|en|HPT1WUD-X001-Y001 , HP Tools Showa/KYB Compression Body Fork Cap Tool-Dirtbike Fork Cap Wrench(110.81, 36925)
# cds|C|6467954|US|en|a99bb41dbe23525c:en_US , Milwaukee M18 FUEL 18 Volt Lithium Ion Cordless Brushless String Grass Trimmer 8.0Ah Kit with Pole Saw, Hedge Trimmer, Edger(110.35, 45690)
# cds|C|6467954|US|en|da4254659837e043:en_US , General International 15 In. Bench Commercial Variable Speed Drill Press with Laser and Regular Chuck Green | 75-060 M1 | Acme Tools(110.21, 44753)
# cds|C|6467954|US|en|d6dc9bdbbf8431cc:en_US , Dr. Slick Fly Tyer Gift Set | Fly Fishing Tying Set | SKU TYER(110.17, 65039)
# cds|C|6467954|US|en|dc08a30c1136e329:en_US , 12-Piece Reciprocating Saw Blade Kit By Milwaukee 49-22-1129(110.16, 96229)
# cds|C|6467954|US|en|aca52a5cce444d00:en_US , Eklind 10 Piece T-Handle Hex Key Set - Hex Range 3/32 to 3/8", Alloy Steel | Part #53610(110.15, 70603)
# cds|O|3074108|US|en|2KUY1 , Prime Edge Knife Sharpening Machine: 110 V, 1/6 Horsepower, Single Phase, 12 in Overall Dp Model: HE1-110V1P60HZ(110.14, 62876)
# cds|C|6467954|US|en|c77c545302407832:en_US , Nifty Home Products, Inc. Innovation Factory Trucker'S Friend All-Purpose Survival Tool - Woodcraft(110.01, 97592)
# cds|C|6467954|US|en|99d8388100bb690c:en_US , Powerbuilt Master Steering Wheel and Lock Plate Puller Kit, Included (qty.) 21, Product Type Pullers, Single Set, Model 648748(109.55, 21004)
# cds|O|114143634|US|en|553539078914_254178903344 , Canvas Roll Up Tools Storage Bag 8/10/14-pocket Spanner Wrench(109.50, 36945)
# cds|C|6467954|US|en|c7ee82bf9a672e59:en_US , Wal-Board Tools 24 in. Taping Knife with Wooden Handle(109.43, 3842)
# cds|O|101704838|US|en|174104040720 , Hart 5 Piece Quick Tatch Trowel Set Grout Float, Square Notch, Handle(109.36, 22863)
# cds|C|6467954|US|en|89b7f0b7fcea9a0a:en_US , DEWALT Reciprocating Saw Blades, Straight Back, 6-Inch, 14 TPI, 5-Pack (DW4808)(109.35, 16960)
# cds|O|101684535|US|en|254905331731 , 1" Quick Release 'l' Shaped Windshield Glass Knife - Rockwell(109.13, 44638)
# cds|C|6467954|US|en|c2e510528af86727:en_US , Landscapers Select PS-60943L Lawn Weeder, Plastic Handle, Powder-Coated(109.12, 43607)
# cds|C|6467954|US|en|5d55e412a46d9f99:en_US , Milwaukee Cordless Concrete Vibrator Model: 2911-20(109.12, 34151)
# cds|C|6467954|US|en|6551d06ab0397ab0:en_US , Milwaukee M12 FUEL 12-Volt Li-Ion Brushless Cordless Hammer Drill and Impact Driver Combo Kit (2-Tool)W/ M12 3/8 In. Ratchet power tool set, power(108.92, 49285)
# cds|C|6467954|US|en|72dd5fb4752206d0:en_US , Bulltools 6-Piece Flex-Head Extra Long Ratcheting Wrenches Double Box End Chrome Vanadium Steel 72-Tooth Wrench Set with Metric 8mm - 19mm, Size: SETS(108.86, 58808)
# cds|O|8740|US|en|306810110 , DEWALT 20 in. 20V MAX Lithium Ion Cordless Battery Walk Behind Push Lawn Mower with (4) 5.0Ah Batteries and Charger Included(108.83, 18074)
# cds|C|6467954|US|en|3a2847b3feda7132:en_US , GEARWRENCH Ratcheting Combination Wrench 16mm, 12 Point - 9116D(108.24, 63964)
# cds|C|6467954|US|en|b9533f36c639309b:en_US , KAKO String Trimmer Line 0.065'' Replacement Spool for Ryobi One Plus AC14RL3A 18V 24V 40V Auto Feed Cordless Weed Eater Spools Line with AC14HCA(108.06, 71013)
# cds|C|6467954|US|en|ccef3f01901de174:en_US , Jackhammer Driving Kit Jack Hammer Driver Bit Spacer Install Fence(107.94, 67447)
# cds|C|6467954|US|en|5dbfecb4cbf53526:en_US , Guosu Cable Grip Wire Gripper Steel Cable Puller Tool for Wire Rope,Pulling 4408 Lbs(2 Ton)(107.90, 85846)
# cds|C|6467954|US|en|d01fd345d3179390:en_US , Dewalt Screwdriver Kit: 1/4 in Hex Drive Size, 430 RPM Free Speed, (1) Bare Tool, (1) Battery, (1) Charger Model: DCF680N1(107.79, 94538)
# cds|C|6467954|US|en|d28a4c7430443570:en_US , Craftsman 8 oz Ball Pein Hammer Steel Head 11 in.(107.51, 46760)
# cds|C|6467954|US|en|087f618f97ec36ea:en_US , Milwaukee 48-01-7787 9" 14 TPI The Torch SAWZALL Blades (Pack of 100)(107.31, 50534)
# cds|C|6467954|US|en|3cd442db3c7ebeed:en_US , Feuling Crankshaft Runout Measuring Tool 9015(107.24, 25409)
# cds|C|6467954|US|en|d1632a0a36c283d9:en_US , Flex 24-volt Brushless Drywall Cut Out Tool - Fx2471-z -tool Only-(107.21, 10821)
# cds|C|6467954|US|en|3e03c1b0780b288b:en_US , DEWALT 125 MPH 600 CFM Flexvolt 60V MAX Lithium-Ion Cordless Axial Blower (Tool Only) with Bonus (1) FLEXVOLT 60V 3.0Ah Battery(107.14, 40317)
# cds|C|6467954|US|en|f4cab55e2c9c3424:en_US , Attractor 24 in. Magnetic Sweeper PS337C(106.85, 25410)
# cds|C|6467954|US|en|cd697a164a554954:en_US , Milwaukee 48-68-0031 1/4" Collet Nut(106.74, 54444)
# cds|C|6467954|US|en|7d4a8bdcf2c0f94e:en_US , Westward 2Dbr6 Ball Pein Hammer,8 Oz,hickory Handle(106.68, 60073)
# cds|O|247906560|US|en|22455 , Ko-ken Socket Set in Foam PM-HND-1014-00-F / TI4261M | Pentagon, Socket Set Titanium(106.42, 75228)
# cds|O|272358891|US|en|419058 , Hummingbird Needle Threader(106.41, 35604)
# cds|C|6467954|US|en|6a1c14a4700cfffe:en_US , BOSCH 10 pc. Wood and Metal Cutting T-Shank Jig Saw Blade Set | T5002 | Acme Tools(106.39, 2932)
# cds|C|6467954|US|en|be51f85a7f0207db:en_US , Mueller Kueps 457705 Line Wrench Kit With Joint Brand(106.25, 87607)
# cds|C|6467954|US|en|80515813c37838e6:en_US , Knipex 02 01 200: Knipex High-Leverage Combination Pliers(105.84, 73491)
# cds|O|6296724|US|en|114918806727 , Genuine Makita Makpac Interlocking Charger Case Systainer W/o(105.82, 60009)
# cds|O|111108931|US|en|PS16325548 , Ryobi 314608005 Bump Feed Trimmer Head Assembly (Inc. Key No. 21)(105.73, 9290)
# cds|C|6467954|US|en|dd19ff2ed10b9ef8:en_US , Icon SAE Professional Ratcheting Combination Wrench Set, 7 Piece(105.70, 54359)
# cds|O|110026978|US|en|shopify_US_4621895046_15133467334 , Milwaukee 4094 Diamond Coring Motor 450/900 RPM, 20 Amp with Shear Pin(105.56, 24586)
# cds|O|423913691|US|en|433395879019_133947822736 , 1~20pack 20 Volt For Dewalt 20v Max 5.0ah Lithium Ion Battery Dcb206-2(105.30, 76002)
# cds|C|6467954|US|en|453d4abcece22b0b:en_US , 3pcs Locking Pliers Set 10'' 7" 5" Curved Jaw Nickel Plated Heat(105.18, 7642)
# cds|C|6467954|US|en|cf5a5bdbb7776b00:en_US , Magic Tool Clip Set Regular - Marc Petitjean - Fly Tying(105.17, 13422)
# cds|C|6467954|US|en|255bf24da809f042:en_US , T40070-T40133 Camshaft Clamp Set Alt(105.01, 97716)
# cds|C|6467954|US|en|5ca8836234eec0ed:en_US , Rockler Table Saw Blade Holder(104.86, 84417)
# cds|C|6467954|US|en|3ca071894f86af50:en_US , K Tool International 72450 - Magnetic Tool Hanger(104.54, 47565)
# cds|O|8128387|US|en|CR10B , Handle Maker(104.45, 6090)
# cds|O|117171671|US|en|830508606 , Knipex Holder ~ Leather Case for Knipex Pliers ~ Knipex Pliers Holder ~ Plier Holster for Knipex Cobra(104.44, 79747)
# cds|C|6467954|US|en|bc3748ca24728fbe:en_US , Ultima 5.5" Razor Sharp Surgical Seam Rippers/seam Cutters (4 Pack)(104.28, 92347)
# cds|C|6467954|US|en|d2e4f3b027ee1995:en_US , DeWALT 3/4" Pipe Capacity, PEX Expander Tool - 1 Piece, Cuts PEX Type-A, Includes Expansion Head | Part #DCE40034(104.21, 33064)
# cds|O|113478214|US|en|31-004011 , Gerber Gear Randy Newberg EBS Tools Replacement Blades(104.20, 43795)
# cds|C|6467954|US|en|15c6785a45e48d08:en_US , Flexible Hose Clamp Pliers 2' Long Wire For Flat Oil Water Fuel Hose(104.19, 42382)
# cds|C|6467954|US|en|f455177fd9394293:en_US , Powerbuilt 648796 For Honda Crank Pulley Holder Tool(103.93, 34824)
# cds|C|6467954|US|en|212fc674c11a44bb:en_US , Dewalt 5140178-86 Replacement Radio Power Supply Dwst08810(103.81, 49269)
# cds|O|144646454|US|en|09A0121 , Replacement Blades for Pro Seam-Ripper Kit, Repl. (6)(103.62, 7782)
# cds|O|7892326|US|en|R-3018+RC4 , UTV Roll Bar Tool Holder Carrier by Hornet Outdoors(103.53, 74638)
# cds|C|6467954|US|en|7acbc115daa38d53:en_US , SUNEX TOOLS Pencil Air Die Grinder Kit(103.19, 13393)
# cds|O|9299300|US|en|19876 , Frame Hammer- 1 Each(102.97, 60241)
# cds|C|6467954|US|en|369fbcb6836d2471:en_US , Westward Intermediate Chest: Powder Coated Black, 26 3/8 in W x 17 in D x 10 5/8 in H, Black Model: 32H849(102.94, 76444)
# cds|C|6467954|US|en|592e767d18914901:en_US , Motion Pro 08-0349 35mm Flywheel Puller M35 X 1.5 R.h.(102.72, 99840)
# cds|C|6467954|US|en|1f521d452ad76a25:en_US , Bond Mattock 15 in. Steel Handle(102.55, 65962)
# cds|C|6467954|US|en|b9d94ce938ad456c:en_US , Multi-Angle Measuring Ruler,Multi Angle Tool,12-Sided Angle Measurement,Tile Holes Measure Ruler with 3-Holes Positioning Apertures,Upgrade Multi(102.52, 575)
# cds|C|6467954|US|en|ee829f932d35e0f2:en_US , GearWrench 9520D 10 Piece 12 Point Stubby Ratcheting Combination Metric Wrench Set(102.36, 12522)
# cds|C|6467954|US|en|80bbedcd43fa8b30:en_US , NAVAC NTR14 Internal & External Reamer, 1/8" to 1 5/8" Tube O.D.(102.18, 32892)
# cds|C|6467954|US|en|294ecf986090d707:en_US , Detroit Diesel Dd15 Dd16 Camshaft Timing Tool Kit & Tdc Locating Pin(102.15, 18890)
# cds|O|124241419|US|en|103693 , TW8, 3/4 - 1-1/2 Straight Tap Wrench(102.13, 4077)
# cds|C|6467954|US|en|38c37986d77283f3:en_US , Gates 91023 SureLok 1/8" to 3/8" Vertical Quick-Release Push-Lock Pliers(101.68, 85891)
# cds|O|374448703|US|en|m83613137553 , Drill Master 18v 3/8 In Cordless Drill. | Color: Black(101.66, 53708)
# cds|C|6467954|US|en|0aba4e04e20f45c5:en_US , Dremel 615 Router Bit,roundover,1/8 In Bit Dia(101.60, 73753)
# cds|C|6467954|US|en|d3fda0d5ae38696c:en_US , eTORK Click-Style Torque Wrench (1/4-Inch, 40-200 in.-lb)(101.56, 81829)
# cds|C|6467954|US|en|b6ddcf9e2e6f0ee0:en_US , DEWALT 20-Volt MAX Cordless 6-1/2 in. Circular Saw with (1) 20-Volt Battery 4.0Ah and Charger power tool set, power tool combo kits, cordless tool set(101.53, 3307)
# cds|C|6467954|US|en|e507b206c553c792:en_US , CST-1900 - jonard tools(101.43, 70313)
# cds|C|6467954|US|en|aa6ceab8306ad5ca:en_US , Stanley Quick Change Retractable Utility Knife (2-pack)(101.41, 96709)
# cds|C|6467954|US|en|18ff49f1b75f4d4f:en_US , ABN Valve Stem Seal Remover and Installer 11-Piece Tool Kit with Carrying Case – Pliers, Drive Handle, Sockets, Adapters(101.24, 68384)
# cds|C|6467954|US|en|2721a2c9a86e8651:en_US , DEWALT 6 gal Pancake Compressor/2 In. Brad Nailer Combo Kit Yellow/Black | DWC1KIT-B | Acme Tools(100.97, 40062)
# cds|C|6467954|US|en|c565a58b33c84567:en_US , ATOMIC 20-Volt MAX Cordless Brushless Compact Reciprocating Saw with (1) 4.0Ah Battery(100.93, 23056)
# cds|C|6467954|US|en|ee9f42410a638e3c:en_US , Truck Tool Box Mounting Kit Pickup Universal Fit Toolbox Tie Downs Aluminum Alloy J Hooks Crossover with 304 Stainless Steel Screws and Washers(4(100.90, 60229)
# cds|C|6467954|US|en|377556650927335a:en_US , BMW E46 M3 S54 - Genuine BMW Rear Toe Adjustment Tool: A big help when doing an alignment(100.90, 65073)
# cds|C|6467954|US|en|2a9f72c8be513dfb:en_US , Kraft Tool Sk102 Power Troweler Blade,floatshoe,10X14 In(100.58, 12479)
# cds|C|6467954|US|en|c2186f7765d74570:en_US , Tapetech 40" Premium Skimming Finishing Knife Px40tt(100.57, 44484)
# cds|C|6467954|US|en|4034afb5408e7275:en_US , Rubber Bench Block Set (4x4in) with Mini Hammer (6in) - Jewelry Making Kits Supplies, Metal Smiting Tool, Jewelry Tools for Metal Stamping Kit,(100.51, 358)
# cds|C|6467954|US|en|68d4932a3930f6f1:en_US , Dewalt Inner Core Bulb Head Drain Cleaning Cable 5/16 in x 25 ft Model: DCD2005(100.47, 57942)
# cds|C|6467954|US|en|ae7ac8e1dd1ffbdf:en_US , Speedaire 5Yap3 Tool Retractor,for Tool 2-4 Lb,no Lock(100.12, 52431)
# cds|C|6467954|US|en|6ef304eed6081bb2:en_US , SEKETMAN 24 Pcs Combination Ratcheting Wrench Set 12 Point Speed Wrench Set Fit for Garage,Office, Home DIY, Repair and Maintenance(100.10, 31212)
# cds|C|6467954|US|en|97af89a40498d174:en_US , Bosch 12 5 Tpi Rcp Blade 5Pk Pch | Bosch-RP125(99.78, 55642)
# cds|C|6467954|US|en|9c6db3ed7da35d3b:en_US , Milwaukee M12 FUEL 12-Volt Lithium-Ion Brushless Cordless 1/2 in. Drill Driver Kit with 4.0Ah and 2.0Ah Battery and Hard Case(99.65, 12466)
# cds|C|6467954|US|en|ba790f3324155a7a:en_US , Dewalt Genuine OEM Replacement Rip Fence + Rip Fence # Combo00233, Men's, Size: One size(99.58, 80314)
# cds|C|6467954|US|en|43c4a3b148796141:en_US , Bosch Daredevil 6 in. QC Spade Drill Bit Extension(99.45, 50654)
# cds|C|6467954|US|en|0a44015407dcc3ec:en_US , Husky 11 mm 12-Point Metric Ratcheting Combination Wrench(99.03, 63589)
# cds|C|6467954|US|en|2b371302409ff316:en_US , Makita XML11CT1 | 18V X2 (36V) LXT Lithium-Ion 21" Cordless Self-Propelled Lawn Mower Kit /w 4 Batteries (5 Ah) | Tyler Tool(98.97, 56411)
# cds|C|6467954|US|en|90cbf55877709deb:en_US , Ultimate Complete Kawasaki KLR650 Tool Kit with Tool Roll MADE IN USA(98.80, 29129)
# cds|C|6467954|US|en|3a3df56797a1d45d:en_US , 3-piece High Leverage Diagonal Cutter Set(98.72, 60447)
# cds|C|6467954|US|en|eaab6ff939a78c89:en_US , Stewmac Endpin Jack Reamer(98.55, 3203)
# cds|O|121794993|US|en|woocommerce_gpf_12819 , Service Line Puller Kit(98.38, 1555)
# cds|O|137734820|US|en|264040364663 , 40" X 324" (27') Monarch Engine Lathe: Stock 65383(98.35, 72239)
# cds|C|6467954|US|en|7ed4434e39fc853e:en_US , Dewit 60" Half Moon Hoe(98.35, 28874)
# cds|C|6467954|US|en|e8457480289fd4ca:en_US , Pliers Ear Clamp Pliers W/ Side Jaw Knipex(98.25, 56775)
# cds|C|6467954|US|en|8a71b31ccf79ed90:en_US , Corona 14" Level Head Rake - Red(98.08, 44431)
# cds|C|6467954|US|en|da58d37af9571879:en_US , CRAFTSMAN 9-Pack Bi-Metal Set Wood/Metal Cutting Reciprocating Saw Blade Set | 2058840(98.00, 79621)
# cds|O|110888525|US|en|123887934872 , Dewalt 20v Max Dcd780 ,dcd785 Cordless 2nd Gen Trigger Switch(97.99, 55178)
# cds|C|6467954|US|en|1c71612ae0177ae6:en_US , 2x XRP 18V NiCD Dc9096 Battery For Dewalt De9095 Dw9098 Dc9099 18Volt Power Tool, Black(97.74, 4751)
# cds|O|106567002|US|en|HYD+000-163-617 , HydraMaster Evolution Glided Upholstery Tool(97.64, 83281)
# cds|C|6467954|US|en|014c178f88020c79:en_US , DeWalt DCB609(97.54, 69266)
# cds|O|262986322|US|en|47636812345 , MultiTasker Twist Multi-Tool SKU - 476368(97.47, 22437)
# cds|C|6467954|US|en|43f113b13f81dd5e:en_US , OTC Hub Grappler(97.42, 43191)
# cds|C|6467954|US|en|71aaede266ee0231:en_US , Dewalt Dw618b3 120v 12 Amp 2-1/4 Hp 3 Base Router Kit(97.38, 64180)
# cds|C|6467954|US|en|3c1f05c6ea199c25:en_US , OmniWall Grinder Holder-Black(97.28, 92694)
# cds|C|6467954|US|en|40a94abd6d70afab:en_US , 5-Inch Replacement Pad for Ryobi #300527002, Compatible with Ryobi RS290, RS280/RS280VS, RS281VS, P411 Random Orbit Sander(97.24, 987)
# cds|C|6467954|US|en|98698579641c4f22:en_US , Bucktool Combo 2" x 42" Belt Sander 6" Bench Grinder, Knife Sharpener with Large Work Table BG2600 Upgraded Model(97.22, 46055)
# cds|O|4900386|US|en|1363145 , DeWALT DW 40 ft. Pocket Laser Distance Measurer, DW055PL-Q(97.21, 99819)
# cds|C|6467954|US|en|bf546ecf2860c1a5:en_US , DeWalt Sa Shoe #DWB-605076-00SV(97.12, 35227)
# cds|C|6467954|US|en|17c2ad933af25175:en_US , Pac Strapping Products Bt3920 5/8-Set Strapping Combo Tool,battery,hea(96.98, 55381)
# cds|C|6467954|US|en|8699a774dd961d49:en_US , StrongHand MLA600 Adjustable Angle 6" Magnet(96.77, 28170)
# cds|C|6467954|US|en|52f79d96210f1937:en_US , Unique Truck Accessories UB36-20TD Brute HD Two Drawers Underbody Tool Box(96.71, 53305)
# cds|C|6467954|US|en|b035c9395d8ad978:en_US , CHIEN RONG 1.5 HP Tire Machine Tire Changer Wheel Changers Machine Balancer Rim Clamp Combo 580-680 12"-21" / 12 Month Warranty(96.45, 52490)
# cds|C|6467954|US|en|3f030b2862fb7bc5:en_US , DEWALT 1/2-in 6-in Titanium Twist Drill Bit | DD5132(96.32, 45627)
# cds|C|6467954|US|en|ab676c77739074b2:en_US , Ch-70 Hydraulic Hole Punching 35t Tool Puncher Cfp-800-1 Copper Bar(96.30, 20755)
# cds|C|6467954|US|en|055e7ce0c8b47aa6:en_US , Marshalltown DuraFlex 5 in. W Stainless Steel Finishing Trowel(96.19, 45701)
# cds|C|6467954|US|en|a9502c807e582d17:en_US , General Tools 86014 14 piece Quad Saw/Driver, Size: Various tools, Black(96.00, 49858)
# cds|C|6467954|US|en|3ef5f2236076ddbb:en_US , Marshalltown 6 X 4 3/8 Zinc Groover-1D X 3/8 Bit-DuraSoft Hdl, Product Type Groover, Model 835D(95.78, 25263)
# cds|C|6467954|US|en|bc3abc5ef41bcfbb:en_US , RYOBI 10 in. 40-Volt Lithium-Ion Cordless Pole Saw, 2.0 Ah Battery and Charger Included RY40562VNM(95.74, 19031)
# cds|O|9384133|US|en|CRT36-26A , Husqvarna CRT36-26A Riding Trowel with Wheel Kit(95.66, 28573)
# cds|C|6467954|US|en|2e81c57147398ed8:en_US , DeWalt DCB205-2 20V Max XR 5.0Ah Lithium Ion Battery (2-Pack)(95.57, 70305)
# cds|C|6467954|US|en|7d42022be337fb2b:en_US , DEWALT 20-Volt MAX XR Cordless Brushless Compact Router with (1) 20-Volt Battery 3.0Ah & Charger(95.56, 45060)
# cds|O|110026978|US|en|shopify_US_4621871366_15133376710 , Milwaukee 2676-23 FORCELOGIC M18 10-Ton Knockout Tool 1/2" to 4" Kit(95.55, 77236)
# cds|C|6467954|US|en|7b883ffc6fe1c2c5:en_US , Dremel 1/16 in. Rotary Tool Round-Shaped Engraving Accessory for Wood, Fiberglass, Plastic, Jewelry and Soft Metals (2-Pack)(95.45, 77858)
# cds|C|6467954|US|en|1b39edd268326bb3:en_US , Tru-flate Steel Valve Core Extractor Model: 41-444(95.24, 17865)
# cds|O|7857044|US|en|384492798458 , Vintage 1930s Ford Snap-on Tools 5/8" Drive Socket Ratchet P-4 L72r(95.21, 69380)
# cds|C|6467954|US|en|9ece07cf9dd759a0:en_US , Wera 074716 1.2 Nm Fixed Torque Screwdriver(95.04, 53439)
# cds|C|6467954|US|en|6335388638f4acf0:en_US , Weyland Survival Axe, Beige(94.72, 51867)
# cds|O|513534827|US|en|shoplaza_US_9effa0ce-6e07-460c-8e8f-4d88f6659a93 , Milwaukee 2741-20 M18 FUEL 16GA Straight Finish Nailer Bare Tool(94.70, 47729)
# cds|C|6467954|US|en|7b350d0a57940e5e:en_US , DeWalt Wheel Kit #DWB-5140095-02(94.70, 94422)
# cds|C|6467954|US|en|243860e9224f076f:en_US , 60-piece Master Tap and Die Set - Include Both SAE Inch and Metric Sizes, Coarse and Fine Threads | Essential Threading and Rethreading Tool Kit with(94.66, 41796)
# cds|C|6467954|US|en|5b9ea2384c7d4a8b:en_US , DeWalt | 165 ft Laser Distance Measurer, Black/Yellow - Floor & Decor(94.58, 37520)
# cds|C|6467954|US|en|2641f5cb5b4aa336:en_US , DeWALT 146929-01 Screw(94.58, 53500)
# cds|C|6467954|US|en|113ef1cf9b9d085a:en_US , DEWALT 14/18 TPI Band Saw Blades (3) | DW3986C | Acme Tools(94.48, 88595)
# cds|C|6467954|US|en|4b386c8970f50cab:en_US , Small Size Home Household Wood Working Turning Lathe Multifunction Infinitely Variable Speed Cutting Grinding Drilling Tools, Size: 50, Silver(94.47, 84595)
# cds|C|6467954|US|en|c2470483bb59f554:en_US , Dexter-Russell 6" Curved, Flexible Boning Knife, S131F-6PCP, SANI-Safe Series, White (01493)(94.46, 51910)
# cds|C|6467954|US|en|c0721e836d83a419:en_US , Can Am Defender Hd8 Hd10 Belt Removal Clutch Tool AC-CA-0686-0072(94.31, 62231)
# cds|C|6467954|US|en|b122d3ec8626b60d:en_US , S-21307 Tri-Functional Wide Bushing Adapter Alt(94.20, 30473)
# cds|O|144646454|US|en|06D0520 , Flexcut Whittler's Pocket Knife(94.11, 91045)
# cds|C|6467954|US|en|aa92c42ce6c01338:en_US , Milwaukee Chisel Bit: 1 in Head Wd, 12 in Overall Lg, 45/64 in Shank Dia Model: 48-62-4079(94.05, 98303)
# cds|C|6467954|US|en|d60d423b31f37095:en_US , Jewelry Making Workbench & Tools Set Bench Tools Rotary Tool with Flexible Shaft(93.93, 44642)
# cds|O|2663876|US|en|699472 , Schlage Commercial M204198 Boring Jig for AL or D Series Levers(93.92, 94500)
# cds|C|6467954|US|en|64751edd8b303100:en_US , 9998068 Flywheel Rotating Tool Alt(93.89, 4964)
# cds|C|6467954|US|en|4d37be8502d7d176:en_US , Bosch 12-Pack 5-in Plain High Speed Steel Scroll Saw Blade | SS5-46SPL(93.76, 56325)
# cds|C|6467954|US|en|3bc38a6deaed4269:en_US , Proto JSCV07 7/32 Reversing Combination Ratcheting Spline Wrench #7(93.70, 67329)
# cds|C|6467954|US|en|9a5eb61089b2be10:en_US , 20pcs Carbide turnning Inserts TCMT21.51 TCMT110204 Carbide Insert for Lathe Turning Tool Holder for Steel,Stainless Steel(93.50, 63585)
# cds|C|6467954|US|en|61cd1787729b5841:en_US , BMW E46 330xi M54 3.0L - CTA Tools BMW TDC Pin: Used for finding Top Dead Center when servicing a BMW engine.(93.36, 57276)
# cds|C|6467954|US|en|08b5a4420301cd2d:en_US , Amana Tool 658010-1-R Carbide Tipped R/H Outside Dado Blade 8 Inch D x 24T 1 Inch Bore(93.19, 80449)
# cds|C|6467954|US|en|93a242d254240644:en_US , Surly Jethro Tule, 15mm Socket/Bottle Opener(93.18, 16910)
# cds|C|6467954|US|en|d1e80bfc73072556:en_US , 10" x 80T Freud Industrial Plastic Blade (LU94M010) available at Rockler(92.95, 66051)
# cds|C|6467954|US|en|58d9a40a68282d82:en_US , Jonard Tools Ast-200 Cable Saber - Armored Mid-Span Cable Slit & Ring(92.37, 67060)
# cds|C|6467954|US|en|c9373492a965ec15:en_US , Parker 3/4" Max Cut Diam, 30 Ton Portable Hose Crimper - 30 sec Cycle, 12" Wide x 15" High x 6" Deep | Part #94C-002-PFD(92.36, 68072)
# cds|C|6467954|US|en|5cf95517d0495d14:en_US , Grip On 7" Axial Grip "l" Plier (epoxy) Gr91207(92.30, 17651)
# cds|C|6467954|US|en|48f79f5aac15625d:en_US , Goldengulf 16pcs/Pack Pretend Play Mini Construction Hardware Tool Keychain Toy Gift Assorted Designs DIY Creative Tool Car Keyring(92.14, 80417)
# cds|C|6467954|US|en|7923c1693d251e46:en_US , Pittsburgh 5-3/4 in. Needle Nose Pliers(92.12, 44988)
# cds|O|291426434|US|en|18053417629526042552622204 , Best Seller Milwaukee M18 FUEL 18-Volt Lithium-Ion Brushless Cordless Gen II 18-Gauge Brad Nailer (Tool-Only)(92.07, 28338)
# cds|C|6467954|US|en|bc9fa2ca686e6044:en_US , Kennedy 2600B Tool Chest Riser(91.68, 56909)
# cds|C|6467954|US|en|c2fa0b6eba306bbe:en_US , Biltwell EXFIL-0 Tool Roll(91.31, 69681)
# cds|O|241667459|US|en|DKK-TG70-SK , Japanese Boning Knife 7" - KYOKU Shogun Series(90.98, 78709)
# cds|C|6467954|US|en|cf740c4aedc38539:en_US , m18 X 1.5 HSS Plug Tap and 16.50mm HSS Drill Bit Kit, Qualtech(90.91, 87637)
# cds|C|6467954|US|en|b50c06247865c887:en_US , Makita XCU08Z | 18V X2 (36V) LXT Lithium-Ion Brushless Cordless 14" Top Handle Chainsaw (Tool Only) | Tyler Tool(90.89, 33629)
# cds|C|6467954|US|en|93eae9234f8e7cd2:en_US , Marshalltown Funny Trowel Adapter-Swivel, Product Type Adapters + Brackets, Model 4826(90.65, 62874)
# cds|O|8439803|US|en|100-036 , Leigh D4R+D24 Master Pack(90.56, 17078)
# cds|C|6467954|US|en|32e9b7d475d75be9:en_US , Neiko 02448A 1/2" Drive Master Impact Socket Set, 65 Piece Deep & Shallow Socket Assortment | Standard SAE (3/8-Inch to 1-1/4-Inch) and Metric (10-24(90.10, 38530)
# cds|C|6467954|US|en|d124ea296b236fa5:en_US , DeWalt OEM 5140103-20 replacement band saw tire DCS370 DCS371(90.07, 36496)
# cds|C|6467954|US|en|7fe04b73f739e2bb:en_US , Kitchenaid Food Grinder Blade 2 Pack, Ap5669553, Ps6883726, Wpw10408733(90.05, 65325)
# cds|C|6467954|US|en|5c09c214f6170ba6:en_US , Ryobi 10" Orbital Buffer- In Box Never Opened(89.55, 45755)
# ...
# cds|C|6467954|US|en|310edf1e908335ec:en_US , CLC 1 pocket Leather Hammer Holder 3.9 in. L X 5.8 in. H Tan(12.29, 33268)
# cds|C|6467954|US|en|5401da23d83fa81a:en_US , Ableware Raptor Reacher(11.96, 69863)
# cds|C|6467954|US|en|bf20c6fbd56cc5ca:en_US , Landscape Rake Independence Series(11.94, 99661)
# cds|C|6467954|US|en|26039131e4734a25:en_US , Milwaukee 4932464080 Packout Box 3 Toolbox System ( 2 X Boxes )(11.91, 36704)
# cds|C|6467954|US|en|547711c16f453b72:en_US , STREBITO Precision Screwdriver Set 124-Piece Electronics Tool Kit with 101 Bits Magnetic Screwdriver Set for Computer, Laptop, Cell Phone, PC,(11.88, 66019)
# cds|C|6467954|US|en|c7acc34713fd709a:en_US , StealthMounts EGO Battery Holders | Cordless Ego Power+ Battery Mounts | 4 Pack | EGO Power Plus Battery Organizers(11.85, 24951)
# cds|C|6467954|US|en|5d6d7bbf5e2a79bd:en_US , mkki 4" 100mm Angle Grinder Wall Bracket Tool Hook Holder Stand for 1-4 Angle Grinders(11.84, 6317)
# cds|O|10776|US|en|B1308792 , Import 5C Rotating Indexing Fixture(11.72, 5812)
# cds|O|388792255|US|en|US1920-02_2 , Jardineer 2" Anvil Loppers Shears - Gardening Loppers Heavy Duty with Garden Shears & Spare Blade, Effortless Pruning Tree Loppers(11.64, 1774)
# cds|C|6467954|US|en|e9fb7cea635012e6:en_US , Sp Scienceware Tapered Plug Sampler Model: H37826-0000(11.54, 19006)
# cds|C|6467954|US|en|f3d1472e46ab8590:en_US , EGO Power+ ST1620T 16 in. Battery String Trimmer Tool Only(11.51, 9685)
# cds|C|6467954|US|en|9307d42b07e68caf:en_US , Pieces be with you, Grande Groovin Piping Trimming Tool(11.48, 18399)
# cds|C|6467954|US|en|c8323635969c6540:en_US , Magnepull XR1000 Magnespot Reference Point Locator Kit(11.39, 94025)
# cds|C|6467954|US|en|84223e7b24d18616:en_US , Kings County Tools Traditional Maddock 2-in-1 Garden Tool | Hoe and Axe Combo | 42 Ash Handle | Carbon Steel Heads | German-Made Quality(11.37, 32401)
# cds|C|6467954|US|en|bb884f8cf35c80d4:en_US , Sunrise Commercial Grade Wok Shovel 16.75 inch (#3) & Ladle 16.75 inch (#3)) Set, Size: #3 (16.75 Large), Silver(11.36, 71424)
# cds|C|6467954|US|en|88734aafe587abb1:en_US , Norton 1/2 X 2 X 6 In. 3-In-1 Tool & Knife Sharpening System(11.36, 38024)
# cds|C|6467954|US|en|a29cd18661e2d0aa:en_US , HITACHI DH38YE2 Rotary Hammer, 120 V, 950 W, 1-1/2 in Chuck, Keyless Chuck, Black/Green/Silver(11.31, 29144)
# cds|C|6467954|US|en|2aa2347bf696c886:en_US , BOSCH RH540M 1-9/16" SDS-max Combination Hammer by FastoolNow(11.29, 38742)
# cds|C|6467954|US|en|15d63793318be18d:en_US , Fein 92035060090 Turbo I Wet / Dry Dust Extractor Set(11.23, 99106)
# cds|O|441318628|US|en|TOOLTOTEBLK , 8" X 8" HD Tool Tote Black(11.21, 59041)
# cds|C|6467954|US|en|2872191e882e978b:en_US , WHDZ Paintless Dent Repair Rods Auto Body Dent Removal Tools 10pcs Auto Car Body Paintless Dent Repair Dent Puller Dent Hammer Tap Down(11.14, 46283)
# cds|O|132533|US|en|154921 , Ryobi 030157001013 Bearing Cap Assembly(11.14, 45763)
# cds|C|6467954|US|en|bf4a88d28cd20651:en_US , Klein 200028EINS Insulated Slim-Handle Diagonal Cutting Pliers(11.10, 63086)
# cds|C|6467954|US|en|69b1c68ea897d6d1:en_US , Bosch 25618-02 18 Volt Li-ion 1/4-hex Cordless 18v Impact Driver Kit(11.10, 47219)
# cds|C|6467954|US|en|c234b6f1da492616:en_US , Rack'em RA7 6-Hook Multi Tool Rack(11.06, 88790)
# cds|C|6467954|US|en|a61ec890abe7656e:en_US , Hose Removal Hook Pick Set, 10" Hose Hook, 8" Hose Remover, Hose Puller Tool for Radiator Hoses, VASTOOLS(11.04, 39231)
# cds|C|6467954|US|en|ac203052d66e7fc1:en_US , Snapper XD 82V MAX Cultivator Attachment with Adjustable Tilling Width, Compatible with Snapper XD String Trimmer(10.97, 31085)
# cds|O|9769319|US|en|lr3460 , Corona Long Reach Cut and Hold Pruner LR 3460(10.88, 42232)
# cds|O|130220265|US|en|shopify_US_6836339146928_40417273381040 , Gate Remover Set(10.86, 92061)
# cds|C|6467954|US|en|7367e101cbc5b2e9:en_US , Pull Start Recoil Carburetor Set Replacement for Predator 212cc 6.5hp OHV Engine(10.79, 22617)
# cds|C|6467954|US|en|5d14d3c597cffe3e:en_US , 1pc Gundlach 611 Lil Squeezy Carpet Stretcher(10.77, 18448)
# cds|C|6467954|US|en|5093ca490b5d3389:en_US , Room & Board | Modern Roan Wall-Mounted Magnetic Knife Holder . in Slate Blue 20w .5d 3h(10.74, 52746)
# cds|O|142087827|US|en|shopify_US_6119626342553_37947389771929 , Mr. Fix It Tool Bouquet | Gift Idea for Dad, Husband, Boyfriend(10.71, 78962)
# cds|O|6421244|US|en|120803307782 , 21 Pc Eye Micro Minor Surgery Surgical Opthalmic Instrument Student(10.67, 33769)
# cds|C|6467954|US|en|2660c97c606b82ef:en_US , Jonas of Sweden 38404 Adult Red Plastic Comb Berry Picker - 8 1/2" x 5 1/2"(10.64, 8122)
# cds|O|114711376|US|en|192468736507 , Milwaukee 48-22-1920 Duct Knife, Full Tang, Double Edged Blade ( Lot(10.58, 21078)
# cds|C|6467954|US|en|1270a5d788cca965:en_US , Milwaukee 48-22-2706 Screwdriver Kit, 6-Piece(10.55, 52867)
# cds|O|6296724|US|en|393546869690 , Dental Tool 10 Pack Professional Plaque Remover Teeth Cleaning Tool(10.52, 71714)
# cds|C|6467954|US|en|de18230a6182d6a7:en_US , Dead Ringer Arrow Puller(10.46, 37327)
# cds|C|6467954|US|en|4525d347eea17c21:en_US , LifeLine Home Mechanic Workstand inc. Mat - Gold(10.38, 49041)
# cds|C|6467954|US|en|069eced4660dee3a:en_US , Blue Sea 8293 Contura Actuator Removal Tool(10.37, 18182)
# cds|C|6467954|US|en|8b5475ce0519eda7:en_US , Klein Tools Tool Pouches, 11 Compartment, Black, Leather, Belt Slot, 1/EA, #5167 | AFT Fasteners(10.31, 24815)
# cds|C|6467954|US|en|bc621e5eeae6204c:en_US , Monteverde Tool 0.9mm Pencil - Brass(10.23, 16538)
# cds|C|6467954|US|en|b1748dc05bf1aefa:en_US , Bambu Wok Spatula(10.22, 99234)
# cds|C|6467954|US|en|fe6fb6f7199a5969:en_US , Cuda Universal Lanyards, 2-Pack | For Fishing(10.16, 38245)
# cds|C|6467954|US|en|b7f2fce5417ae9f1:en_US , Fiskar Paper Crimper Tool, #9340, Fits Paper 6.5" Wide, Wavy Paper(10.12, 60901)
# cds|C|6467954|US|en|21fc81882ea48107:en_US , Center Pin Punch Automatic Center Strike Spring Loaded Window Breaker Drilling Marking Tool, Black, without Cap, Size: 130 mm(10.11, 83992)
# cds|O|501595024|US|en|shopify_US_5111236526213_34416780247173 , Extreme Reamer X-Large(10.08, 35099)
# cds|C|6467954|US|en|5d22502cb0f6f29c:en_US , The Pocket Scientist - Wallet Science Ruler Scale and Unit Conversion Reference 3 inch(9.99, 31938)
# cds|O|117171671|US|en|690401552 , Channellock 430 Plier Holder(9.98, 52263)
# cds|O|127676668|US|en|95-362-Pack-of-1 , Sklar Surgi-OR Vaginal Speculum Pederson NonSterile Mid Grade Stainless Steel Large Double Blade Duckbill Reusable Without Light Source Capability -(9.98, 79535)
# cds|C|6467954|US|en|8869d898225b16bd:en_US , Spanner Nut Tamper-Proof Security Screwdriver(9.98, 32309)
# cds|C|6467954|US|en|94370ad8fb930b8d:en_US , Silicon Carbide Flexible Cylinder Hone, Coarse Grade, 120 Grit(9.93, 8047)
# cds|O|258354524|US|en|LCLAMP8511 , Precision Clamping Squares 90 Degree Right Angle Clamps(9.89, 66752)
# cds|C|6467954|US|en|a7a32cdde23a54b9:en_US , Estes 302227 Tube Marking Guide(9.88, 51512)
# cds|C|6467954|US|en|7341f5cf688ffd73:en_US , Bartender's Hammered Solid Copper Cocktail Shaker Set(9.86, 84503)
# cds|O|11022734|US|en|223300521187-MTY1-155-903 , 155-903-Telescoping Gage Set SERIES 155 (MITUTOYO) | Misumi(9.84, 46037)
# cds|C|6467954|US|en|83484922d810747e:en_US , Omc Johnson Evinrude Outboard Needle Bearing Grease Assembly Lube(9.79, 56351)
# cds|C|6467954|US|en|89b39e3e03590be2:en_US , Mag-Mate Tplp30 Magnetic Part Handler,2.48Inhx3Inlx3Inw(9.77, 2100)
# cds|O|7654024|US|en|shopify_US_313208609_32077187252273 , Sure Design Thai Wooden Massage Tool 03 1-Size / Wood(9.73, 86094)
# cds|C|6467954|US|en|d9864f36aabb52e8:en_US , CNCEST High Quality Portable Fiber Optic Tools Kits-18PCS(9.69, 93022)
# cds|O|8760422|US|en|shopify_US_6999980081333_41989116100789 , Fire Hose Spanner Wrench (2-Pack)(9.68, 69248)
# cds|C|6467954|US|en|1252d54b9fcf668b:en_US , Solo 200 Alarm & Detector Removal Tool, Flat or Angled Ceilings(9.68, 74277)
# cds|C|6467954|US|en|608005b02c8b3c2a:en_US , Jims USA Compensator Nut Torx Socket Harley Davidson FLRT Freewheeler 2015-2016(9.62, 74820)
# cds|C|6467954|US|en|a75b993e31a6f776:en_US , Adjustable Operating Wrench, 60 to 108 in(9.57, 90333)
# cds|C|6467954|US|en|d85b3a670da004b6:en_US , 80C-A16 - PARKER(9.55, 784)
# cds|O|115809258|US|en|RDI36 , 36" Double Bend Interchangeable Tip Rod(9.52, 84262)
# cds|C|6467954|US|en|ce418631b43fe03e:en_US , HHIP 3129-0015 1/2 Inch Shank Knee Feed Adapter for Power Drill(9.45, 53284)
# cds|O|138357567|US|en|403076218402 , Lathe Vertical Milling Slide Attachment Fixed Base Myford 7 Series(9.37, 87842)
# cds|C|6467954|US|en|6337dcd82cc48568:en_US , Dino-Lite MS23B Articulating Flex-arm Clamp, Designed for Dino-Lite(9.37, 19928)
# cds|C|6467954|US|en|ffd777bce430be3d:en_US , Yiranok HVAC Tools - Copper Tube Expander for Air Conditioner and Heater Equipment - Pipe Swaging Tool Hand Drill Accessories - 1/4'', 3/8'', 1/2'',(9.31, 55253)
# cds|O|11349283|US|en|AM-Z-010 , Tornador Professional Cleaning Tools Tornador Classic Z-010(9.26, 83120)
# cds|O|299611441|US|en|121957 , Deluxe Rivet Cutter Deluxe Rivet Cutter(9.15, 10901)
# cds|C|6467954|US|en|f2edf1aaef7d8d03:en_US , QEP 29185114 Laminate/Wood Floor Installation Kit(9.08, 70070)
# cds|O|3768652|US|en|TTT-XXL-MCT , Veto Pro Pac TP-XXL Meter Pouch and TECH-MCT Tool Bag Combo(9.06, 38550)
# cds|C|6467954|US|en|1516bae824d60b22:en_US , Firstline Evolve Loc & Twist Starter Kit(8.98, 1268)
# cds|O|8049|US|en|42242 , Klutch 2Inch Non-Woven Abrasive Pads — 4-Pack, with 1/4Inch Round Shaft Quick Connector(8.94, 26064)
# cds|C|6467954|US|en|0c29d8b693de5318:en_US , Bon 12-357 Dirt Tamper - 10 inch X 10 inch - 48 inch Wooden Handle(8.93, 3212)
# cds|O|4159258|US|en|tl0008 , Piercing tool Kit with essential tools to pierce with Leather case Made of Surgical Steel(8.93, 8383)
# cds|O|113677249|US|en|473919541694_174740468518 , Flexible Head Metric Tubing Ratchet Wrench Repair Tool Open End(8.92, 35671)
# cds|C|6467954|US|en|4b1dcd3fd068d7f1:en_US , Occidental Leather 8068 Impact, screwgun and Drill Bag(8.91, 6215)
# cds|C|6467954|US|en|1cb9127a937e5c00:en_US , TapeTech QuickBox QSX 6.5" Finishing Box(8.89, 79619)
# cds|C|6467954|US|en|c412b73e1125629f:en_US , VEVOR Tire Dolly Wheel Dolly 300 Lbs Capacity Truck Tire Wheel Dolly Heavy Duty Cart(8.87, 25967)
# cds|C|6467954|US|en|83993ae52c10297f:en_US , Rockler Dixon Reach Deep-Hole Mechanical Pencil with 12-Pack Lead Refills(8.86, 96216)
# cds|C|6467954|US|en|d181c61f00d3ea46:en_US , Sorby Scraper, Box - Woodcraft(8.86, 72374)
# cds|C|6467954|US|en|a0fff59b946f1ee4:en_US , black decker rtx-1 rotary tool for 220 volts(8.86, 10824)
# cds|C|6467954|US|en|3fddd6b8adef041a:en_US , Latauar Croissant Cutter, Stainless Steel Croissant Roller Slices with Wooden Handle Perfect Shaped Pastry Dough, Rolling Knife Kitchen Baking Tool.(8.86, 22650)
# cds|C|6467954|US|en|32db9c77f3dd6713:en_US , Music Nomad MN610 Neck Relief Kit Taylor Guitars(8.85, 30287)
# cds|O|522529553|US|en|402814332981 , Vinyl Lp Turntable Alignment Protractor Tool For Record Player(8.85, 89321)
# cds|C|6467954|US|en|a7946bbbf24d78f3:en_US , Gerber Gear Processor - Salt Scissors in Steel(8.84, 26005)
# cds|C|6467954|US|en|40282cfe8a1386e7:en_US , Garage Hooks, 19 Pack Heavy Duty Garage Storage Hooks Steel Tool Hangers for Garage Wall Mount Utility Hooks and Hangers with Anti-Slip Coating for(8.81, 96523)
# cds|C|6467954|US|en|906a1df4295dc778:en_US , CRAFTSMAN Plastic Socket Storage in Black | CMMT99415(8.78, 23358)
# cds|C|6467954|US|en|1d875539e7dd23e1:en_US , Starrett Gauge Rod - 6 in Length - 1/4 in Wide - 657X(8.72, 18899)
# cds|C|6467954|US|en|9bc53e0a912b7c74:en_US , CASOMAN 5/8" Swivel Magnetic Spark Plug Socket, 3/8" Drive x 8-Inch Ext. Bar Length, 360 Degree Swivel, Enhanced Magnetic Design, 6 Point, Cr-V Steel(8.70, 54609)
# cds|C|6467954|US|en|1d06046abf018c19:en_US , Dewalt 8 ft 500 lb Load Capacity Fiberglass Stepladder Model: DXL3810-08(8.68, 52686)
# cds|C|6467954|US|en|696a73a7bb666e8b:en_US , 4 Way Wood Rasp File, Premium Grade High Carbon Hand File and Round Rasp, Half Round Flat & Needle Files. Best Wood Rasp Set for Sharping Wood and(8.65, 78064)
# cds|C|6467954|US|en|2ef16cd04f317757:en_US , SUNEX TOOLS Sunex 1889 1/4 in., 3/8 in., and 1/2 in. Drive SAE and Metric Master Chrome Socket Set (89-Piece)(8.64, 51452)
# cds|C|6467954|US|en|6551d543424e4a4e:en_US , Aurand - KP5V Pneumatic 5" Surface Scaler, Vac(8.63, 79333)
# cds|C|6467954|US|en|67cefd2e03b5524a:en_US , Make Your Own Kitchen Tools: Simple Woodworking Projects for Everyday Use by Picciuto, David - Alibris Books, Music & Movies(8.56, 37868)
# cds|O|259719927|US|en|shopify_US_4390334103630_31625600106574 , Spring Steel Gripper Clip - Half Vinyl Coated - 3/4"-1 1/8 (#225-HL) 25 pcs(8.48, 35688)
# cds|C|6467954|US|en|d519e5cae30aa58d:en_US , Stanley Jr. Pull-Back Airplane Kit(8.48, 76509)
# cds|C|6467954|US|en|53d8015f30b5ed56:en_US , Anytime Tools Angle Block Set 1°, 2°, 3°, 4°, 5°, 10°, 15°, 20°, 25°, 30° Precision +/- 20 Seconds, Machinist Tool, 10 Piece Set(8.47, 87448)
# cds|O|101640084|US|en|194233254342 , Lego Gray Brick Separator Vintage, Great Condition(8.44, 37119)
# cds|O|100572154|US|en|082-BE400 , E-Z Trench EZ Trench BE400 Bedscaper Bed Edger 6.5HP Honda Engine(8.37, 38086)
# cds|C|6467954|US|en|a049dee08b783ffe:en_US , Tweezerman Blackhead Extractor(8.34, 64331)
# cds|C|6467954|US|en|bf99b0906a1a437b:en_US , Milwaukee 48-22-8271 Heavy Duty Canvas Utility Bucket w/ 75 lbs Weight Capacity(8.31, 4861)
# cds|C|6467954|US|en|9a2dbefe9e6b86bd:en_US , Autel TPMS Relearn Tool TS408, 2022 Upgraded of Autel MaxiTPMS TS401, Tire Pressure Monitor Sensor Programming and Rest Tool for All Cars, TPMS(8.29, 55784)
# cds|C|6467954|US|en|79e957ba32392eb3:en_US , ToolkitRC M6D 500W 25A 1-6S Dual Channel DC Smart Charger(8.24, 24238)
# cds|C|6467954|US|en|c9a19a7bcd839026:en_US , Roberts 10-28 Flooring Installation Kit Flooring Install Kit 4 Boxes(8.21, 66363)
# cds|C|6467954|US|en|b9b62e8d0b23b697:en_US , 1210 Semi Trailer Air Brake Testing Tool(8.20, 82136)
# cds|O|487168117|US|en|shopify_US_7146485186729_41048967872681 , Golf Club Groove Sharpener, Re-Grooving Tool and Cleaner for Wedges & Irons(8.19, 70295)
# cds|O|128026611|US|en|HRP24BH-HA-RP24 , Rock Picks - 24oz Hammer - Carbide Bushing Head & Blade - 12in (30cm) Wood Handle(8.12, 36984)
# cds|O|8156927|US|en|98NHO26-1 , Mayo Hegar Needle Holder, 5", Economy - Needle Holders(8.09, 44337)
# cds|C|6467954|US|en|8c2ecba89fbf3d91:en_US , Westward Screw Extractor: Spiral Flute, 17/32 in Drill Size, For 1" to 1-3/8" Bolt Size Model: 2RUP5(8.09, 10628)
# cds|C|6467954|US|en|763aa1658f3fb254:en_US , 4-inch Molding Flap Sanding Wheel Kit For Drill Press, Pack Of 3, 80, 120, 240 Grit(8.07, 66058)
# cds|C|6467954|US|en|6d3040c5f8ffcfbf:en_US , TRU TENSION MEGA TOOL BUNDLE 19 - 59-2806(7.96, 69613)
# cds|C|6467954|US|en|19f2b964884de27b:en_US , Zircon MT7 Metalliscanner - Metal Scanner Detector Locator Zircon(7.95, 63079)
# cds|C|6467954|US|en|59f2603247de0781:en_US , Freeman P2PFK14 Professional Pneumatic Flooring Nailer Kit with Fasteners (2-Piece) L-Cleat Flooring Nailer, 4-in-1 Mini Flooring Nailer and Stapler(7.95, 93460)
# cds|O|242947|US|en|406-62006 , Tanner Racing Products 62006 AN Wrench -6AN (11/16")(7.93, 91429)
# cds|C|6467954|US|en|177533965f56bb8a:en_US , Zurn Z1180-2IP Solids Interceptor, 15gpm (2-inch Inlet/Outlet)(7.93, 57049)
# cds|C|6467954|US|en|dab210c273bd9b23:en_US , Sioux Tools 1/4" Capacity, Air Riveting Hammer - 8 CFM, 4" Long Stroke, 1/4 NPT Inlet | Part #270A-4(7.92, 46839)
# cds|O|285493498|US|en|5f6aaec6b475e90049e01b01 , Facial Hair Remover Hair Spring Threading Epilator Lip Eyebrows Smooth Removal(7.89, 47789)
# cds|C|6467954|US|en|61f4d4de0de2b0bd:en_US , Corner Rounder Mini Punch Set - EK Success - Punches(7.89, 31986)
# cds|C|6467954|US|en|991e3780ea3026be:en_US , Toledo Pipe 42360 1206 Stand fits RIDGID 41855 300 Power Drive(7.89, 46033)
# cds|C|6467954|US|en|34faf1273caed3f8:en_US , Foundation | Bench/Wall Mount Repair Stand 360 Rotation, Bench or Wall Mounting(7.89, 86315)

# %%
print(get_text(A_init.shape[0]-2, Y, temp, sep='\n'))
# Out:
# 1023 :
# cds|O|469769397|US|en|947935433 , 10 pack Dewalt 20v tool Holder BLACK / YELLOW(194.29, 68248)
# cds|C|6467954|US|en|436b92c3ff8f5c1d:en_US , KD Tools 3624 2- Ton Ratcheting Puller | Auto Tool World(185.39, 77691)
# cds|C|6467954|US|en|5bfa797477184b6a:en_US , RYOBI ONE+ 18V Cordless 10-Tool Combo Kit w/ 3 Batteries, Charger, LINK Rolling Tool Box, Standard Tool Box, & Medium Tool Box(183.24, 74261)
# cds|C|6467954|US|en|ff335312e0391692:en_US , GEARWRENCH 2 Ton 3-1/2 in. 2 or 3 Jaw Reversible Internal/External Pullers(182.57, 35517)
# cds|C|6467954|US|en|1622d5226c19773b:en_US , Apollo Precision Tools Dt0204 71-Piece Household Tool Kit(182.04, 10677)
# cds|C|6467954|US|en|ed4050bc8420b610:en_US , DEWALT 1/4 in. and 3/8 in. Drive Mechanics Tool Set with Toughsystem Trays (131-Piece)(181.91, 36722)
# cds|C|6467954|US|en|f9ee5a3fab800928:en_US , ONE+ 18V Cordless MultiTool with 2.0 Ah Battery and Charger P343B-PSK005(181.76, 5009)
# cds|C|6467954|US|en|029398d94249a971:en_US , DEWALT 20-Volt MAX Cordless Died Cable Crimping Tool with (2) 20-Volt 4.0Ah Batteries, Charger & Case(179.74, 68525)
# cds|O|5817554|US|en|40-C2243 , Spear removing / Opening Demounting Tool for Sankey D & S System(176.36, 71468)
# cds|C|6467954|US|en|0da211e28778f133:en_US , Hart 5-piece Multi-tool Blade Set For Wood, Metal, Drywall, Grout 1686(176.05, 41106)
# cds|C|6467954|US|en|a8feb1df9d829ecb:en_US , Master Appliance 35084 SAE 22 to 10 AWG Ratcheting Master Full Cycle Terminal Crimper(175.58, 82905)
# cds|C|6467954|US|en|ca670dd2f3755cdf:en_US , JobSmart Fence Tool with Hammer, JS2017102(172.82, 12627)
# cds|C|6467954|US|en|13884596639ffc68:en_US , Paladin Tools PA1389 1300 HDTV Universal Crimp Tool with Die(168.33, 79506)
# cds|C|6467954|US|en|8084d2ff1b8bdcdf:en_US , Klein Tool Nylon Tie Tensioning Tool with Auto-Cutoff(166.17, 9763)
# cds|C|6467954|US|en|d2fed5039c1b6142:en_US , Ideal 30-3429 Smart-Grip Multi-Crimp Tool(165.38, 74622)
# cds|C|6467954|US|en|4b7404bbbb468ae2:en_US , Crescent 193610CVSMN 10" Heavy Duty Fence Tool(163.59, 16633)
# cds|C|6467954|US|en|5bb3553386b6f8d1:en_US , Makita HB350 1-3/8 in. 10 Amp Corded Magnetic Drill(163.11, 88114)
# cds|O|6296724|US|en|114369497614 , E5 Quick Change Tool Post For 200-400mm Lathe 8"-16" Multifix E(162.71, 61126)
# cds|O|132533|US|en|156443 , Ryobi 039028007054 Auxiliary Handle(162.69, 72170)
# cds|C|6467954|US|en|82b285826a327c15:en_US , DEWALT 22 oz. Steel Framing Hammer(162.02, 11524)
# cds|C|6467954|US|en|277ef016cf908523:en_US , Milwaukee Oscillating Tool Blade: 1 3/8 in Blade Wd, 1 1/2 in Blade Lg, Straight Cutting, 1 Pieces, Milwaukee Model: 49-25-1501(161.51, 83244)
# cds|C|6467954|US|en|e48ed360dc1f5488:en_US , DEWALT 20-Volt MAX XR Li-Ion Cordless Brushless Drill/Impact Combo Kit (2-Tool) w/ 20-V Brushless 6-1/2 in. Circ Saw(Tool-Only)(160.63, 51918)
# cds|C|6467954|US|en|f5f34c2c07c26f2f:en_US , DeWalt N435687 Belt Hook Clip Kit for DCF620 DCF620B DCF622 Drywall Screwgun(160.33, 74286)
# cds|O|8949|US|en|8608889 , Gardener's Lifetime Long T-handle Lawn Edger(159.55, 98609)
# cds|C|6467954|US|en|c83e5a192bf6670c:en_US , Dyson Dc40 Dc41 Dc65 Combination Tool 920753-01, Gray(157.93, 53042)
# cds|C|6467954|US|en|4499e48385ddb500:en_US , DeWalt 5140001-90 Outer Flange(156.84, 65583)
# cds|C|6467954|US|en|3a3da43ebe90c686:en_US , Bones Bearing Puller Tool(156.28, 74927)
# cds|C|6467954|US|en|2eb5e8e74fc0c7ea:en_US , AJC Shingle Slate Ripper(156.26, 44931)
# cds|C|6467954|US|en|5f63deb4f5691d85:en_US , DeWalt TStak Flat Top Organizer Storage Box DWST17807(155.63, 26466)
# cds|C|6467954|US|en|f9776255608ff34e:en_US , PSI Woodworking CLTSET58 Straight Bar 3pc Toolrest Set, 5/8" Diameter Post (15.875mm)(155.34, 78752)
# cds|C|6467954|US|en|123f685194cbc2bc:en_US , FEIN Cordless Multimaster 12V AMM 300 PLUS Start(155.26, 48647)
# cds|O|8969059|US|en|LL-U10601 , UtiliCarryWallet 11-In-1 Multi-Tool (1/CD) -by Lucky Line(153.69, 51741)
# cds|O|469769397|US|en|934658362 , 10 pack Craftsman 20v 20 Volt Max Tool holder Tool Mount Tool Hanger(153.40, 8347)
# cds|O|8927679|US|en|801800 , Stainless Steel Garden Pocket Tool(153.16, 37227)
# cds|C|6467954|US|en|f0062157a252c52f:en_US , Astro Pneumatic 9589 4 Pc. Door Panel & Upholstery Tool Set by National Tool Warehouse(153.13, 62373)
# cds|C|6467954|US|en|e8e5b5f751a94a30:en_US , 16 Wrench Holder Organizer Storage Rack Tray Toolbox Sorter Wall JSP Brand (Red)(150.86, 23567)
# cds|C|6467954|US|en|1829c5b07e22ce7c:en_US , Vevor Magnetic Drill Magnetic Base Drill 750w Mag Drill 0.5" Max Boring Diameter(150.74, 44366)
# cds|C|6467954|US|en|0862569a899f683a:en_US , CALIDAKA Saw Slot Adjuster Mortise and Tenon Tool Movable Measuring Block Making Seam Adjustment Controller Table Woodworking Tool Mortise Measuring(150.63, 24134)
# cds|C|6467954|US|en|8611375503ffec67:en_US , Dewalt DWE4997NVS 2-inch (50mm) Brushless Variable Speed Paddle Switch Die Grinder w/ No Lock-On(150.34, 19014)
# cds|O|101702933|US|en|254359212372 , Snap-on Gmtk General Mechanic's Maintenance Military Tool Set Kit 8(150.31, 95506)
# cds|C|6467954|US|en|19fc3d124e04bfb2:en_US , Bearing Packer - Plastic PTW1218(150.24, 35625)
# cds|C|6467954|US|en|ac29922143886fde:en_US , RYOBI ONE+ 18V Cordless 2-Tool Combo Kit W/ Drill/Driver, Circ Saw, (2) Batteries, Charger, Bag, & Drill/Drive Kit (40-Piece) power tool set, power(149.83, 76267)
# cds|C|6467954|US|en|295fc0f960cdd9d9:en_US , 2 Pieces Automatic Rebar Tie Wire Twister, Rebar Tie Wire Twister Tool, Rebar Wire Twister Pull Tie Wire Twister, Concrete Metal Wire Twisting Fence(149.39, 12054)
# cds|C|6467954|US|en|87192eef21c738ee:en_US , Essentials Purple Floral Garden Hand Tools Set with Cultivator, Trowel, Pruner and Bonus Gloves, Size: Trowel-10.63 inch x 2.95 inch x 1.3 inch ;(149.17, 88804)
# cds|C|6467954|US|en|4f32ba3060b3fd5e:en_US , Xcelite Tca100Stn General Hand Tool Kit,no. Of Pcs. 89(149.08, 61221)
# cds|C|6467954|US|en|614f8afeba197cd0:en_US , Dynamite T1107 Dynamite Ultimate E-clip Tool 1.5mm-5mm(148.23, 35717)
# cds|C|6467954|US|en|7b4f7ee9ed77739e:en_US , ROCKWELL Sonicrafter Carbide Grit Rasp | RW8924(147.28, 23941)
# cds|C|6467954|US|en|feae634b66ec8905:en_US , Gerber SUSPENSION-NXT multi-tool(147.19, 64727)
# cds|C|6467954|US|en|4c6bff95c5d451fc:en_US , 63 inch Adjustable Garden Rake for Leaf - Collect Loose Debris Among Delicate Plants Lawns and Yards Best Expandable Head rake for Leaves Small to(146.64, 26213)
# cds|C|6467954|US|en|3db5520fa71bfff4:en_US , Ken-tool Lock Ring Remover,30 In,11/16 In Stk,Stl Model: 33223(145.65, 92380)
# cds|C|6467954|US|en|3149cd9383f45333:en_US , Tool Holder Magnetic Panel Carlyle Tools(144.72, 84291)
# cds|C|6467954|US|en|c889e00a8757dee8:en_US , Ryobi 18-Volt One+ Cordless 5-Tool Combo Kit with (2) 1.5 Ah Compact Lithium-Ion Batteries, Charger, and Bag(144.63, 96301)
# cds|C|6467954|US|en|35ded39bc0802ba4:en_US , OEM Tools 27119 Bearing Race Installer Set(144.05, 74663)
# cds|C|6467954|US|en|9e4069c5d9e555e9:en_US , Longacre 78295 Digital C/C Gauge w/AccuLevel & Quick Set Adapter(143.58, 10840)
# cds|O|6020949|US|en|cp-26pc-tl-kt%2B965833 , Design Your Own 26 Piece Deluxe Home Tool Kit(143.58, 4120)
# cds|C|6467954|US|en|b3e4ad9d60e66b66:en_US , Ace 2-1/2 in. W Steel Stiff Paint Scraper(143.52, 96062)
# cds|C|6467954|US|en|caba7f034664f752:en_US , Eaton Fuller Transmission Countershaft Front Bearing Puller RR1012TR-3 - Oni Tools(143.11, 87568)
# cds|O|10900|US|en|191200 , Ferrule Blaster Ferrule Puller(142.72, 27234)
# cds|C|6467954|US|en|450756d910dd42a7:en_US , Warrior 2 Amp Variable Speed Oscillating Multi-Tool(142.71, 97974)
# cds|C|6467954|US|en|4bea0648624f7051:en_US , DEWALT 20-Volt MAX Cordless 4-1/2 in. to 5 in. Grinder with (25) Metal and Stainless Cutting Wheels DCG412BW8062W25(142.41, 1137)
# cds|C|6467954|US|en|42f7b5399e9d160a:en_US , RYOBI Impact Rated Driving Kit With (8-pc) with Impact Rated Driving Kit (70-pc)(142.41, 64709)
# cds|C|6467954|US|en|13a3485e292476d2:en_US , RDX Carbide Tool Grinder(142.06, 94857)
# cds|C|6467954|US|en|6a794c2f73fbd298:en_US , Saker Deburring Tool Pro-Deburring Drill Bit,Deburring Tool for Metal,Remove Burr Steel Tools Quick Release Shank Fits 1/8' (3mm) to 3/4' (19mm)(141.70, 29257)
# cds|C|6467954|US|en|cdff87e625f826ae:en_US , DEWALT DG5132 Heavy-Duty Yoke-Style Suspenders(141.35, 22116)
# cds|C|6467954|US|en|351b6274eedcebf5:en_US , Cruz Tools Fender Mount Tool Kit - DMX2(141.09, 6887)
# cds|C|6467954|US|en|3313c52f3e00f3c4:en_US , Marshalltown Heavy-Duty Road Rake, Model RED802920(141.05, 46468)
# cds|C|6467954|US|en|256c2a2584cdf19f:en_US , Wooden top for roller cabinets chrono a(141.04, 25654)
# cds|C|6467954|US|en|5885ad953e75a637:en_US , Gerber 1732 Armbar Slim Drive Bronze(139.46, 55400)
# cds|C|6467954|US|en|4035ae60a4db9f15:en_US , Westcott Weeder Tool, Die-Cut Cartridges, White, for Craft, 1-Count(139.24, 24932)
# cds|C|6467954|US|en|956ab6458338ba8c:en_US , BOSCH Power Tools Combo Kit GXL12V-310B22 - 12V Max 3-Tool Set with 3/8 In. Drill/Driver, Pocket Reciprocating Saw and LED Worklight(139.13, 95464)
# cds|C|6467954|US|en|3688547b0b7a8656:en_US , Biker's Choice Roll-Up Tool Kit 151522(138.52, 29785)
# cds|C|6467954|US|en|53b3384cb31c9ff8:en_US , Milwaukee M18 Magnetic Drill — With 2 Batteries, 18 Volt, Model 2787-22HD(138.42, 25518)
# cds|C|6467954|US|en|e07f6546b3abbefb:en_US , PT-6400-C 3376015 Cylinder Liner Puller Assembly Tool Alt(137.73, 65103)
# cds|C|6467954|US|en|62d7477628016a55:en_US , Zurn P1321-12-CT 12-inch Cartridge Removal Tool(137.72, 77369)
# cds|O|133112864|US|en|TK25/60 , Tool Kit - Chain Breaker & Puller For 25-60 Chain(137.71, 24843)
# cds|C|6467954|US|en|76252ff6cf114cb8:en_US , Garage Storage Organization Tool Storage Rack,Garden Hose Holder,Heavy Duty Tool Organizers Garage Wall Mount Hooks, Space Saving Max 300 lbs Garden(136.89, 2737)
# cds|O|6901112|US|en|70004 , ACME C-Clamp Prop Puller(136.76, 78900)
# cds|C|6467954|US|en|781722a4321445c6:en_US , Valve Lash Wrench - 1/2 in Wrench - Adapter Bushings Included - Aluminum - Black Anodize - Kit(136.75, 76066)
# cds|C|6467954|US|en|c15927331466b80b:en_US , Maxfit Steel Driving Bit Set (30-Piece) with Sleeve(136.43, 28330)
# cds|C|6467954|US|en|16f7e9306ef76033:en_US , Dorman - HELP Windshield Wiper Arm Tool 49023(136.01, 94049)
# cds|C|6467954|US|en|708ad02f3e83496f:en_US , Wrecking Bar 45 In. Steel Rocker Dual Claw Head Nail Screw Remover(135.76, 50605)
# cds|C|6467954|US|en|4583aab00eeebccb:en_US , Heavy-Duty Nail/Screw Removing Pliers(135.26, 18204)
# cds|C|6467954|US|en|f2ea8ef21c53d290:en_US , DEWALT 14-Piece Screwdriver Guide Set | DW2097 | Acme Tools(135.04, 5790)
# cds|O|112466508|US|en|7794 , Renishaw OTS Optical Transmission 3D Touch-Trigger Tool Setter for Machining Centers(134.94, 26357)
# cds|O|162826539|US|en|607958712fb5a56fa003676e , 65MM Bench Drill To Square Tenon Machine Converter Chuck Holder Modified Tenoning Eyelet Accessories with Reducing Sleeve (40/53/55/58/60 Optioanal)(134.68, 21523)
# cds|O|507161872|US|en|185046063672 , Hitachi Chain Mortiser Bc21sa Single Phase 100 V 50/60 Hz 1140 W(134.68, 57874)
# cds|C|6467954|US|en|0357e8d91a63bd5a:en_US , Engine Camshaft Checking Fixture Kit w/Dial Indicator; 0 to 1.000 Inch Range 66830 Proform(134.62, 31719)
# cds|C|6467954|US|en|d17dfb0d3c806a1f:en_US , Milescraft Orbiter Multi-Angle Drill Attachment(134.05, 64551)
# cds|C|6467954|US|en|8b24f66f7c088b7a:en_US , Tekton 90192 Comb. Wrench Set,1/4-1" 8-22Mm,30Pcs.(133.95, 16194)
# cds|C|6467954|US|en|013a9ff627d856d8:en_US , Apollo 1 PEX Quick Pinch Clamp Tool Black/Yellow 1 pc., Size: 5.5 x 15.25 x 6.5(133.77, 59477)
# cds|C|6467954|US|en|3164e1a33163d793:en_US , Cricut Weeding Tool Kit | Michaels(133.58, 8348)
# cds|C|6467954|US|en|68848591e911f82d:en_US , Westward Rolling Tool Cabinet: Gloss Red, 28 3/4 in W x 18 1/10 in D x 33 7/8 in H, Red, 5 Drawers Model: 48RJ74(133.41, 49292)
# cds|C|6467954|US|en|e2fc2a4a68c3ad91:en_US , Dewalt Angle Grinder: 13 A Current, 8,500 RPM Max. Speed, Trigger, 7 in Wheel Dia Model: DWE43840CN(133.24, 49877)
# cds|C|6467954|US|en|93b8f54b5e854b12:en_US , Arsenal General Construction Tool Apron in Gray | 13694(133.06, 3698)
# cds|C|6467954|US|en|84439d24f07c0990:en_US , BOSCH 4-1/2 Inch Angle Grinder GWS8-45(133.04, 26053)
# cds|C|6467954|US|en|b7fa1b5f5fe164a8:en_US , GERBER MP600 Multi-Plier, Needle Nose, Bladeless, Black [30-000952](132.82, 66601)
# cds|C|6467954|US|en|e61f67cd5e150516:en_US , STANLEY COLORmaxx STMT71653 Mechanics Tool Set, Chrome Vanadium Steel, Silver, Chrome, 145-Piece(132.79, 72384)
# cds|C|6467954|US|en|58431f3c96d04f85:en_US , Lodesol Flexible Magnetic Tool Holder 12.5"x9.5" Mp4835(132.46, 59289)
# cds|O|131363368|US|en|shopify_US_1537997252_5446580356 , GuaSha Professional Tool-3(132.19, 84609)
# cds|C|6467954|US|en|1a2aeacf6bf2da97:en_US , Threading & Tapping attachment-lathe tailstock die holder set Machine Tools ((MT2))(131.81, 90480)
# cds|C|6467954|US|en|1267938aea96f857:en_US , Universal Black Finish Steel Adjustable Face Spanner Wrench Pin Pliers For Round Nuts with Drilled Holes (3mm)(131.69, 80620)
# cds|O|142382492|US|en|BM30003 , 7mm Preset Torque Wrench, Hex Size 3/4", Preset Torque 14 in lbs(131.43, 5794)
# cds|O|1228374|US|en|HDP-155.00 , WireJewelry Hammer Handpiece for Eurotool Flex Shaft System(131.27, 8356)
# cds|C|6467954|US|en|aec03882fe6457e2:en_US , Pittsburgh 6 In. T-Bevel(131.17, 77494)
# cds|C|6467954|US|en|e4c86e9646bfc4c1:en_US , DEWALT 20-Volt MAX Cordless 1/4 in. Impact Driver, (1) 20-Volt 3.0Ah Battery & Charger(131.11, 68166)
# cds|C|6467954|US|en|1ab044e7c5c53221:en_US , 18v Octane Angle Grinder Brushless Cordless 4-1/2 In. Lithium-ion 1.5(130.97, 75611)
# cds|C|6467954|US|en|1acf9c84bd9f409a:en_US , Lisle 3/8 in. x 16 in. Short Installer Adapter for 38850 Pulley Puller(130.62, 74063)
# cds|C|6467954|US|en|fbcea7b975138c17:en_US , Workpro 16 inch Top Wide Mouth Tool Bag with Water Proof Rubber Base, Multi-Compartment, 46 Pockets, For Tool Organizer & Storage, W081122a(130.38, 72165)
# cds|C|6467954|US|en|c5785b1dbfb882d3:en_US , Dewalt DCW100K Portable Stick & TIG Welder 1 Tig Welder(130.30, 67764)
# cds|O|121825104|US|en|shopify_US_2112141262945_19844992761953 , AFW Rigging Pliers 5"(129.69, 92890)
# cds|O|6607559|US|en|BGSS-102 , Bench Grinder Safety Scale(129.59, 92136)
# cds|C|6467954|US|en|30a5e6197e3d77aa:en_US , DEWALT DW 23PC Titanium Drill Bit Set(129.02, 19509)
# cds|C|6467954|US|en|bdf5445a27d7c783:en_US , Granite Design Talon 2 Units(127.64, 66718)
# cds|C|6467954|US|en|2cd5a35f6ea2dbf7:en_US , OTC 7470 INJECTOR TIMING TOOL SET,(127.57, 97889)
# cds|C|6467954|US|en|c322fa447b1352bc:en_US , GEARWRENCH GW Series 72" x 25" 20 Drawer Roller Cabinet Black - Red(127.46, 24889)
# cds|C|6467954|US|en|ac23abc11b8bda08:en_US , Dremel 2050-11 Stylo+ Versatile Craft & Hobby Tool With 11 Accessories - each(126.56, 42833)
# cds|C|6467954|US|en|c1989ca8473d3985:en_US , Quad Logic Wheel Bearing Installer/Remover Tool Rear Only Polaris RZR 800 2010-2014(126.36, 84654)
# cds|C|6467954|US|en|fdd7272ce55aab37:en_US , Mayhew Pro 1-1/4 in. W Blade 0.498 in. Dia. Body Pneumatic Hammer(125.99, 86671)
# cds|C|6467954|US|en|d5c115781c35a6fa:en_US , Spear & Jackson 94-370R Eclipse Saw Tooth Setter, Red(125.93, 69519)
# cds|O|8009538|US|en|12202768 , Global CNC Industries Turret & VDI Tool Holders; Type: BMT Live Tooling ; Clamping System: 73mm X 70mm ; Tool Axis: Axial ; Through Coolant: Yes(125.82, 73962)
# cds|C|6467954|US|en|aeecb73c936fefd4:en_US , Marshalltown 10.25-in Zinc Plated Steel Moulding Pry Bar | MPB-L(125.59, 24765)
# cds|C|6467954|US|en|1595befdc07af4ea:en_US , Burgon and Ball Deluxe Gardening Tool Set(125.57, 7441)
# cds|C|6467954|US|en|5712060d10889134:en_US , Diamabrush ZMSTBLD25R10 Coatings/Mastic Removal Replacement Blades Counter Clockwise for 16-inch and 19-inch Tools, 25 Grit, 10 Blades(125.29, 86367)
# cds|C|6467954|US|en|b8cfbf83b61c826a:en_US , Brand Lisle Exhaust Pipe Rubber Hanger Support / Removal Pliers Tool(125.23, 43251)
# cds|C|6467954|US|en|2bc0c96ca13234e3:en_US , Park Tool | Spa-1 and Spa-2 Pin Spanners Spa-1, Green(125.20, 48485)
# cds|O|116927301|US|en|46SO-DD-HS-COY , Direct Draw Hammer Sheath(124.94, 58267)
# cds|C|6467954|US|en|98164e4daad9711b:en_US , Ganasan Contour Gauge With Lock|10+5 Inch Construction Rulers Measure Tool For Corners And Contoured Handyman Diy Woodworking Tools Construction Carpe(124.94, 46112)
# cds|O|116927301|US|en|46HH-AHBH-2-W/M , AIMS Hammer/Hatchet Belt Holder with Magnet(124.86, 75331)
# cds|C|6467954|US|en|a071e8cc74fe93fd:en_US , Baileigh PH-24A Pneumatic Operated Planishing Hammer, 24 Inch Throat Depth(124.76, 27612)
# cds|O|348908|US|en|MOP0021-X001-Y001 , Motion Pro Damper Rod Fork Tool-Dirtbike Damper Rod Fork Tool(124.22, 93908)
# cds|O|5642721|US|en|J1853 , Detroit Diesel Injector Timing Tool(124.09, 57729)
# cds|C|6467954|US|en|65b25a39e5c4f54f:en_US , Dare Chain Grab Puller and Tightener - 2456(124.05, 92048)
# cds|C|6467954|US|en|142887eb503e24dd:en_US , S & G Tool Aid Sgt-18915 Terminal Crimper Kits(123.98, 58602)
# cds|C|6467954|US|en|696d78a67acc3318:en_US , 71161161090, FEIN ASCM 18 QM 4-speed Cordless Drill/Driver(123.72, 61736)
# cds|C|6467954|US|en|433b9c7f33a78c62:en_US , RYOBI ONE+ 18V Cordless 18-Gauge AirStrike Brad Nailer with Compression Drive 3/8 in. Crown Stapler (Tools Only)(123.52, 8934)
# cds|C|6467954|US|en|9f01f143a82ab53e:en_US , Bosch Angle Grinder: 13 A Current, 11,500 RPM Max. Speed, Slide, (1) Bare Tool, (1) Wheel Guard Model: GWS13-50TG(123.31, 35297)
# cds|C|6467954|US|en|248117fb790429ce:en_US , 1" Drain Tube Flaring Tool Flanging Tool 8PCS Fastener for Boat Marine Plumbing Replaces 520290-1(122.91, 20026)
# cds|C|6467954|US|en|7377d95feee8ba58:en_US , DeWalt DWMC150 35-Degree Pneumatic Metal Connector Nailer(122.59, 78593)
# cds|C|6467954|US|en|b8870882995fa430:en_US , OTC 5035 Truck Clutch AdjusTment Gauge Set(122.22, 29973)
# cds|C|6467954|US|en|9290c08d3669c9a1:en_US , Mibro Adjustable Tap Wrench, 302871(122.12, 13813)
# cds|C|6467954|US|en|6ac83166efd2d546:en_US , Ring Bending Tool Repair Bracelet Bender Copper Silver Gold Strip Bending Tool(121.10, 24890)
# cds|O|114193152|US|en|B01FJQ14NQ , Glamorway 6Pcs Clay Sculpture Sculpting Tool Mini Ribbon Cutter Metal Tools Set Carving Art(120.81, 9263)
# cds|C|6467954|US|en|2e2b351c821f7757:en_US , Anvil 51 in. Wood Handle Steel 14-Tine Bow Rake(120.77, 10443)
# cds|C|6467954|US|en|c54d15acf555bf6c:en_US , Hyper Tough 38-pc Stubby Tool Set: Wrench Ratcheting Screwdriver Bits(120.73, 25849)
# cds|C|6467954|US|en|8af282d29380cbe6:en_US , Fiskars 18" Demolition Hammer - Dead Blow Hammers(120.49, 68684)
# cds|C|6467954|US|en|8a427d05df121059:en_US , Dremel Straight Router Bit - 654(120.15, 75210)
# cds|C|6467954|US|en|4c1a695c8ca8c170:en_US , Gear Wrench Hose Grip Double-X Pliers - 3/4", 82019(120.08, 69944)
# cds|C|6467954|US|en|96791657c58bb5d4:en_US , Husky Multi-angle Pipe Wrench 1003 005 294 (e10017225)(120.03, 33939)
# cds|C|6467954|US|en|b3acdb35cc28d2a4:en_US , Dremel Drill Press Rotary Tool Workstation For Woodworking Jewelry(120.01, 54218)
# cds|C|6467954|US|en|c477dd7a336f7200:en_US , Toolbag DMM(119.98, 60398)
# cds|C|6467954|US|en|4fc1dc570584ccac:en_US , TEKTON 7 -in Diagonal Cutting Pliers PCT00007 | PCT00007-D(119.60, 56757)
# cds|C|6467954|US|en|de0cce42ccb305d1:en_US , Steelman 79435 Heavy-Duty Tire Valve Stem Puller/Installer, Green(119.49, 96562)
# cds|C|6467954|US|en|174454ad543bbd4f:en_US , Steck Studlever Dent Puller(119.34, 20279)
# cds|C|6467954|US|en|e283b08b64582d08:en_US , Bosch 1Inch SDS-plus Rotary Hammer, Pistol Grip, Chuck Size 1 in, Volts 120, Amps 8, Model GBH2-26(119.21, 82051)
# cds|C|6467954|US|en|4366ec51109e1f88:en_US , Bosch Black Oxide Impact Tough Drill Bit Set (9-Piece)(118.99, 43090)
# cds|C|6467954|US|en|a40241d506179181:en_US , DEWALT DWST08205-DWST08202-DWST08201-DWST08204-DWST08210 ToughSystem Workshop Deluxe Mobile Bundle Kit(118.94, 21630)
# cds|O|101830283|US|en|472571036932_173855230431 , Craftsman Ratchet Wrench 1/4 3/8 1/2 Teardrop 75t 84t Teeth Brand(118.79, 33230)
# cds|C|6467954|US|en|04c299e2ff14352e:en_US , DEWALT 3/4" Sds-Max Ground Rod Driver - 324DW5847 - Power Tool & Equipment Accessories - Concrete & Masonry Drill Bits(118.70, 51670)
# cds|O|7308165|US|en|TDPP112+or+TDPP113 , Tire Changing Tool (5" or 6")(118.61, 19565)
# cds|O|10798|US|en|shopify_US_2057445572697_21364897775705 , Gemplers Extra-Wide, Long-Handled Tool Rack(118.61, 74049)
# cds|C|6467954|US|en|6ea698546dbc6ff0:en_US , Dremel EZ726-01 EZ Lock Sanding & Polishing Kit for Rotary Tool, 8 Piece (Dremel EZ726-01)(118.45, 40092)
# cds|C|6467954|US|en|f5b61290af5983d2:en_US , Craftool Strap Cutter Replacement Blades 3081-00 By Tandy Leather(118.44, 84667)
# cds|C|6467954|US|en|b8c48e090f01d320:en_US , DeWalt DW2735 Drill Flip Drive Set(118.14, 93097)
# cds|C|6467954|US|en|d924cd552a10bda7:en_US , RZX 16" RIVET NUT TOOL Hand Blind Riveter ,RIVNUT Riveting Tools with Nut Setting System totally 12mandrels M3 M4 M5,m6,m8,m10 M12, 10-24, 1/4-20 , 5(117.95, 70399)
# cds|O|142898678|US|en|2298357 , Rack Lat Pulldown / Row Attachment - Light Commercial/Residential Power Rack | Bells of Steel(117.83, 74068)
# cds|O|545697639|US|en|880 , CH-22 Manual Tire Changer(117.24, 45313)
# cds|C|6467954|US|en|e6dd3d7be28f199f:en_US , Universal Sharpening Station, Multifunctional Sharpener Professional Knife & Chisel & HSS Drill Electric Multitask Sharpening Machine(117.07, 61680)
# cds|C|6467954|US|en|f60950a66f18e230:en_US , OZ-Puller Post Clamp(116.92, 75145)
# cds|C|6467954|US|en|d2b14df38583ca3d:en_US , Estwing 8-Pocket Leather Electrician's Tool Pouch for Work and Tool Belts, Flashlight Loop, Tape Chain, Pliers Pockets, 3-inch Tunnel Loop(116.81, 43789)
# cds|C|6467954|US|en|9a42ae6cb0f3df2b:en_US , Oni Tools Input Shaft Bearing Puller Tool Kit for Eaton Fuller 1 3/4” & 2” Shafts and Ultra Shift Plus Transmission Bearing 4308011(116.77, 31833)
# cds|C|6467954|US|en|57c89a643c6541fa:en_US , Wrench Set Full Polish Chrome(116.41, 4104)
# cds|C|6467954|US|en|e1603a356b46d445:en_US , MAKITA 18V X2 (36V) LXT Lithium‐Ion Brushless Cordless 21" Self Propelled Lawn Mower, Tool Only Teal | XML08Z | Acme Tools(116.11, 96832)
# cds|C|6467954|US|en|09b1e9fbb3df5043:en_US , Vevor Lawn Mower Blade Grinder 1/2 Hp Bench Blade Sharpener 8" Grinding Wheel(115.89, 33779)
# cds|C|6467954|US|en|6592b45d5cf97c1c:en_US , 100 Pcs Rubber Grinding Heads,3mm Shank Polishing Tip Mounted Point Bufing Wheel for Dremel Rotary Tools(115.71, 86494)
# cds|C|6467954|US|en|1597ded244b6d4e4:en_US , Leatherman Skeletool Multi-Tool Coyote Tan, Clamshell Packaging Full Size, General Purpose 832201(115.44, 50429)
# cds|C|6467954|US|en|b8b07b9b85be016b:en_US , CRAFTSMAN 2000 Series 26.5-in W x 37.5-in H 5-Drawer Steel Rolling Tool Cabinet (Black) | CMST98268BK(115.29, 58056)
# cds|O|6296724|US|en|133439388719 , Sears Craftsman Commercial Electric Drill Heavy Duty Reversible 1/2(115.27, 32104)
# cds|C|6467954|US|en|7cbc63dc75585062:en_US , RYOBI 3 in. Carbide Cut Off Wheel Set (6-Piece)(115.25, 96997)
# cds|C|6467954|US|en|252f3328ff28ddc8:en_US , PSB/Purdy 140900230 Carbide Scraper ~ 2 - 1/2"(115.12, 55240)
# cds|C|6467954|US|en|147651e0457eafbe:en_US , Crescent 24 in. Chain Wrench(114.68, 70196)
# cds|C|6467954|US|en|019a29c6109b5c6a:en_US , Makita XSF03R 18V LXT Lithium-Ion COMPACT Brushless Cordless Drywall Screwdriver Kit (2.0Ah)(114.62, 99958)
# cds|C|6467954|US|en|565bf57c7d24765f:en_US , Dead On Dos22m 22-ounce 18-inch Steel Milled Face Hammer(114.44, 83400)
# cds|C|6467954|US|en|cb5b3838ff9f8589:en_US , Milwaukee 48-22-1928 5" HARDLINE Fixed Blade Knife(114.25, 62062)
# cds|C|6467954|US|en|63474ab23d9dca08:en_US , Edger Blade - Echo 720237001(114.22, 14897)
# cds|C|6467954|US|en|85e97db70cb24959:en_US , Hercules 10 in. Tool Tote with 22 Pockets(113.99, 345)
# cds|C|6467954|US|en|0730b093ef4f25fd:en_US , Homax Drywall Corner Taping Easy Seamer Tool, Plastic, Yellow, Size: 7.6 x 4.5 x 1.9(113.82, 45490)
# cds|C|6467954|US|en|cfdd073da3dd9594:en_US , Ridge Tool Company Manual Threading/Metal Cases, For 12R, Holds 9 Die Heads, 1/EA, #97375 | AFT Fasteners(113.72, 64437)
# cds|C|6467954|US|en|70c0dc20368a2657:en_US , Bauer Tools 1895c-b(113.66, 84524)
# cds|C|6467954|US|en|e623761846d11c8f:en_US , Klein Tools Bull-Pin And Bolt Bags, 3 Compartments, 10 In X 5 In, Canvas - 1 Ea (409-5416)(113.63, 52335)
# cds|O|9202400|US|en|10598 , Irritec Drip Clip Punch/Installation Tool(113.60, 80657)
# cds|C|6467954|US|en|8279924a0a2f2cd2:en_US , Workington Portable Carpenter Metal Tool Box with Latch, Small Parts Box, Sockets Storage Box Organizer 4002(113.49, 90489)
# cds|O|12768591|US|en|898325253 , Pink tool belt incl. pink tool(113.35, 3192)
# cds|O|4214520|US|en|91082068 , Speedway Racing Tire Needler Prep Tool(113.28, 8727)
# cds|C|6467954|US|en|17b099866ffe7fd4:en_US , Crescent Z2 Auto-Bite Tongue and Groove Plier Set (3-Piece)(113.21, 84040)
# cds|C|6467954|US|en|05c509ee40d8889d:en_US , Berry's Superior Bullet Puller(112.94, 83538)
# cds|O|100872875|US|en|21730 , Jacknob 8935, Toilet Partition One Way Screw Removers, Can Remove Sizes: 6-14 by WoodworkerExpress.com(112.93, 59106)
# cds|C|6467954|US|en|b23a623a78b49903:en_US , Gerber Gator Combo Axe and Knife(112.73, 61212)
# cds|C|6467954|US|en|2d127c08cdecc34b:en_US , Gordon Lock-Back Utility Knife(112.64, 6087)
# cds|C|6467954|US|en|20ebe6b121a6ff15:en_US , End Cutting Pliers Nail Puller End Nippers For Zipper Install Stops(112.38, 32993)
# cds|C|6467954|US|en|2e71242c84fbf954:en_US , Milwaukee Lineman's Underground Knife(112.11, 9080)
# cds|C|6467954|US|en|4d4147965dcbf799:en_US , Machinist Clamping Kit, 42 Piece(111.75, 92657)
# cds|C|6467954|US|en|3ae907620849385c:en_US , Epicurean Magnetic Knife Holders(111.23, 57461)
# cds|C|6467954|US|en|e1019aa76bf0cc50:en_US , JEGS 5-Drawer Tool Box Cart | Smooth Ball Bearing Glides | Over 700 LBS Capacity | Red Powder Coated Finish | Includes Drawer Liners(111.23, 68202)
# cds|C|6467954|US|en|8487eb6bb8d6c647:en_US , RYOBI ONE+ 18V Brushless Cordless 1/4 in. Extended Reach Ratchet with (1) 2.0 Ah Battery and Charger(110.93, 5581)
# cds|O|348908|US|en|HPT1WUD-X001-Y001 , HP Tools Showa/KYB Compression Body Fork Cap Tool-Dirtbike Fork Cap Wrench(110.81, 36925)
# cds|C|6467954|US|en|a99bb41dbe23525c:en_US , Milwaukee M18 FUEL 18 Volt Lithium Ion Cordless Brushless String Grass Trimmer 8.0Ah Kit with Pole Saw, Hedge Trimmer, Edger(110.35, 45690)
# cds|C|6467954|US|en|da4254659837e043:en_US , General International 15 In. Bench Commercial Variable Speed Drill Press with Laser and Regular Chuck Green | 75-060 M1 | Acme Tools(110.21, 44753)
# cds|C|6467954|US|en|d6dc9bdbbf8431cc:en_US , Dr. Slick Fly Tyer Gift Set | Fly Fishing Tying Set | SKU TYER(110.17, 65039)
# cds|C|6467954|US|en|dc08a30c1136e329:en_US , 12-Piece Reciprocating Saw Blade Kit By Milwaukee 49-22-1129(110.15, 96229)
# cds|C|6467954|US|en|aca52a5cce444d00:en_US , Eklind 10 Piece T-Handle Hex Key Set - Hex Range 3/32 to 3/8", Alloy Steel | Part #53610(110.15, 70603)
# cds|O|3074108|US|en|2KUY1 , Prime Edge Knife Sharpening Machine: 110 V, 1/6 Horsepower, Single Phase, 12 in Overall Dp Model: HE1-110V1P60HZ(110.14, 62876)
# cds|C|6467954|US|en|c77c545302407832:en_US , Nifty Home Products, Inc. Innovation Factory Trucker'S Friend All-Purpose Survival Tool - Woodcraft(110.01, 97592)
# cds|C|6467954|US|en|99d8388100bb690c:en_US , Powerbuilt Master Steering Wheel and Lock Plate Puller Kit, Included (qty.) 21, Product Type Pullers, Single Set, Model 648748(109.55, 21004)
# cds|O|114143634|US|en|553539078914_254178903344 , Canvas Roll Up Tools Storage Bag 8/10/14-pocket Spanner Wrench(109.50, 36945)
# cds|C|6467954|US|en|c7ee82bf9a672e59:en_US , Wal-Board Tools 24 in. Taping Knife with Wooden Handle(109.43, 3842)
# cds|O|101704838|US|en|174104040720 , Hart 5 Piece Quick Tatch Trowel Set Grout Float, Square Notch, Handle(109.36, 22863)
# cds|C|6467954|US|en|89b7f0b7fcea9a0a:en_US , DEWALT Reciprocating Saw Blades, Straight Back, 6-Inch, 14 TPI, 5-Pack (DW4808)(109.35, 16960)
# cds|O|101684535|US|en|254905331731 , 1" Quick Release 'l' Shaped Windshield Glass Knife - Rockwell(109.13, 44638)
# cds|C|6467954|US|en|c2e510528af86727:en_US , Landscapers Select PS-60943L Lawn Weeder, Plastic Handle, Powder-Coated(109.12, 43607)
# cds|C|6467954|US|en|5d55e412a46d9f99:en_US , Milwaukee Cordless Concrete Vibrator Model: 2911-20(109.12, 34151)
# cds|C|6467954|US|en|6551d06ab0397ab0:en_US , Milwaukee M12 FUEL 12-Volt Li-Ion Brushless Cordless Hammer Drill and Impact Driver Combo Kit (2-Tool)W/ M12 3/8 In. Ratchet power tool set, power(108.92, 49285)
# cds|C|6467954|US|en|72dd5fb4752206d0:en_US , Bulltools 6-Piece Flex-Head Extra Long Ratcheting Wrenches Double Box End Chrome Vanadium Steel 72-Tooth Wrench Set with Metric 8mm - 19mm, Size: SETS(108.86, 58808)
# cds|O|8740|US|en|306810110 , DEWALT 20 in. 20V MAX Lithium Ion Cordless Battery Walk Behind Push Lawn Mower with (4) 5.0Ah Batteries and Charger Included(108.83, 18074)
# cds|C|6467954|US|en|3a2847b3feda7132:en_US , GEARWRENCH Ratcheting Combination Wrench 16mm, 12 Point - 9116D(108.24, 63964)
# cds|C|6467954|US|en|b9533f36c639309b:en_US , KAKO String Trimmer Line 0.065'' Replacement Spool for Ryobi One Plus AC14RL3A 18V 24V 40V Auto Feed Cordless Weed Eater Spools Line with AC14HCA(108.06, 71013)
# cds|C|6467954|US|en|ccef3f01901de174:en_US , Jackhammer Driving Kit Jack Hammer Driver Bit Spacer Install Fence(107.94, 67447)
# cds|C|6467954|US|en|5dbfecb4cbf53526:en_US , Guosu Cable Grip Wire Gripper Steel Cable Puller Tool for Wire Rope,Pulling 4408 Lbs(2 Ton)(107.90, 85846)
# cds|C|6467954|US|en|d01fd345d3179390:en_US , Dewalt Screwdriver Kit: 1/4 in Hex Drive Size, 430 RPM Free Speed, (1) Bare Tool, (1) Battery, (1) Charger Model: DCF680N1(107.79, 94538)
# cds|C|6467954|US|en|d28a4c7430443570:en_US , Craftsman 8 oz Ball Pein Hammer Steel Head 11 in.(107.51, 46760)
# cds|C|6467954|US|en|087f618f97ec36ea:en_US , Milwaukee 48-01-7787 9" 14 TPI The Torch SAWZALL Blades (Pack of 100)(107.31, 50534)
# cds|C|6467954|US|en|3cd442db3c7ebeed:en_US , Feuling Crankshaft Runout Measuring Tool 9015(107.24, 25409)
# cds|C|6467954|US|en|d1632a0a36c283d9:en_US , Flex 24-volt Brushless Drywall Cut Out Tool - Fx2471-z -tool Only-(107.21, 10821)
# cds|C|6467954|US|en|3e03c1b0780b288b:en_US , DEWALT 125 MPH 600 CFM Flexvolt 60V MAX Lithium-Ion Cordless Axial Blower (Tool Only) with Bonus (1) FLEXVOLT 60V 3.0Ah Battery(107.14, 40317)
# cds|C|6467954|US|en|f4cab55e2c9c3424:en_US , Attractor 24 in. Magnetic Sweeper PS337C(106.85, 25410)
# cds|C|6467954|US|en|cd697a164a554954:en_US , Milwaukee 48-68-0031 1/4" Collet Nut(106.74, 54444)
# cds|C|6467954|US|en|7d4a8bdcf2c0f94e:en_US , Westward 2Dbr6 Ball Pein Hammer,8 Oz,hickory Handle(106.68, 60073)
# cds|O|247906560|US|en|22455 , Ko-ken Socket Set in Foam PM-HND-1014-00-F / TI4261M | Pentagon, Socket Set Titanium(106.42, 75228)
# cds|O|272358891|US|en|419058 , Hummingbird Needle Threader(106.41, 35604)
# cds|C|6467954|US|en|6a1c14a4700cfffe:en_US , BOSCH 10 pc. Wood and Metal Cutting T-Shank Jig Saw Blade Set | T5002 | Acme Tools(106.38, 2932)
# cds|C|6467954|US|en|be51f85a7f0207db:en_US , Mueller Kueps 457705 Line Wrench Kit With Joint Brand(106.25, 87607)
# cds|C|6467954|US|en|80515813c37838e6:en_US , Knipex 02 01 200: Knipex High-Leverage Combination Pliers(105.84, 73491)
# cds|O|6296724|US|en|114918806727 , Genuine Makita Makpac Interlocking Charger Case Systainer W/o(105.82, 60009)
# cds|O|111108931|US|en|PS16325548 , Ryobi 314608005 Bump Feed Trimmer Head Assembly (Inc. Key No. 21)(105.73, 9290)
# cds|C|6467954|US|en|dd19ff2ed10b9ef8:en_US , Icon SAE Professional Ratcheting Combination Wrench Set, 7 Piece(105.70, 54359)
# cds|O|110026978|US|en|shopify_US_4621895046_15133467334 , Milwaukee 4094 Diamond Coring Motor 450/900 RPM, 20 Amp with Shear Pin(105.56, 24586)
# cds|O|423913691|US|en|433395879019_133947822736 , 1~20pack 20 Volt For Dewalt 20v Max 5.0ah Lithium Ion Battery Dcb206-2(105.30, 76002)
# cds|C|6467954|US|en|453d4abcece22b0b:en_US , 3pcs Locking Pliers Set 10'' 7" 5" Curved Jaw Nickel Plated Heat(105.19, 7642)
# cds|C|6467954|US|en|cf5a5bdbb7776b00:en_US , Magic Tool Clip Set Regular - Marc Petitjean - Fly Tying(105.17, 13422)
# cds|C|6467954|US|en|255bf24da809f042:en_US , T40070-T40133 Camshaft Clamp Set Alt(105.01, 97716)
# cds|C|6467954|US|en|5ca8836234eec0ed:en_US , Rockler Table Saw Blade Holder(104.86, 84417)
# cds|C|6467954|US|en|3ca071894f86af50:en_US , K Tool International 72450 - Magnetic Tool Hanger(104.54, 47565)
# cds|O|8128387|US|en|CR10B , Handle Maker(104.45, 6090)
# cds|O|117171671|US|en|830508606 , Knipex Holder ~ Leather Case for Knipex Pliers ~ Knipex Pliers Holder ~ Plier Holster for Knipex Cobra(104.44, 79747)
# cds|C|6467954|US|en|bc3748ca24728fbe:en_US , Ultima 5.5" Razor Sharp Surgical Seam Rippers/seam Cutters (4 Pack)(104.28, 92347)
# cds|C|6467954|US|en|d2e4f3b027ee1995:en_US , DeWALT 3/4" Pipe Capacity, PEX Expander Tool - 1 Piece, Cuts PEX Type-A, Includes Expansion Head | Part #DCE40034(104.21, 33064)
# cds|O|113478214|US|en|31-004011 , Gerber Gear Randy Newberg EBS Tools Replacement Blades(104.20, 43795)
# cds|C|6467954|US|en|15c6785a45e48d08:en_US , Flexible Hose Clamp Pliers 2' Long Wire For Flat Oil Water Fuel Hose(104.19, 42382)
# cds|C|6467954|US|en|f455177fd9394293:en_US , Powerbuilt 648796 For Honda Crank Pulley Holder Tool(103.93, 34824)
# cds|C|6467954|US|en|212fc674c11a44bb:en_US , Dewalt 5140178-86 Replacement Radio Power Supply Dwst08810(103.81, 49269)
# cds|O|144646454|US|en|09A0121 , Replacement Blades for Pro Seam-Ripper Kit, Repl. (6)(103.62, 7782)
# cds|O|7892326|US|en|R-3018+RC4 , UTV Roll Bar Tool Holder Carrier by Hornet Outdoors(103.53, 74638)
# cds|C|6467954|US|en|7acbc115daa38d53:en_US , SUNEX TOOLS Pencil Air Die Grinder Kit(103.19, 13393)
# cds|O|9299300|US|en|19876 , Frame Hammer- 1 Each(102.97, 60241)
# cds|C|6467954|US|en|369fbcb6836d2471:en_US , Westward Intermediate Chest: Powder Coated Black, 26 3/8 in W x 17 in D x 10 5/8 in H, Black Model: 32H849(102.94, 76444)
# cds|C|6467954|US|en|592e767d18914901:en_US , Motion Pro 08-0349 35mm Flywheel Puller M35 X 1.5 R.h.(102.73, 99840)
# cds|C|6467954|US|en|1f521d452ad76a25:en_US , Bond Mattock 15 in. Steel Handle(102.55, 65962)
# cds|C|6467954|US|en|b9d94ce938ad456c:en_US , Multi-Angle Measuring Ruler,Multi Angle Tool,12-Sided Angle Measurement,Tile Holes Measure Ruler with 3-Holes Positioning Apertures,Upgrade Multi(102.52, 575)
# cds|C|6467954|US|en|ee829f932d35e0f2:en_US , GearWrench 9520D 10 Piece 12 Point Stubby Ratcheting Combination Metric Wrench Set(102.36, 12522)
# cds|C|6467954|US|en|80bbedcd43fa8b30:en_US , NAVAC NTR14 Internal & External Reamer, 1/8" to 1 5/8" Tube O.D.(102.19, 32892)
# cds|C|6467954|US|en|294ecf986090d707:en_US , Detroit Diesel Dd15 Dd16 Camshaft Timing Tool Kit & Tdc Locating Pin(102.15, 18890)
# cds|O|124241419|US|en|103693 , TW8, 3/4 - 1-1/2 Straight Tap Wrench(102.13, 4077)
# cds|C|6467954|US|en|38c37986d77283f3:en_US , Gates 91023 SureLok 1/8" to 3/8" Vertical Quick-Release Push-Lock Pliers(101.68, 85891)
# cds|O|374448703|US|en|m83613137553 , Drill Master 18v 3/8 In Cordless Drill. | Color: Black(101.65, 53708)
# cds|C|6467954|US|en|0aba4e04e20f45c5:en_US , Dremel 615 Router Bit,roundover,1/8 In Bit Dia(101.60, 73753)
# cds|C|6467954|US|en|d3fda0d5ae38696c:en_US , eTORK Click-Style Torque Wrench (1/4-Inch, 40-200 in.-lb)(101.57, 81829)
# cds|C|6467954|US|en|b6ddcf9e2e6f0ee0:en_US , DEWALT 20-Volt MAX Cordless 6-1/2 in. Circular Saw with (1) 20-Volt Battery 4.0Ah and Charger power tool set, power tool combo kits, cordless tool set(101.53, 3307)
# cds|C|6467954|US|en|e507b206c553c792:en_US , CST-1900 - jonard tools(101.43, 70313)
# cds|C|6467954|US|en|aa6ceab8306ad5ca:en_US , Stanley Quick Change Retractable Utility Knife (2-pack)(101.41, 96709)
# cds|C|6467954|US|en|18ff49f1b75f4d4f:en_US , ABN Valve Stem Seal Remover and Installer 11-Piece Tool Kit with Carrying Case – Pliers, Drive Handle, Sockets, Adapters(101.24, 68384)
# cds|C|6467954|US|en|2721a2c9a86e8651:en_US , DEWALT 6 gal Pancake Compressor/2 In. Brad Nailer Combo Kit Yellow/Black | DWC1KIT-B | Acme Tools(100.97, 40062)
# cds|C|6467954|US|en|c565a58b33c84567:en_US , ATOMIC 20-Volt MAX Cordless Brushless Compact Reciprocating Saw with (1) 4.0Ah Battery(100.93, 23056)
# cds|C|6467954|US|en|ee9f42410a638e3c:en_US , Truck Tool Box Mounting Kit Pickup Universal Fit Toolbox Tie Downs Aluminum Alloy J Hooks Crossover with 304 Stainless Steel Screws and Washers(4(100.91, 60229)
# cds|C|6467954|US|en|377556650927335a:en_US , BMW E46 M3 S54 - Genuine BMW Rear Toe Adjustment Tool: A big help when doing an alignment(100.90, 65073)
# cds|C|6467954|US|en|2a9f72c8be513dfb:en_US , Kraft Tool Sk102 Power Troweler Blade,floatshoe,10X14 In(100.58, 12479)
# cds|C|6467954|US|en|c2186f7765d74570:en_US , Tapetech 40" Premium Skimming Finishing Knife Px40tt(100.57, 44484)
# cds|C|6467954|US|en|4034afb5408e7275:en_US , Rubber Bench Block Set (4x4in) with Mini Hammer (6in) - Jewelry Making Kits Supplies, Metal Smiting Tool, Jewelry Tools for Metal Stamping Kit,(100.51, 358)
# cds|C|6467954|US|en|68d4932a3930f6f1:en_US , Dewalt Inner Core Bulb Head Drain Cleaning Cable 5/16 in x 25 ft Model: DCD2005(100.47, 57942)
# cds|C|6467954|US|en|ae7ac8e1dd1ffbdf:en_US , Speedaire 5Yap3 Tool Retractor,for Tool 2-4 Lb,no Lock(100.12, 52431)
# cds|C|6467954|US|en|6ef304eed6081bb2:en_US , SEKETMAN 24 Pcs Combination Ratcheting Wrench Set 12 Point Speed Wrench Set Fit for Garage,Office, Home DIY, Repair and Maintenance(100.10, 31212)
# cds|C|6467954|US|en|97af89a40498d174:en_US , Bosch 12 5 Tpi Rcp Blade 5Pk Pch | Bosch-RP125(99.78, 55642)
# cds|C|6467954|US|en|9c6db3ed7da35d3b:en_US , Milwaukee M12 FUEL 12-Volt Lithium-Ion Brushless Cordless 1/2 in. Drill Driver Kit with 4.0Ah and 2.0Ah Battery and Hard Case(99.65, 12466)
# cds|C|6467954|US|en|ba790f3324155a7a:en_US , Dewalt Genuine OEM Replacement Rip Fence + Rip Fence # Combo00233, Men's, Size: One size(99.58, 80314)
# cds|C|6467954|US|en|43c4a3b148796141:en_US , Bosch Daredevil 6 in. QC Spade Drill Bit Extension(99.45, 50654)
# cds|C|6467954|US|en|0a44015407dcc3ec:en_US , Husky 11 mm 12-Point Metric Ratcheting Combination Wrench(99.03, 63589)
# cds|C|6467954|US|en|2b371302409ff316:en_US , Makita XML11CT1 | 18V X2 (36V) LXT Lithium-Ion 21" Cordless Self-Propelled Lawn Mower Kit /w 4 Batteries (5 Ah) | Tyler Tool(98.97, 56411)
# cds|C|6467954|US|en|90cbf55877709deb:en_US , Ultimate Complete Kawasaki KLR650 Tool Kit with Tool Roll MADE IN USA(98.79, 29129)
# cds|C|6467954|US|en|3a3df56797a1d45d:en_US , 3-piece High Leverage Diagonal Cutter Set(98.72, 60447)
# cds|C|6467954|US|en|eaab6ff939a78c89:en_US , Stewmac Endpin Jack Reamer(98.55, 3203)
# cds|O|121794993|US|en|woocommerce_gpf_12819 , Service Line Puller Kit(98.38, 1555)
# cds|O|137734820|US|en|264040364663 , 40" X 324" (27') Monarch Engine Lathe: Stock 65383(98.35, 72239)
# cds|C|6467954|US|en|7ed4434e39fc853e:en_US , Dewit 60" Half Moon Hoe(98.35, 28874)
# cds|C|6467954|US|en|e8457480289fd4ca:en_US , Pliers Ear Clamp Pliers W/ Side Jaw Knipex(98.25, 56775)
# cds|C|6467954|US|en|8a71b31ccf79ed90:en_US , Corona 14" Level Head Rake - Red(98.08, 44431)
# cds|C|6467954|US|en|da58d37af9571879:en_US , CRAFTSMAN 9-Pack Bi-Metal Set Wood/Metal Cutting Reciprocating Saw Blade Set | 2058840(98.00, 79621)
# cds|O|110888525|US|en|123887934872 , Dewalt 20v Max Dcd780 ,dcd785 Cordless 2nd Gen Trigger Switch(97.99, 55178)
# cds|C|6467954|US|en|1c71612ae0177ae6:en_US , 2x XRP 18V NiCD Dc9096 Battery For Dewalt De9095 Dw9098 Dc9099 18Volt Power Tool, Black(97.74, 4751)
# cds|O|106567002|US|en|HYD+000-163-617 , HydraMaster Evolution Glided Upholstery Tool(97.65, 83281)
# cds|C|6467954|US|en|014c178f88020c79:en_US , DeWalt DCB609(97.54, 69266)
# cds|O|262986322|US|en|47636812345 , MultiTasker Twist Multi-Tool SKU - 476368(97.47, 22437)
# cds|C|6467954|US|en|43f113b13f81dd5e:en_US , OTC Hub Grappler(97.42, 43191)
# cds|C|6467954|US|en|71aaede266ee0231:en_US , Dewalt Dw618b3 120v 12 Amp 2-1/4 Hp 3 Base Router Kit(97.38, 64180)
# cds|C|6467954|US|en|3c1f05c6ea199c25:en_US , OmniWall Grinder Holder-Black(97.28, 92694)
# cds|C|6467954|US|en|40a94abd6d70afab:en_US , 5-Inch Replacement Pad for Ryobi #300527002, Compatible with Ryobi RS290, RS280/RS280VS, RS281VS, P411 Random Orbit Sander(97.24, 987)
# cds|C|6467954|US|en|98698579641c4f22:en_US , Bucktool Combo 2" x 42" Belt Sander 6" Bench Grinder, Knife Sharpener with Large Work Table BG2600 Upgraded Model(97.22, 46055)
# cds|O|4900386|US|en|1363145 , DeWALT DW 40 ft. Pocket Laser Distance Measurer, DW055PL-Q(97.21, 99819)
# cds|C|6467954|US|en|bf546ecf2860c1a5:en_US , DeWalt Sa Shoe #DWB-605076-00SV(97.12, 35227)
# cds|C|6467954|US|en|17c2ad933af25175:en_US , Pac Strapping Products Bt3920 5/8-Set Strapping Combo Tool,battery,hea(96.98, 55381)
# cds|C|6467954|US|en|8699a774dd961d49:en_US , StrongHand MLA600 Adjustable Angle 6" Magnet(96.77, 28170)
# cds|C|6467954|US|en|52f79d96210f1937:en_US , Unique Truck Accessories UB36-20TD Brute HD Two Drawers Underbody Tool Box(96.71, 53305)
# cds|C|6467954|US|en|b035c9395d8ad978:en_US , CHIEN RONG 1.5 HP Tire Machine Tire Changer Wheel Changers Machine Balancer Rim Clamp Combo 580-680 12"-21" / 12 Month Warranty(96.45, 52490)
# cds|C|6467954|US|en|3f030b2862fb7bc5:en_US , DEWALT 1/2-in 6-in Titanium Twist Drill Bit | DD5132(96.33, 45627)
# cds|C|6467954|US|en|ab676c77739074b2:en_US , Ch-70 Hydraulic Hole Punching 35t Tool Puncher Cfp-800-1 Copper Bar(96.30, 20755)
# cds|C|6467954|US|en|055e7ce0c8b47aa6:en_US , Marshalltown DuraFlex 5 in. W Stainless Steel Finishing Trowel(96.19, 45701)
# cds|C|6467954|US|en|a9502c807e582d17:en_US , General Tools 86014 14 piece Quad Saw/Driver, Size: Various tools, Black(96.00, 49858)
# cds|C|6467954|US|en|3ef5f2236076ddbb:en_US , Marshalltown 6 X 4 3/8 Zinc Groover-1D X 3/8 Bit-DuraSoft Hdl, Product Type Groover, Model 835D(95.78, 25263)
# cds|C|6467954|US|en|bc3abc5ef41bcfbb:en_US , RYOBI 10 in. 40-Volt Lithium-Ion Cordless Pole Saw, 2.0 Ah Battery and Charger Included RY40562VNM(95.74, 19031)
# cds|O|9384133|US|en|CRT36-26A , Husqvarna CRT36-26A Riding Trowel with Wheel Kit(95.66, 28573)
# cds|C|6467954|US|en|2e81c57147398ed8:en_US , DeWalt DCB205-2 20V Max XR 5.0Ah Lithium Ion Battery (2-Pack)(95.57, 70305)
# cds|C|6467954|US|en|7d42022be337fb2b:en_US , DEWALT 20-Volt MAX XR Cordless Brushless Compact Router with (1) 20-Volt Battery 3.0Ah & Charger(95.56, 45060)
# cds|O|110026978|US|en|shopify_US_4621871366_15133376710 , Milwaukee 2676-23 FORCELOGIC M18 10-Ton Knockout Tool 1/2" to 4" Kit(95.55, 77236)
# cds|C|6467954|US|en|7b883ffc6fe1c2c5:en_US , Dremel 1/16 in. Rotary Tool Round-Shaped Engraving Accessory for Wood, Fiberglass, Plastic, Jewelry and Soft Metals (2-Pack)(95.45, 77858)
# cds|C|6467954|US|en|1b39edd268326bb3:en_US , Tru-flate Steel Valve Core Extractor Model: 41-444(95.24, 17865)
# cds|O|7857044|US|en|384492798458 , Vintage 1930s Ford Snap-on Tools 5/8" Drive Socket Ratchet P-4 L72r(95.21, 69380)
# cds|C|6467954|US|en|9ece07cf9dd759a0:en_US , Wera 074716 1.2 Nm Fixed Torque Screwdriver(95.04, 53439)
# cds|C|6467954|US|en|6335388638f4acf0:en_US , Weyland Survival Axe, Beige(94.72, 51867)
# cds|O|513534827|US|en|shoplaza_US_9effa0ce-6e07-460c-8e8f-4d88f6659a93 , Milwaukee 2741-20 M18 FUEL 16GA Straight Finish Nailer Bare Tool(94.70, 47729)
# cds|C|6467954|US|en|7b350d0a57940e5e:en_US , DeWalt Wheel Kit #DWB-5140095-02(94.70, 94422)
# cds|C|6467954|US|en|243860e9224f076f:en_US , 60-piece Master Tap and Die Set - Include Both SAE Inch and Metric Sizes, Coarse and Fine Threads | Essential Threading and Rethreading Tool Kit with(94.66, 41796)
# cds|C|6467954|US|en|5b9ea2384c7d4a8b:en_US , DeWalt | 165 ft Laser Distance Measurer, Black/Yellow - Floor & Decor(94.58, 37520)
# cds|C|6467954|US|en|2641f5cb5b4aa336:en_US , DeWALT 146929-01 Screw(94.58, 53500)
# cds|C|6467954|US|en|113ef1cf9b9d085a:en_US , DEWALT 14/18 TPI Band Saw Blades (3) | DW3986C | Acme Tools(94.48, 88595)
# cds|C|6467954|US|en|4b386c8970f50cab:en_US , Small Size Home Household Wood Working Turning Lathe Multifunction Infinitely Variable Speed Cutting Grinding Drilling Tools, Size: 50, Silver(94.47, 84595)
# cds|C|6467954|US|en|c2470483bb59f554:en_US , Dexter-Russell 6" Curved, Flexible Boning Knife, S131F-6PCP, SANI-Safe Series, White (01493)(94.46, 51910)
# cds|C|6467954|US|en|c0721e836d83a419:en_US , Can Am Defender Hd8 Hd10 Belt Removal Clutch Tool AC-CA-0686-0072(94.31, 62231)
# cds|C|6467954|US|en|b122d3ec8626b60d:en_US , S-21307 Tri-Functional Wide Bushing Adapter Alt(94.20, 30473)
# cds|O|144646454|US|en|06D0520 , Flexcut Whittler's Pocket Knife(94.11, 91045)
# cds|C|6467954|US|en|aa92c42ce6c01338:en_US , Milwaukee Chisel Bit: 1 in Head Wd, 12 in Overall Lg, 45/64 in Shank Dia Model: 48-62-4079(94.05, 98303)
# cds|C|6467954|US|en|d60d423b31f37095:en_US , Jewelry Making Workbench & Tools Set Bench Tools Rotary Tool with Flexible Shaft(93.93, 44642)
# cds|O|2663876|US|en|699472 , Schlage Commercial M204198 Boring Jig for AL or D Series Levers(93.92, 94500)
# cds|C|6467954|US|en|64751edd8b303100:en_US , 9998068 Flywheel Rotating Tool Alt(93.89, 4964)
# cds|C|6467954|US|en|4d37be8502d7d176:en_US , Bosch 12-Pack 5-in Plain High Speed Steel Scroll Saw Blade | SS5-46SPL(93.76, 56325)
# cds|C|6467954|US|en|3bc38a6deaed4269:en_US , Proto JSCV07 7/32 Reversing Combination Ratcheting Spline Wrench #7(93.70, 67329)
# cds|C|6467954|US|en|9a5eb61089b2be10:en_US , 20pcs Carbide turnning Inserts TCMT21.51 TCMT110204 Carbide Insert for Lathe Turning Tool Holder for Steel,Stainless Steel(93.50, 63585)
# cds|C|6467954|US|en|61cd1787729b5841:en_US , BMW E46 330xi M54 3.0L - CTA Tools BMW TDC Pin: Used for finding Top Dead Center when servicing a BMW engine.(93.36, 57276)
# cds|C|6467954|US|en|08b5a4420301cd2d:en_US , Amana Tool 658010-1-R Carbide Tipped R/H Outside Dado Blade 8 Inch D x 24T 1 Inch Bore(93.19, 80449)
# cds|C|6467954|US|en|93a242d254240644:en_US , Surly Jethro Tule, 15mm Socket/Bottle Opener(93.17, 16910)
# cds|C|6467954|US|en|d1e80bfc73072556:en_US , 10" x 80T Freud Industrial Plastic Blade (LU94M010) available at Rockler(92.95, 66051)
# cds|C|6467954|US|en|58d9a40a68282d82:en_US , Jonard Tools Ast-200 Cable Saber - Armored Mid-Span Cable Slit & Ring(92.37, 67060)
# cds|C|6467954|US|en|c9373492a965ec15:en_US , Parker 3/4" Max Cut Diam, 30 Ton Portable Hose Crimper - 30 sec Cycle, 12" Wide x 15" High x 6" Deep | Part #94C-002-PFD(92.36, 68072)
# cds|C|6467954|US|en|5cf95517d0495d14:en_US , Grip On 7" Axial Grip "l" Plier (epoxy) Gr91207(92.30, 17651)
# cds|C|6467954|US|en|48f79f5aac15625d:en_US , Goldengulf 16pcs/Pack Pretend Play Mini Construction Hardware Tool Keychain Toy Gift Assorted Designs DIY Creative Tool Car Keyring(92.14, 80417)
# cds|C|6467954|US|en|7923c1693d251e46:en_US , Pittsburgh 5-3/4 in. Needle Nose Pliers(92.11, 44988)
# cds|O|291426434|US|en|18053417629526042552622204 , Best Seller Milwaukee M18 FUEL 18-Volt Lithium-Ion Brushless Cordless Gen II 18-Gauge Brad Nailer (Tool-Only)(92.07, 28338)
# cds|C|6467954|US|en|bc9fa2ca686e6044:en_US , Kennedy 2600B Tool Chest Riser(91.68, 56909)
# cds|C|6467954|US|en|c2fa0b6eba306bbe:en_US , Biltwell EXFIL-0 Tool Roll(91.31, 69681)
# cds|O|241667459|US|en|DKK-TG70-SK , Japanese Boning Knife 7" - KYOKU Shogun Series(90.98, 78709)
# cds|C|6467954|US|en|cf740c4aedc38539:en_US , m18 X 1.5 HSS Plug Tap and 16.50mm HSS Drill Bit Kit, Qualtech(90.91, 87637)
# cds|C|6467954|US|en|b50c06247865c887:en_US , Makita XCU08Z | 18V X2 (36V) LXT Lithium-Ion Brushless Cordless 14" Top Handle Chainsaw (Tool Only) | Tyler Tool(90.89, 33629)
# cds|C|6467954|US|en|93eae9234f8e7cd2:en_US , Marshalltown Funny Trowel Adapter-Swivel, Product Type Adapters + Brackets, Model 4826(90.65, 62874)
# cds|O|8439803|US|en|100-036 , Leigh D4R+D24 Master Pack(90.56, 17078)
# cds|C|6467954|US|en|32e9b7d475d75be9:en_US , Neiko 02448A 1/2" Drive Master Impact Socket Set, 65 Piece Deep & Shallow Socket Assortment | Standard SAE (3/8-Inch to 1-1/4-Inch) and Metric (10-24(90.10, 38530)
# cds|C|6467954|US|en|d124ea296b236fa5:en_US , DeWalt OEM 5140103-20 replacement band saw tire DCS370 DCS371(90.07, 36496)
# cds|C|6467954|US|en|7fe04b73f739e2bb:en_US , Kitchenaid Food Grinder Blade 2 Pack, Ap5669553, Ps6883726, Wpw10408733(90.05, 65325)
# cds|C|6467954|US|en|5c09c214f6170ba6:en_US , Ryobi 10" Orbital Buffer- In Box Never Opened(89.55, 45755)
# ...
# cds|C|6467954|US|en|310edf1e908335ec:en_US , CLC 1 pocket Leather Hammer Holder 3.9 in. L X 5.8 in. H Tan(12.29, 33268)
# cds|C|6467954|US|en|5401da23d83fa81a:en_US , Ableware Raptor Reacher(11.96, 69863)
# cds|C|6467954|US|en|bf20c6fbd56cc5ca:en_US , Landscape Rake Independence Series(11.94, 99661)
# cds|C|6467954|US|en|26039131e4734a25:en_US , Milwaukee 4932464080 Packout Box 3 Toolbox System ( 2 X Boxes )(11.91, 36704)
# cds|C|6467954|US|en|547711c16f453b72:en_US , STREBITO Precision Screwdriver Set 124-Piece Electronics Tool Kit with 101 Bits Magnetic Screwdriver Set for Computer, Laptop, Cell Phone, PC,(11.88, 66019)
# cds|C|6467954|US|en|c7acc34713fd709a:en_US , StealthMounts EGO Battery Holders | Cordless Ego Power+ Battery Mounts | 4 Pack | EGO Power Plus Battery Organizers(11.85, 24951)
# cds|C|6467954|US|en|5d6d7bbf5e2a79bd:en_US , mkki 4" 100mm Angle Grinder Wall Bracket Tool Hook Holder Stand for 1-4 Angle Grinders(11.84, 6317)
# cds|O|10776|US|en|B1308792 , Import 5C Rotating Indexing Fixture(11.72, 5812)
# cds|O|388792255|US|en|US1920-02_2 , Jardineer 2" Anvil Loppers Shears - Gardening Loppers Heavy Duty with Garden Shears & Spare Blade, Effortless Pruning Tree Loppers(11.64, 1774)
# cds|C|6467954|US|en|e9fb7cea635012e6:en_US , Sp Scienceware Tapered Plug Sampler Model: H37826-0000(11.54, 19006)
# cds|C|6467954|US|en|f3d1472e46ab8590:en_US , EGO Power+ ST1620T 16 in. Battery String Trimmer Tool Only(11.51, 9685)
# cds|C|6467954|US|en|9307d42b07e68caf:en_US , Pieces be with you, Grande Groovin Piping Trimming Tool(11.48, 18399)
# cds|C|6467954|US|en|c8323635969c6540:en_US , Magnepull XR1000 Magnespot Reference Point Locator Kit(11.39, 94025)
# cds|C|6467954|US|en|84223e7b24d18616:en_US , Kings County Tools Traditional Maddock 2-in-1 Garden Tool | Hoe and Axe Combo | 42 Ash Handle | Carbon Steel Heads | German-Made Quality(11.37, 32401)
# cds|C|6467954|US|en|bb884f8cf35c80d4:en_US , Sunrise Commercial Grade Wok Shovel 16.75 inch (#3) & Ladle 16.75 inch (#3)) Set, Size: #3 (16.75 Large), Silver(11.36, 71424)
# cds|C|6467954|US|en|88734aafe587abb1:en_US , Norton 1/2 X 2 X 6 In. 3-In-1 Tool & Knife Sharpening System(11.36, 38024)
# cds|C|6467954|US|en|a29cd18661e2d0aa:en_US , HITACHI DH38YE2 Rotary Hammer, 120 V, 950 W, 1-1/2 in Chuck, Keyless Chuck, Black/Green/Silver(11.31, 29144)
# cds|C|6467954|US|en|2aa2347bf696c886:en_US , BOSCH RH540M 1-9/16" SDS-max Combination Hammer by FastoolNow(11.29, 38742)
# cds|C|6467954|US|en|15d63793318be18d:en_US , Fein 92035060090 Turbo I Wet / Dry Dust Extractor Set(11.23, 99106)
# cds|O|441318628|US|en|TOOLTOTEBLK , 8" X 8" HD Tool Tote Black(11.21, 59041)
# cds|C|6467954|US|en|2872191e882e978b:en_US , WHDZ Paintless Dent Repair Rods Auto Body Dent Removal Tools 10pcs Auto Car Body Paintless Dent Repair Dent Puller Dent Hammer Tap Down(11.14, 46283)
# cds|O|132533|US|en|154921 , Ryobi 030157001013 Bearing Cap Assembly(11.14, 45763)
# cds|C|6467954|US|en|bf4a88d28cd20651:en_US , Klein 200028EINS Insulated Slim-Handle Diagonal Cutting Pliers(11.10, 63086)
# cds|C|6467954|US|en|69b1c68ea897d6d1:en_US , Bosch 25618-02 18 Volt Li-ion 1/4-hex Cordless 18v Impact Driver Kit(11.10, 47219)
# cds|C|6467954|US|en|c234b6f1da492616:en_US , Rack'em RA7 6-Hook Multi Tool Rack(11.06, 88790)
# cds|C|6467954|US|en|a61ec890abe7656e:en_US , Hose Removal Hook Pick Set, 10" Hose Hook, 8" Hose Remover, Hose Puller Tool for Radiator Hoses, VASTOOLS(11.04, 39231)
# cds|C|6467954|US|en|ac203052d66e7fc1:en_US , Snapper XD 82V MAX Cultivator Attachment with Adjustable Tilling Width, Compatible with Snapper XD String Trimmer(10.97, 31085)
# cds|O|9769319|US|en|lr3460 , Corona Long Reach Cut and Hold Pruner LR 3460(10.88, 42232)
# cds|O|130220265|US|en|shopify_US_6836339146928_40417273381040 , Gate Remover Set(10.86, 92061)
# cds|C|6467954|US|en|7367e101cbc5b2e9:en_US , Pull Start Recoil Carburetor Set Replacement for Predator 212cc 6.5hp OHV Engine(10.79, 22617)
# cds|C|6467954|US|en|5d14d3c597cffe3e:en_US , 1pc Gundlach 611 Lil Squeezy Carpet Stretcher(10.77, 18448)
# cds|C|6467954|US|en|5093ca490b5d3389:en_US , Room & Board | Modern Roan Wall-Mounted Magnetic Knife Holder . in Slate Blue 20w .5d 3h(10.74, 52746)
# cds|O|142087827|US|en|shopify_US_6119626342553_37947389771929 , Mr. Fix It Tool Bouquet | Gift Idea for Dad, Husband, Boyfriend(10.71, 78962)
# cds|O|6421244|US|en|120803307782 , 21 Pc Eye Micro Minor Surgery Surgical Opthalmic Instrument Student(10.67, 33769)
# cds|C|6467954|US|en|2660c97c606b82ef:en_US , Jonas of Sweden 38404 Adult Red Plastic Comb Berry Picker - 8 1/2" x 5 1/2"(10.64, 8122)
# cds|O|114711376|US|en|192468736507 , Milwaukee 48-22-1920 Duct Knife, Full Tang, Double Edged Blade ( Lot(10.58, 21078)
# cds|C|6467954|US|en|1270a5d788cca965:en_US , Milwaukee 48-22-2706 Screwdriver Kit, 6-Piece(10.55, 52867)
# cds|O|6296724|US|en|393546869690 , Dental Tool 10 Pack Professional Plaque Remover Teeth Cleaning Tool(10.51, 71714)
# cds|C|6467954|US|en|de18230a6182d6a7:en_US , Dead Ringer Arrow Puller(10.46, 37327)
# cds|C|6467954|US|en|4525d347eea17c21:en_US , LifeLine Home Mechanic Workstand inc. Mat - Gold(10.38, 49041)
# cds|C|6467954|US|en|069eced4660dee3a:en_US , Blue Sea 8293 Contura Actuator Removal Tool(10.37, 18182)
# cds|C|6467954|US|en|8b5475ce0519eda7:en_US , Klein Tools Tool Pouches, 11 Compartment, Black, Leather, Belt Slot, 1/EA, #5167 | AFT Fasteners(10.31, 24815)
# cds|C|6467954|US|en|bc621e5eeae6204c:en_US , Monteverde Tool 0.9mm Pencil - Brass(10.23, 16538)
# cds|C|6467954|US|en|b1748dc05bf1aefa:en_US , Bambu Wok Spatula(10.22, 99234)
# cds|C|6467954|US|en|fe6fb6f7199a5969:en_US , Cuda Universal Lanyards, 2-Pack | For Fishing(10.16, 38245)
# cds|C|6467954|US|en|b7f2fce5417ae9f1:en_US , Fiskar Paper Crimper Tool, #9340, Fits Paper 6.5" Wide, Wavy Paper(10.12, 60901)
# cds|C|6467954|US|en|21fc81882ea48107:en_US , Center Pin Punch Automatic Center Strike Spring Loaded Window Breaker Drilling Marking Tool, Black, without Cap, Size: 130 mm(10.11, 83992)
# cds|O|501595024|US|en|shopify_US_5111236526213_34416780247173 , Extreme Reamer X-Large(10.08, 35099)
# cds|C|6467954|US|en|5d22502cb0f6f29c:en_US , The Pocket Scientist - Wallet Science Ruler Scale and Unit Conversion Reference 3 inch(9.99, 31938)
# cds|O|117171671|US|en|690401552 , Channellock 430 Plier Holder(9.98, 52263)
# cds|C|6467954|US|en|8869d898225b16bd:en_US , Spanner Nut Tamper-Proof Security Screwdriver(9.98, 32309)
# cds|O|127676668|US|en|95-362-Pack-of-1 , Sklar Surgi-OR Vaginal Speculum Pederson NonSterile Mid Grade Stainless Steel Large Double Blade Duckbill Reusable Without Light Source Capability -(9.98, 79535)
# cds|C|6467954|US|en|94370ad8fb930b8d:en_US , Silicon Carbide Flexible Cylinder Hone, Coarse Grade, 120 Grit(9.92, 8047)
# cds|O|258354524|US|en|LCLAMP8511 , Precision Clamping Squares 90 Degree Right Angle Clamps(9.89, 66752)
# cds|C|6467954|US|en|a7a32cdde23a54b9:en_US , Estes 302227 Tube Marking Guide(9.88, 51512)
# cds|C|6467954|US|en|7341f5cf688ffd73:en_US , Bartender's Hammered Solid Copper Cocktail Shaker Set(9.86, 84503)
# cds|O|11022734|US|en|223300521187-MTY1-155-903 , 155-903-Telescoping Gage Set SERIES 155 (MITUTOYO) | Misumi(9.84, 46037)
# cds|C|6467954|US|en|83484922d810747e:en_US , Omc Johnson Evinrude Outboard Needle Bearing Grease Assembly Lube(9.79, 56351)
# cds|C|6467954|US|en|89b39e3e03590be2:en_US , Mag-Mate Tplp30 Magnetic Part Handler,2.48Inhx3Inlx3Inw(9.77, 2100)
# cds|O|7654024|US|en|shopify_US_313208609_32077187252273 , Sure Design Thai Wooden Massage Tool 03 1-Size / Wood(9.73, 86094)
# cds|C|6467954|US|en|d9864f36aabb52e8:en_US , CNCEST High Quality Portable Fiber Optic Tools Kits-18PCS(9.69, 93022)
# cds|O|8760422|US|en|shopify_US_6999980081333_41989116100789 , Fire Hose Spanner Wrench (2-Pack)(9.68, 69248)
# cds|C|6467954|US|en|1252d54b9fcf668b:en_US , Solo 200 Alarm & Detector Removal Tool, Flat or Angled Ceilings(9.68, 74277)
# cds|C|6467954|US|en|608005b02c8b3c2a:en_US , Jims USA Compensator Nut Torx Socket Harley Davidson FLRT Freewheeler 2015-2016(9.62, 74820)
# cds|C|6467954|US|en|a75b993e31a6f776:en_US , Adjustable Operating Wrench, 60 to 108 in(9.58, 90333)
# cds|C|6467954|US|en|d85b3a670da004b6:en_US , 80C-A16 - PARKER(9.55, 784)
# cds|O|115809258|US|en|RDI36 , 36" Double Bend Interchangeable Tip Rod(9.52, 84262)
# cds|C|6467954|US|en|ce418631b43fe03e:en_US , HHIP 3129-0015 1/2 Inch Shank Knee Feed Adapter for Power Drill(9.45, 53284)
# cds|O|138357567|US|en|403076218402 , Lathe Vertical Milling Slide Attachment Fixed Base Myford 7 Series(9.37, 87842)
# cds|C|6467954|US|en|6337dcd82cc48568:en_US , Dino-Lite MS23B Articulating Flex-arm Clamp, Designed for Dino-Lite(9.37, 19928)
# cds|C|6467954|US|en|ffd777bce430be3d:en_US , Yiranok HVAC Tools - Copper Tube Expander for Air Conditioner and Heater Equipment - Pipe Swaging Tool Hand Drill Accessories - 1/4'', 3/8'', 1/2'',(9.31, 55253)
# cds|O|11349283|US|en|AM-Z-010 , Tornador Professional Cleaning Tools Tornador Classic Z-010(9.26, 83120)
# cds|O|299611441|US|en|121957 , Deluxe Rivet Cutter Deluxe Rivet Cutter(9.15, 10901)
# cds|C|6467954|US|en|f2edf1aaef7d8d03:en_US , QEP 29185114 Laminate/Wood Floor Installation Kit(9.08, 70070)
# cds|O|3768652|US|en|TTT-XXL-MCT , Veto Pro Pac TP-XXL Meter Pouch and TECH-MCT Tool Bag Combo(9.06, 38550)
# cds|C|6467954|US|en|1516bae824d60b22:en_US , Firstline Evolve Loc & Twist Starter Kit(8.98, 1268)
# cds|O|8049|US|en|42242 , Klutch 2Inch Non-Woven Abrasive Pads — 4-Pack, with 1/4Inch Round Shaft Quick Connector(8.94, 26064)
# cds|C|6467954|US|en|0c29d8b693de5318:en_US , Bon 12-357 Dirt Tamper - 10 inch X 10 inch - 48 inch Wooden Handle(8.93, 3212)
# cds|O|4159258|US|en|tl0008 , Piercing tool Kit with essential tools to pierce with Leather case Made of Surgical Steel(8.93, 8383)
# cds|O|113677249|US|en|473919541694_174740468518 , Flexible Head Metric Tubing Ratchet Wrench Repair Tool Open End(8.92, 35671)
# cds|C|6467954|US|en|4b1dcd3fd068d7f1:en_US , Occidental Leather 8068 Impact, screwgun and Drill Bag(8.91, 6215)
# cds|C|6467954|US|en|1cb9127a937e5c00:en_US , TapeTech QuickBox QSX 6.5" Finishing Box(8.89, 79619)
# cds|C|6467954|US|en|c412b73e1125629f:en_US , VEVOR Tire Dolly Wheel Dolly 300 Lbs Capacity Truck Tire Wheel Dolly Heavy Duty Cart(8.87, 25967)
# cds|C|6467954|US|en|83993ae52c10297f:en_US , Rockler Dixon Reach Deep-Hole Mechanical Pencil with 12-Pack Lead Refills(8.86, 96216)
# cds|C|6467954|US|en|d181c61f00d3ea46:en_US , Sorby Scraper, Box - Woodcraft(8.86, 72374)
# cds|C|6467954|US|en|3fddd6b8adef041a:en_US , Latauar Croissant Cutter, Stainless Steel Croissant Roller Slices with Wooden Handle Perfect Shaped Pastry Dough, Rolling Knife Kitchen Baking Tool.(8.86, 22650)
# cds|C|6467954|US|en|a0fff59b946f1ee4:en_US , black decker rtx-1 rotary tool for 220 volts(8.86, 10824)
# cds|C|6467954|US|en|32db9c77f3dd6713:en_US , Music Nomad MN610 Neck Relief Kit Taylor Guitars(8.85, 30287)
# cds|O|522529553|US|en|402814332981 , Vinyl Lp Turntable Alignment Protractor Tool For Record Player(8.85, 89321)
# cds|C|6467954|US|en|a7946bbbf24d78f3:en_US , Gerber Gear Processor - Salt Scissors in Steel(8.84, 26005)
# cds|C|6467954|US|en|40282cfe8a1386e7:en_US , Garage Hooks, 19 Pack Heavy Duty Garage Storage Hooks Steel Tool Hangers for Garage Wall Mount Utility Hooks and Hangers with Anti-Slip Coating for(8.81, 96523)
# cds|C|6467954|US|en|906a1df4295dc778:en_US , CRAFTSMAN Plastic Socket Storage in Black | CMMT99415(8.78, 23358)
# cds|C|6467954|US|en|1d875539e7dd23e1:en_US , Starrett Gauge Rod - 6 in Length - 1/4 in Wide - 657X(8.73, 18899)
# cds|C|6467954|US|en|9bc53e0a912b7c74:en_US , CASOMAN 5/8" Swivel Magnetic Spark Plug Socket, 3/8" Drive x 8-Inch Ext. Bar Length, 360 Degree Swivel, Enhanced Magnetic Design, 6 Point, Cr-V Steel(8.69, 54609)
# cds|C|6467954|US|en|1d06046abf018c19:en_US , Dewalt 8 ft 500 lb Load Capacity Fiberglass Stepladder Model: DXL3810-08(8.68, 52686)
# cds|C|6467954|US|en|696a73a7bb666e8b:en_US , 4 Way Wood Rasp File, Premium Grade High Carbon Hand File and Round Rasp, Half Round Flat & Needle Files. Best Wood Rasp Set for Sharping Wood and(8.65, 78064)
# cds|C|6467954|US|en|2ef16cd04f317757:en_US , SUNEX TOOLS Sunex 1889 1/4 in., 3/8 in., and 1/2 in. Drive SAE and Metric Master Chrome Socket Set (89-Piece)(8.64, 51452)
# cds|C|6467954|US|en|6551d543424e4a4e:en_US , Aurand - KP5V Pneumatic 5" Surface Scaler, Vac(8.63, 79333)
# cds|C|6467954|US|en|67cefd2e03b5524a:en_US , Make Your Own Kitchen Tools: Simple Woodworking Projects for Everyday Use by Picciuto, David - Alibris Books, Music & Movies(8.56, 37868)
# cds|O|259719927|US|en|shopify_US_4390334103630_31625600106574 , Spring Steel Gripper Clip - Half Vinyl Coated - 3/4"-1 1/8 (#225-HL) 25 pcs(8.48, 35688)
# cds|C|6467954|US|en|d519e5cae30aa58d:en_US , Stanley Jr. Pull-Back Airplane Kit(8.48, 76509)
# cds|C|6467954|US|en|53d8015f30b5ed56:en_US , Anytime Tools Angle Block Set 1°, 2°, 3°, 4°, 5°, 10°, 15°, 20°, 25°, 30° Precision +/- 20 Seconds, Machinist Tool, 10 Piece Set(8.47, 87448)
# cds|O|101640084|US|en|194233254342 , Lego Gray Brick Separator Vintage, Great Condition(8.44, 37119)
# cds|O|100572154|US|en|082-BE400 , E-Z Trench EZ Trench BE400 Bedscaper Bed Edger 6.5HP Honda Engine(8.37, 38086)
# cds|C|6467954|US|en|a049dee08b783ffe:en_US , Tweezerman Blackhead Extractor(8.34, 64331)
# cds|C|6467954|US|en|bf99b0906a1a437b:en_US , Milwaukee 48-22-8271 Heavy Duty Canvas Utility Bucket w/ 75 lbs Weight Capacity(8.31, 4861)
# cds|C|6467954|US|en|9a2dbefe9e6b86bd:en_US , Autel TPMS Relearn Tool TS408, 2022 Upgraded of Autel MaxiTPMS TS401, Tire Pressure Monitor Sensor Programming and Rest Tool for All Cars, TPMS(8.29, 55784)
# cds|C|6467954|US|en|79e957ba32392eb3:en_US , ToolkitRC M6D 500W 25A 1-6S Dual Channel DC Smart Charger(8.24, 24238)
# cds|C|6467954|US|en|c9a19a7bcd839026:en_US , Roberts 10-28 Flooring Installation Kit Flooring Install Kit 4 Boxes(8.21, 66363)
# cds|C|6467954|US|en|b9b62e8d0b23b697:en_US , 1210 Semi Trailer Air Brake Testing Tool(8.20, 82136)
# cds|O|487168117|US|en|shopify_US_7146485186729_41048967872681 , Golf Club Groove Sharpener, Re-Grooving Tool and Cleaner for Wedges & Irons(8.19, 70295)
# cds|O|128026611|US|en|HRP24BH-HA-RP24 , Rock Picks - 24oz Hammer - Carbide Bushing Head & Blade - 12in (30cm) Wood Handle(8.12, 36984)
# cds|O|8156927|US|en|98NHO26-1 , Mayo Hegar Needle Holder, 5", Economy - Needle Holders(8.09, 44337)
# cds|C|6467954|US|en|8c2ecba89fbf3d91:en_US , Westward Screw Extractor: Spiral Flute, 17/32 in Drill Size, For 1" to 1-3/8" Bolt Size Model: 2RUP5(8.09, 10628)
# cds|C|6467954|US|en|763aa1658f3fb254:en_US , 4-inch Molding Flap Sanding Wheel Kit For Drill Press, Pack Of 3, 80, 120, 240 Grit(8.07, 66058)
# cds|C|6467954|US|en|6d3040c5f8ffcfbf:en_US , TRU TENSION MEGA TOOL BUNDLE 19 - 59-2806(7.96, 69613)
# cds|C|6467954|US|en|19f2b964884de27b:en_US , Zircon MT7 Metalliscanner - Metal Scanner Detector Locator Zircon(7.95, 63079)
# cds|C|6467954|US|en|59f2603247de0781:en_US , Freeman P2PFK14 Professional Pneumatic Flooring Nailer Kit with Fasteners (2-Piece) L-Cleat Flooring Nailer, 4-in-1 Mini Flooring Nailer and Stapler(7.95, 93460)
# cds|O|242947|US|en|406-62006 , Tanner Racing Products 62006 AN Wrench -6AN (11/16")(7.93, 91429)
# cds|C|6467954|US|en|177533965f56bb8a:en_US , Zurn Z1180-2IP Solids Interceptor, 15gpm (2-inch Inlet/Outlet)(7.93, 57049)
# cds|C|6467954|US|en|dab210c273bd9b23:en_US , Sioux Tools 1/4" Capacity, Air Riveting Hammer - 8 CFM, 4" Long Stroke, 1/4 NPT Inlet | Part #270A-4(7.92, 46839)
# cds|O|285493498|US|en|5f6aaec6b475e90049e01b01 , Facial Hair Remover Hair Spring Threading Epilator Lip Eyebrows Smooth Removal(7.89, 47789)
# cds|C|6467954|US|en|61f4d4de0de2b0bd:en_US , Corner Rounder Mini Punch Set - EK Success - Punches(7.89, 31986)
# cds|C|6467954|US|en|34faf1273caed3f8:en_US , Foundation | Bench/Wall Mount Repair Stand 360 Rotation, Bench or Wall Mounting(7.89, 86315)
# cds|C|6467954|US|en|991e3780ea3026be:en_US , Toledo Pipe 42360 1206 Stand fits RIDGID 41855 300 Power Drive(7.89, 46033)

# %%
temp  = sp.load_npz(f'Results/ELIAS/ShoppingAds-100K/Stage-1-0/A_init.npz')

# %%
temp.getnnz(1)
# Out:
# array([1175, 1280, 1083, ..., 1267, 1201,    0], dtype=int32)

# %%
sp.save_npz(f'Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0-qbst/A_init.npz', A_init)

# %%
A_nnz = A_init.getnnz(0)

# %%
print(get_text(0, Y, A_init, K=10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6787/4242158411.py in <module>
# ----> 1 print(get_text(0, Y, A_init, K=10))
#
# NameError: name 'Y' is not defined

# %%
A_init = sp.load_npz(f'Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0-qbst/A_init.npz')

# %%
A_nnz = A_init.getnnz(0)

A_norm_init = A_init.copy()
A_norm_init.data /= A_nnz[A_norm_init.indices]

# %%
top1k_A_init = retain_topk(A_norm_init, k=1000)

# %%
sp.save_npz(f'Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0-qbst/A_init.npz', top1k_A_init)

# %%
top1k_A_init.getnnz(1).mean()
# Out:
# 999.5545383107124

# %%
np.where(top1k_A_init.getnnz(0) == 0)[0].shape
# Out:
# (31652,)

# %%
cmat = sp.load_npz(f'Datasets/ShoppingAds-10M-v2/cmat-131072x100-0.npz')

# %%
nnz = trn_X_Y.getnnz(0)

# %%
Y = [x.strip() for x in open(f'{DATA_DIR}/raw-orig/Y.txt').readlines()]

# %%
def vispoint(x, spmat, X, Y, stats, true_mat=None, sep='', K=-1, expand=False, trnx_nnz=None):
    if K == -1: K = spmat[x].nnz
    if true_mat is None: true_mat = tst_X_Y
        
    sorted_inds = spmat[x].indices[np.argsort(-spmat[x].data)][:K]
    print(f'x[{x}]: {_c(X[x], attr="bold")}\n')
    for i, ind in enumerate(sorted_inds):
        myattr = ""
        if true_mat[x, ind] > 0.1: myattr="yellow"
        print(f'{i+1}) {_c(Y[ind], attr=myattr)} [{ind}] ({"%.4f"%spmat[x, ind]}, {stats[ind]})')
        if expand:
            for j, trn_ind in enumerate(trn_Y_X[ind].indices[:10]):
                print(f'\t{j+1}) {_c(trnX[trn_ind], attr="green")} [{trn_ind}] ({trnx_nnz[trn_ind]})')
        print(sep)

# %%
A_nnz = A_init.getnnz(0)

# %%
norm

# %%
vispoint(10000, A_init, Y, Y, nnz, cmat, K=100);
# Out:
# x[10000]: Mama Bracelet | Do Good for Mamas | Larissa Loden Gold Filled / Large
#
# 1) Sulcophanaeus achilli pair male female ONE Real Green scarab dung beetles packaged [7654068] (100.7304, 51)
#
# 2) Dermestid Beetle Culture Kit [4416008] (100.4592, 51)
#
# 3) Dynastes granti male One REAL hercules rhinoceros beetle Arizona Unmounted packaged [3055133] (100.3330, 51)
#
# 4) Boneyard Beetleworks Dermestid Beetle Colony - Qty. 700+ (1 Volume [7619028] (100.2541, 51)
#
# 5) Dermestid Beetles [417999] (99.5812, 51)
#
# 6) 2 x A2 Empress Cicadas DAMAGED WING TIPS | Megapomponia imperatoria A1 | Entomology Taxidermy [4168700] (99.3469, 51)
#
# 7) Green Lacewing Eggs - Hanging Cards - 25,000 Eggs on Cards | Pest BioControl Solution | Beneficial Organism | ARBICO Organics [2876855] (99.3220, 51)
#
# 8) Chafer Beetle in Resin, Insects in Resin, Green Beetle, Curiosities [301777] (99.1953, 51)
#
# 9) Texas Beetle Guide, 64 Photo Prints (size 4x6") [5299722] (98.1456, 51)
#
# 10) (best Deal) Buffalo Beetle Cleaner Crew / Larvae Mix 150/250/ Qtys [5495510] (97.7597, 51)
#
# 11) Meet The Beetles Entomology Lithograph Chart Natural History Print 1928 [6820914] (97.6991, 51)
#
# 12) Florida Beetle Guide, 64 Photo Prints (size 4x6") [9421113] (97.6861, 51)
#
# 13) Tennessee's Finest Brood X Cicada Shells [5952094] (97.5098, 51)
#
# 14) Torynorrhina flammea green form One Real scarab beetle Thailand [7519933] (97.4909, 51)
#
# 15) Insects Stag Lucanus Beetle Animals Wildlife-20 Inch By 30 Inch Laminated Poster With Bright Colors And Vivid Imagery-Fits Perfectly In Many [774186] (97.3490, 51)
#
# 16) Metal Poster Displate Collection Of Rare Beetles with magnet mounting system included [1269544] (97.3188, 51)
#
# 17) Potato Bug Classic Round Sticker - Custom Stickers - Make Your Own Personalized Decorative Decals [5546414] (97.0528, 51)
#
# 18) Lladro Rhinoceros Beetle Sculpture [9793034] (96.7433, 51)
#
# 19) Lladró Beetle Hercules [6977263] (96.7281, 51)
#
# 20) Pack of 4 scarab beetles ( 2male/2female) Phanaeus vindex 20/25mm UNMOUNTED A1 for all your taxidermy art projects [9513255] (96.3473, 51)
#
# 21) Rare Rainbow Stag beetle framed taxidermy - Phalacrognathus muelleri - female [4805418] (96.2254, 51)
#
# 22) Huge Hercules Beetle Fighting Scarab Iron on Patch Dynastes hercules [5095916] (96.2045, 51)
#
# 23) 'Insectes I' Graphic Art Print,Poster McGaw Graphics Size: 19" H x 13" W x 0.125" D [1505023] (96.1775, 51)
#
# 24) Loxa flavacollis REAL green shield bug beetle Louisiana USA [1892564] (96.1398, 51)
#
# 25) Cicadas - from France - Original Louis Sicard Large [8260354] (95.6609, 50)
#
# 26) Beetles - Coleoptera #2 - 1885 - Insect Illustration Poster - 8.5" x 11" [5438602] (95.5237, 51)
#
# 27) Green Lacewing Eggs - Hanging Cards - 5,000 Eggs on Cards | Pest BioControl Solution | Beneficial Organism | ARBICO Organics [3753609] (95.4319, 51)
#
# 28) Xxl Goliath Beetle, A1 Giant Male 90-95 Mm+ D.r.congo / Cameroon [207104] (95.4199, 51)
#
# 29) Assorted Bugs and Beetles! Cool insect species from around the world! [5569325] (95.2265, 51)
#
# 30) College Level School Entomology Insect Bug Specimens Choose Species [4959027] (95.1152, 51)
#
# 31) Colorful Beetles - Not Foodsafe - Glass Fusing Decal, Ceramic Decal, Enamel Decal [1865305] (95.0261, 51)
#
# 32) Real Insect Specimen Beetle Unicorn beetle Scarab Flat Stag beetle Student Observation Teaching DIV [1093919] (94.9708, 51)
#
# 33) Green Lacewing Eggs - 5,000 Eggs | Pest BioControl Solution (Aphids, Spider Mites + More) | Beneficial Organism | ARBICO Organics [2145613] (94.9170, 51)
#
# 34) Mixed Bugs Beetles & Other Insects | Mystery Box of Ethical Unmounted Taxidermy Specimens [6945991] (94.6431, 51)
#
# 35) Green Lacewing Eggs - Insect Controls | Gardener's Supply Company [6559286] (94.4586, 51)
#
# 36) Insect Killing Jar, 9 oz, Bioquip Products [3186901] (94.3279, 51)
#
# 37) Entomology Specimens - Canvas Print Wall Art by Natural History Museum (UK) ( animal art > insects > beetles art) [521188] (94.0988, 51)
#
# 38) Japanese Beetle print [7833862] (93.9142, 51)
#
# 39) Beetles And Water Beetles Original Double Sided Print From 'A Field Guide To The Insects Of Britain And Northern Europe' 1973 [2413823] (93.6547, 51)
#
# 40) LLADRO Awesome Insects Hercules Beetle Figurine [897038] (93.6386, 51)
#
# 41) Insects Of The World [8145321] (93.4973, 51)
#
# 42) Real large Rhinoceros beetle framed taxidermy - Eupatorus gracilicornis [3969805] (93.4270, 51)
#
# 43) Insects Education Poster 21x33 [4454205] (92.8939, 51)
#
# 44) Beetle Collection Poster (6" x 8") by Kelly King [6850748] (92.2991, 51)
#
# 45) Insects - Chart 2 - 1898 - Illustration Poster [8954333] (92.1696, 51)
#
# 46) Rare Eggs Of Leaf Insect Phyllium Philipphinicum X25 [7631625] (92.0330, 51)
#
# 47) Small Beetles Mix, 65 From West Kalimantan [1378219] (92.0178, 51)
#
# 48) Poster: Poster: Beetle Poster, 36x24in. [553025] (91.9201, 51)
#
# 49) Beetles Original Vintage Double Sided Print From 'A Field Guide To The Insects Of Britain And Northern Europe' 1973 [943590] (91.8045, 51)
#
# 50) 1916 BARK & SKIN BEETLES Antique Lithograph, Insect Art Print, Entomology, Natural History, Cucujoidea, Dermestidae [6352130] (91.4584, 51)
#
# 51) Bug June Bug Flying Insect Insect Beetle-12 Inch BY 18 Inch Laminated Poster With Bright Colors And Vivid Imagery-Fits Perfectly In Many Attractive [7656094] (91.1996, 51)
#
# 52) SVG Insects, Black silhouette, Digital clipart, Files eps, jpg, Insects Design vector, Instant download svg, png, dxf for Cricut [6325750] (91.0651, 51)
#
# 53) Beetles Collection, Biorama Preparation [5958684] (90.4877, 51)
#
# 54) Earwig : Amazing Facts about Earwig (Paperback) [2681640] (90.4632, 51)
#
# 55) The Beetle-Hunter - Audiobook [8464133] (90.3707, 50)
#
# 56) USA Beetle Guide, 64 Photo Prints (size 4x6") [1260439] (90.3502, 51)
#
# 57) Lacewings, 2,500 Count in Green | Gardener's Edge [9990498] (90.2848, 48)
#
# 58) 50 Dead Bugs Entomology Class Insect Bug Collection Identified All Usa [3442691] (90.0243, 51)
#
# 59) Insect Identification Educational 24 in x 36 in Posters, by Feenixx, Size: 24.5 x 36.5 Laminated [2030622] (89.7863, 51)
#
# 60) 100pcs Insect Pins Specimen For School Entomology Best Lab Steel Disse [1764265] (89.6564, 51)
#
# 61) 1948 Insects Original Vintage Print - Entomology - Butterflies - Beetles - Crickets - Bees - Flies - Grubs Mounted and Matted - Wall Décor [8961296] (89.5824, 51)
#
# 62) Black Buffalo Beetles - Cleaner Crews For Dubia Roaches - Ships Same [5192987] (89.4888, 49)
#
# 63) Lamprima adolphinae mounted wings spread REAL framed green beetle [294102] (89.4714, 51)
#
# 64) Insect Biodiversity: Science and Society Volume 1 [4919625] (89.2447, 51)
#
# 65) 100 Dead Bugs Entomology Class School Insect Bug Collection Identified [3151955] (89.2103, 51)
#
# 66) Lacewings, 1,000 Count in Green | Gardener's Edge [9948574] (89.1648, 51)
#
# 67) Beetles - Coleoptera #2 - 1885 - Insect Illustration Poster, 13" x 19", Posters, by Poster-Rama [9302846] (89.1161, 51)
#
# 68) Assorted beetles bugs insects Wholesale Mix Lot Collection Choose 1, 5, 10, 25, or 50 pieces [6745206] (89.0823, 51)
#
# 69) Green Lacewing Eggs - Hanging Cards - 10,000 Eggs on Cards | Pest BioControl Solution | Beneficial Organism | ARBICO Organics [9355960] (88.9826, 51)
#
# 70) Pack of 5 jewel beetles Belionota tricolor , for all your photography and taxidermy art projects [3889859] (88.8531, 51)
#
# 71) HUGE Phyllium giganteum, World's Largest Leaf Insect! +140mm GIANT BUG! [7977184] (88.6969, 51)
#
# 72) Real metallic Scarab beetle framed taxidermy - Rhomborrhina resplendens chatanayi [8252189] (88.6653, 51)
#
# 73) Assorted beetles bugs insects Wholesale Mix Lot Collection Choose 1, 5, 10, or 50 pieces [8142749] (88.2901, 51)
#
# 74) Trays Of Various Beetle Specimens - Natural History Museum (UK) Canvas Wall Art Print ( animal art > insects > beetles art) [1291214] (88.1743, 51)
#
# 75) Giant black & white flower beetle Goliathus orientalis Unmonted for artwork, taxidermy project and insect collection. [4351007] (88.1531, 51)
#
# 76) Chafer Beetle Wings Open, Green Beetle in Resin, Curiosities [2464205] (87.8386, 51)
#
# 77) Learning About and Living With Insects of the Southwest: How to Identify Helpful, Harmful and Venomous Insects (New Condition) [2086509] (87.8180, 51)
#
# 78) Real 5 Horned Beetle/ Eupatorus Gracilicornis Flying Form Taxidermy in Transparent Box Display (Black Wooden Box) [9464483] (87.6749, 51)
#
# 79) Poster: Poster: Insects & Bugs Charts Poster, 36x24in. [6023424] (87.6494, 51)
#
# 80) June Beetle on Stand Black, Dark Green, Black/Dark Green, Figurines, by Zentique [7945895] (87.5787, 51)
#
# 81) Green Lacewing 1000 Eggs - Good Bugs - Aphid Exterminator By The [4379745] (87.2524, 51)
#
# 82) Beetles - Poster [7266073] (87.1545, 46)
#
# 83) Large Jewel Scarab beetle framed taxidermy - Chrysina victorina [405996] (87.1290, 51)
#
# 84) 51 Insect SVG / Insect Bundle SVG / Cricut / Cut Files / Clipart / Silhouette / Printable / Vector [9077819] (87.0544, 51)
#
# 85) OVERSTOCK: Mixed Real Beetles, Package of 5 [4761091] (86.9738, 51)
#
# 86) Insect Identification Chart non-laminated [739678] (86.7073, 51)
#
# 87) 35+ Dead Bugs Entomology Class Insect Bug Collection Identified Usa In [7171230] (86.4524, 51)
#
# 88) Coleoptera: Beetles [3711201] (86.4122, 51)
#
# 89) Large Scarab beetle framed taxidermy - Mecynorrhina polyphemus confluens [8241544] (86.2480, 51)
#
# 90) ABDragons Black Cleaner Beetles Small Pet & Reptile Food, 1000 count [9698461] (86.1225, 51)
#
# 91) Book of Beetles : A Life-size Guide to Six Hundred of Nature's Gems [340930] (85.4399, 51)
#
# 92) New York Puzzle Company - Vintage Images Insects ~ Insectes - 1000 Piece Jigsaw Puzzle [8904114] (84.9331, 51)
#
# 93) LLADRO Rhinoceros White Beetle - White [9197302] (84.8843, 51)
#
# 94) Insect Identification Educational Decorative Chart Poster 24 X 36 Free [5005156] (84.8727, 51)
#
# 95) 5pcs Garden Ornaments Animals Simulation Cicada Insect Decor Refrigerator Magnets for Home Outdoor Decoration Landscape Education Model Toys Mixed [8099550] (84.7044, 51)
#
# 96) moks186 large insect patch - beetle horn [6006009] (84.5871, 51)
#
# 97) Bugs, Bees, & Beetles - Gallery Wrapped Canvas Art 28" x 42", Posters, by Buyenlarge.com, Inc. [135859] (83.9581, 51)
#
# 98) Real green and red scarab beetle framed taxidermy - Dicronorhina derbyana [8344678] (83.4141, 51)
#
# 99) Bug Identification Log Book For Kids: Bug Activity Journal, Insect Hunting Book, Insect Collecting Journal, Backyard Bug Book, Kids Nature Notebook [9701964] (82.9617, 51)
#
# 100) Weevils of All SIzes / Beetle Mosaic / Composition / Curculionoidea [4012851] (82.4699, 51)

# %%
def gen_A_init(net, trn_embs, trn_Y_X, kappa, device='cpu', bsz=100000):
    trn_tensor_embs = torch.tensor(trn_embs).to(device)
    M_indices = []; M_values = []
    with torch.no_grad():
        for ctr in tqdm(range(0, trn_tensor_embs.shape[0], bsz)):
            res = torch.mm(trn_tensor_embs[ctr:ctr+bsz], net.w1.weight.T.to(device)) + net.w1.bias.reshape(1, -1).to(device)
            res = torch.clamp(net.alpha*F.softmax(res, dim=1), min=0, max=1)
            temp = res.topk(net.beam, dim=1)
            M_indices.append(temp.indices)
            M_values.append(temp.values)

    M_indices = torch.vstack(M_indices)
    M_values = torch.vstack(M_values)

    numx = M_indices.shape[0]
    K = M_indices.shape[1]
    data_bin = np.ones(numx * K) 
    data_val = M_values.reshape(-1).cpu().numpy()
    inds = M_indices.reshape(-1).cpu().numpy()
    indptr = np.arange(0, numx*K + 1, K)
    shape = (trn_embs.shape[0], net.w1.weight.shape[0])
    
    M_bin = sp.csr_matrix((data_bin, inds, indptr), shape)
    M_val = sp.csr_matrix((data_val, inds, indptr), shape)
    C_bin = trn_Y_X.dot(M_bin)
    C_val = trn_Y_X.dot(M_val)

    CT_bin = C_bin.T.tocsr()
    CT_val = C_val.T.tocsr()
    CT_bin_topk = retain_topk(CT_bin, k=kappa)
    CT_val_topk = retain_topk(CT_val, k=kappa)
    A_init = CT_bin_topk + CT_val_topk
    A_init.sum_duplicates()
#     A_init = retain_topk(A_init, k=kappa)

    return A_init

# %% [markdown]
# ## Prepare for ranker

# %%
trn_embs = net.get_embs(trn_dataset)
tst_embs = net.get_embs(tst_dataset)

# %%
trn_dataset = FixedDataset(trn_embs, trn_X_Y)
tst_dataset = FixedDataset(tst_embs, tst_X_Y)

trn_embs_loader = torch.utils.data.DataLoader(
    trn_dataset,
    batch_size=args.bsz,
    num_workers=4,
    collate_fn=XCCollator(args.numy, trn_dataset),
    shuffle=False,
    pin_memory=True)

tst_embs_loader = torch.utils.data.DataLoader(
    tst_dataset,
    batch_size=args.bsz*2,
    num_workers=4,
    collate_fn=XCCollator(args.numy, tst_dataset),
    shuffle=False,
    pin_memory=True)

# %%
tst_score_mat = net.predict(tst_embs_loader, K=100)
trn_score_mat = net.predict(trn_embs_loader, K=100)
XCMetrics(tst_score_mat, tst_X_Y, inv_prop)
XCMetrics(trn_score_mat, trn_X_Y, inv_prop)

sp.save_npz(f'{DIR}/trn_score_mat.npz', trn_score_mat)
np.save(f'{DIR}/trn_embs.npy', trn_embs)
np.save(f'{DIR}/tst_embs.npy', tst_embs)

# %%
sp.save_npz(f'{DIR}/tst_score_mat.npz', score_mat)

# %% [markdown]
# ## Analyse

# %%
A_init = sp.load_npz(f'Results/ELIAS/ShoppingAds-10M-v2/Stage-1-0/A_init.npz')

# %%
cmat = sp.load_npz(f'Datasets/ShoppingAds-10M-v2/cmat-131072x100-0.npz')

# %%
np.where(A_init.getnnz(0) > 0)[0].shape
# Out:
# (9962290,)

# %%
A_nnz = A_init.getnnz(0)

A_norm_init = A_init.copy()
A_norm_init.data /= A_nnz[A_norm_init.indices]

top1k_A_init = retain_topk(A_norm_init, k=1000)

# %%
A_nnz[A_init[0].indices]
# Out:
# array([12, 14, 14, ..., 26, 29,  6])

# %%
top1k_A_init.getnnz(0)
# Out:
# array([14, 13, 18, ...,  3,  0, 14])

# %%
sp.save_npz(f'{OUT_DIR}/A_init.npz', top1k_A_init)

# %%
res = csr_to_pad_tensor(top1k_A_init, pad=args.numy)

# %%
net.A_norm_nz_vals / net.A_norm_nz_vals.max(dim=1).values.reshape(-1, 1)
# Out:
# tensor([[0.0566, 0.0572, 0.4303,  ..., 0.0571, 0.0571, 0.0571],
#         [0.0701, 0.0628, 0.0735,  ..., 0.0679, 0.0732, 0.0672],
#         [0.1769, 0.2494, 0.1033,  ..., 0.0613, 0.0613, 0.0613],
#         ...,
#         [0.0762, 0.0654, 0.0599,  ..., 0.0827, 0.0626, 0.0568],
#         [0.0603, 0.0891, 0.0932,  ..., 0.0967, 0.0959, 0.0972],
#         [0.7477, 0.9157, 0.8849,  ..., 0.4739, 0.8788, 0.7865]],
#        device='cuda:11')

# %%
res['vals']
# Out:
# tensor([[1.7678, 1.3529, 4.3026,  ..., 3.1054, 1.0100, 3.2342],
#         [1.4744, 1.5289, 5.1870,  ..., 1.0056, 0.3653, 3.2915],
#         [1.3993, 2.6927, 0.1219,  ..., 1.1789, 0.7297, 3.5341],
#         ...,
#         [1.3639, 1.6632, 1.5742,  ..., 1.4861, 1.2941, 2.6715],
#         [5.3591, 2.2278, 0.8571,  ..., 0.9233, 2.2492, 1.4642],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %%
res['vals'] / torch.clamp(res['vals'].max(dim=1).values.reshape(-1, 1), min=1e-8)
# Out:
# tensor([[0.3344, 0.2559, 0.8139,  ..., 0.5874, 0.1910, 0.6118],
#         [0.2589, 0.2685, 0.9109,  ..., 0.1766, 0.0642, 0.5781],
#         [0.2164, 0.4164, 0.0188,  ..., 0.1823, 0.1128, 0.5465],
#         ...,
#         [0.2498, 0.3046, 0.2883,  ..., 0.2722, 0.2370, 0.4893],
#         [0.7143, 0.2969, 0.1142,  ..., 0.1231, 0.2998, 0.1952],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %%
np.where(top1k_A_init.getnnz(0) > 0)[0].shape
# Out:
# (9952630,)

# %%
Y = [x.strip() for x in open(f'{DATA_DIR}/raw/Y.txt').readlines()]

# %%
trnX = [x.strip() for x in open(f'{DATA_DIR}/raw/trn_X.txt').readlines()]

# %%
new_cmat = sp.csr_matrix((net.A_norm_nz_vals.detach().cpu().numpy().ravel(), 
                         net.A_nz_inds.cpu().numpy().ravel(),
                         range(0, net.A_nz_inds.shape[0]*net.A_nz_inds.shape[1]+1, net.A_nz_inds.shape[1])),
                         A_init.shape)

# %%
def vispoint(x, spmat, X, Y, stats, true_mat=None, sep='', K=-1, expand=False, trnx_nnz=None):
    if K == -1: K = spmat[x].nnz
    if true_mat is None: true_mat = tst_X_Y
        
    sorted_inds = spmat[x].indices[np.argsort(-spmat[x].data)][:K]
    print(f'x[{x}]: {_c(X[x], attr="bold")}\n')
    for i, ind in enumerate(sorted_inds):
        myattr = ""
        if true_mat[x, ind] > 0.1: myattr="yellow"
        print(f'{i+1}) {_c(Y[ind], attr=myattr)} [{ind}] ({"%.4f"%spmat[x, ind]}, {stats[ind]})')
        if expand:
            for j, trn_ind in enumerate(trn_Y_X[ind].indices[:10]):
                print(f'\t{j+1}) {_c(trnX[trn_ind], attr="green")} [{trn_ind}] ({trnx_nnz[trn_ind]})')
        print(sep)

# %%
stats = trn_X_Y.getnnz(0)

# %%
vispoint(1, top1k_A_init, Y, Y, stats, cmat, K=100)
# Out:
# x[1]: Organic Skinny Natural Tea - Loose Leaf Oolong, 2 oz Bag (approx. 30 servings)
#
# 1) Dress The Population Alicia Dress - Garnet - Red - XS [3911071] (5.6940, 31)
#
# 2) Dress the Population Alicia Chiffon V-Neck Sleeveless Lace Hem Midi Dress - S [6566] (5.1870, 51)
#
# 3) DRESS THE POPULATION Alicia Chiffon Fit & Flare Dress Blue [4995972] (4.8683, 51)
#
# 4) Dress The Population Anable Dress - Brown - M [9726707] (4.8029, 51)
#
# 5) Dress the Population Women's Alicia Plunging Mix Media Sleeveless Fit and Flare Midi Dress [3084982] (4.7050, 51)
#
# 6) Dress the Population Alicia Mixed Media Midi Dress in Pine at Nordstrom, Size X-Small [7674273] (4.6261, 51)
#
# 7) Dress the Population Women's Blair Plunging Fit and Flare Midi Dress [8326410] (4.6202, 51)
#
# 8) Dress The Population Dresses | Dress The Population Elisa Embroidered Fit And Flare Dress - Worn Once! | Color: Gold/White | Size: M | Bailz795's [6141634] (4.5581, 51)
#
# 9) Dress the Population Elle Sweetheart-Neck Bodycon Dress - Pine - Size S [6507570] (4.5230, 24)
#
# 10) Dress the Population Audrey Embroidered Fit & Flare Dress in Lilac/Nude at Nordstrom, Size Large [4992164] (4.5192, 51)
#
# 11) Dress The Population Women's Alicia Chiffon Fit & Flare Dress - Midnight Blue - Size XS [239963] (4.5113, 32)
#
# 12) Alicia Dress L / DARK MAGENTA [2452073] (4.5102, 21)
#
# 13) Dress the Population Darleen Deep-v Floral-Applique Dress - Black - Size M [1116545] (4.5024, 51)
#
# 14) Dress The Population Alicia Dress - Burgundy - Red - XL [3423570] (4.4549, 17)
#
# 15) Kathy Dress L / ELECTRIC BLUE M [711967] (4.4509, 20)
#
# 16) Dress the Population Women's Audrey Mini Dress in Minrl Blue ude | Large | Lord & Taylor [3012645] (4.4502, 51)
#
# 17) Dress the Population Women's Audrey Midi Dress in Ivory/Nude | XS | Lord & Taylor [4389519] (4.4035, 21)
#
# 18) Dress The Population Sandra Plunging V-Neck Sleeveless Crepe Gown, Garnet, Women's, L, Sleeveless Gowns [5399959] (4.3718, 51)
#
# 19) Dress The Population Darleen Floral-applique Dress - Women's Small, [4474237] (4.3691, 51)
#
# 20) Dress the Population Blair Lace Midi Dress - Black/Nude - Size XXS [3909590] (4.3156, 10)
#
# 21) Dress the Population Darleen V-Neck Embroidered Mesh Cocktail Dress in Peacock Blue at Nordstrom, Size Xx-Small [9502125] (4.3121, 30)
#
# 22) Dress the Population Women's Darleen Sleeveless 3D Floral Fit & Flare Midi Dress [632455] (4.2529, 42)
#
# 23) Dress The Population Vanessa Dress - Blue - L [6140879] (4.2132, 30)
#
# 24) Dress The Population Alicia Dress - Red - S [5040813] (4.2087, 50)
#
# 25) Dress The Population Delphine Dress - Black - M [3986174] (4.1758, 38)
#
# 26) Dress The Population Dresses | Dress The Population - Blair Dress - Size Small | Color: Black/Tan | Size: S | Kateylynn's Closet [5829107] (4.1637, 51)
#
# 27) Dress the Population Women's Audrey Mini Dress in Minrl Blue ude | 2XS | Lord & Taylor [7404833] (4.1448, 33)
#
# 28) Dress The Population Alicia Dress - Midnight Blue - Blue - XL [4008530] (4.1229, 51)
#
# 29) Dress The Population Corey Dress - Green - XS [9232287] (4.1137, 51)
#
# 30) Dress The Population - Black Dana Dress [4222726] (4.1083, 27)
#
# 31) Dress The Population Women's Alicia Chiffon Fit & Flare Dress - Midnight Blue - Size XXS [8148837] (4.0928, 51)
#
# 32) Dress The Population Elisa Dress - White - L [7478926] (4.0699, 44)
#
# 33) Dress The Population Women's Uma Embroidered Tulle Fit & Flare Dress - Maroon Black Multi - Size Medium [4111356] (4.0511, 51)
#
# 34) Dress The Population Corey Dress - Purple - S [8469595] (4.0282, 51)
#
# 35) Dress the Population Women's Blair Plunging Fit and Flare Midi Dress [6713568] (3.9996, 51)
#
# 36) Dress the Population Women's Darleen Sleeveless Plunging Neckline Fit and Flare Midi Dress [7366477] (3.9956, 36)
#
# 37) Dress the Population Women's Corey Plunging Mix Media Cap Sleeve A-line Midi Dress [9344859] (3.9848, 51)
#
# 38) Dress the Population Catalina Crepe V-Neck Sleeveless Fit and Flare Dress, Womens, S, Dark Magenta [4799567] (3.9444, 30)
#
# 39) Dress The Population Women's Uma Embroidered Tulle Fit & Flare Dress - Maroon Black Multi - Size XXS [9770079] (3.9158, 51)
#
# 40) Dress The Population Dresses | Eve Sweetheart Twist Front Sleeveless Midi | Color: Pink | Size: Xs | Sidneyj's Closet [7459918] (3.9116, 51)
#
# 41) Dress The Population Alea Dress - White - M [6136909] (3.8879, 51)
#
# 42) Dress The Population Alicia Dress - Burgundy - Red - L [4323702] (3.8874, 51)
#
# 43) Dress the Population Women's Blair Plunging Fit and Flare Midi Dress [6374476] (3.8455, 12)
#
# 44) Elisa Dress S / IVORY [7437529] (3.8172, 32)
#
# 45) Dress the Population Women's Blair Plunging Fit and Flare Midi Dress [7142064] (3.8157, 51)
#
# 46) Dress The Population Dresses | Dress The Population Metallic Blair Sequin Lace Fit & Flare Dress | Color: Silver | Size: M | Xomykia's Closet [5868946] (3.8105, 32)
#
# 47) Dress The Population Maren Dress - Blue - S [9066308] (3.7935, 51)
#
# 48) Colette Dress XS / MINERAL BLUE MU [5144864] (3.7085, 51)
#
# 49) Dress The Population Silvia Dress - Black - S [9344418] (3.6757, 51)
#
# 50) Dress the Population Women's Courtney Sleeveless Veiled Fit & Flare Midi Dress [2128923] (3.6379, 51)
#
# 51) Dress The Population Amada Dress - Pink - S [2460489] (3.6278, 27)
#
# 52) Audrey Dress L / LILAC/NUDE [2215383] (3.6208, 36)
#
# 53) Dress The Population Women's Owen Asymmetrical Tulip-Hem Dress - Midnight Blue - Size XXS [9352992] (3.5830, 51)
#
# 54) Dress The Population Anabel Dress - Black - XS [4314479] (3.5614, 27)
#
# 55) Dress the Population Catalina Fit & Flare Cocktail Dress in Black at Nordstrom, Size Medium [2724288] (3.5380, 51)
#
# 56) Dress The Population Sidney Dress - Brown - M [4081731] (3.5366, 51)
#
# 57) Dress the Population Elisa Lace Fit & Flare Dress in White at Nordstrom, Size Medium [79531] (3.5156, 51)
#
# 58) Dress the Population Eden Body-Con Dress in Black at Nordstrom, Size Large [6002076] (3.4950, 21)
#
# 59) Dress the Population Sweetheart Neck Back Slit Sleeveless Midi Nicole Dress, Womens, M, Garnet [6952999] (3.4884, 37)
#
# 60) Dress the Population Lyla Crepe Cocktail Dress in Navy at Nordstrom, Size X-Small [2821866] (3.4882, 13)
#
# 61) Dress the Population Eve Sweetheart Twist Front Sleeveless Midi Sheath Dress in Rouge at Nordstrom Rack, Size X-Large [8182376] (3.4827, 51)
#
# 62) Dress The Population Dresses | Dress The Population Blair Lace Dress Nwt | Color: Blue/Tan | Size: Xs | Palmbchprinces's Closet [61805] (3.4613, 51)
#
# 63) Dress The Population Women's Anabel Maxi Dress - Port - Size Small [2326869] (3.4607, 51)
#
# 64) Audrey Dress M / OFF WHITE/NUDE [6269432] (3.4591, 30)
#
# 65) Dress the Population Nellie Floral Embroidered Fit & Flare Dress in Black Multi at Nordstrom, Size Medium [8217786] (3.4494, 51)
#
# 66) Ramona Gown L / BLACK [7373686] (3.4405, 32)
#
# 67) Dress The Population Women's Uma Embroidered Tulle Fit & Flare Dress - Maroon Black Multi - Size Small [5301473] (3.4386, 51)
#
# 68) Corey Dress S / BLACK [1747871] (3.4286, 50)
#
# 69) Dress the Population Women's Lyla Midi Dress in Peacock Blue | Medium | Lord & Taylor [9383070] (3.4210, 18)
#
# 70) Blair Dress XS / GOLD/NUDE [2882890] (3.4185, 10)
#
# 71) Dress the Population Women's Audrey Midi Dress in Off White/Nude | Large | Lord & Taylor [3275926] (3.4139, 51)
#
# 72) Dress The Population Lyla Dress - Pine - Green - L [9849180] (3.4127, 51)
#
# 73) Dress the Population Corey Chiffon Fit & Flare Cocktail Dress in Midnight Blue at Nordstrom, Size Medium [9745345] (3.4107, 50)
#
# 74) Dress The Population Catalina Dress - Red - M [7122912] (3.4046, 19)
#
# 75) Dress The Population Nadia Dress - Black - M [7219576] (3.3786, 40)
#
# 76) Dress The Population Silvia Dress - Black - L [8521129] (3.3773, 20)
#
# 77) Catalina Dress S / PEACOCK BLUE [438948] (3.3750, 34)
#
# 78) Dress the Population Audrey Embroidered Fit & Flare Dress in Off White/Nude at Nordstrom, Size Xx-Large [5860017] (3.3713, 51)
#
# 79) Dress the Population Women's Lita Midi Dress in Black | Large | Lord & Taylor [2142787] (3.3696, 18)
#
# 80) Dress the Population Catalina Fit & Flare Cocktail Dress in Black at Nordstrom, Size Small [7209309] (3.3679, 51)
#
# 81) Audrey Dress XS / BLACK/NUDE [8776560] (3.3604, 21)
#
# 82) Dress the Population Melina Plunge V-Neck Sleeveless Sheer Tiered Floral Lace Applique Gown - XL [5600678] (3.3552, 51)
#
# 83) Dress The Population Women's Blair Sleeveless Sequin Lace Midi Dress - White Nude - Size Large [3721438] (3.3357, 51)
#
# 84) Dress The Population Alicia Dress - Black - XS [9964633] (3.3333, 10)
#
# 85) Dress the Population Audrey Embroidered Fit & Flare Dress in Canary/Nude at Nordstrom, Size Small [4750746] (3.3314, 15)
#
# 86) Dress The Population Cantrelle Dress - Red - XS [7000001] (3.3178, 16)
#
# 87) Dress the Population Harlow Floral Embroidered A-Line Dress in Black Multi at Nordstrom, Size Small [7580140] (3.3099, 51)
#
# 88) Dress The Population Floral Print Sequin Fit-And-Flare Midi Dress, Gold, Women's, XS, Cocktail & Party Wedding Guest Dresses A-Line Dresses [1924599] (3.3090, 51)
#
# 89) Dress The Population Dresses | Dress The Population Corey - Nwt | Color: Blue | Size: S | Villagranar3's Closet [1318141] (3.2964, 51)
#
# 90) Dress The Population Alicia Dress - Black - XXS [2432729] (3.2927, 51)
#
# 91) Dress The Population Giulia Dress - Black - XS [9995597] (3.2915, 14)
#
# 92) Dress the Population Women's Catalina Solid Sleeveless Fit & Flare Midi Dress [7396068] (3.2855, 51)
#
# 93) Dress The Population Eden Bodycon Midi Halter Dress, Rouge, Women's, L, Cocktail & Party Wedding Guest Dresses Halter Neck Dresses [1109996] (3.2648, 51)
#
# 94) Dress the Population Nicole Floral-Print Bodycon Dress - Black Multi - Size S [970489] (3.2647, 51)
#
# 95) Dress the Population Audrey Embroidered Fit & Flare Dress in Black/Nude at Nordstrom, Size Medium [2177270] (3.2600, 51)
#
# 96) Dress the Population Courtney Sequin Floral Cocktail Dress in Fuchsia Multi at Nordstrom, Size Medium [7692905] (3.2589, 39)
#
# 97) Dress the Population V-Neck Sleeveless Lace Dress in Black-Nude at Nordstrom Rack, Size Large [3418879] (3.2522, 46)
#
# 98) Dress the Population 3D Floral Fit & Flare Gown in Pale Mauve Multi at Nordstrom, Size Small [9803760] (3.2449, 22)
#
# 99) Dress The Population Elle Dress - Blue - M [8149665] (3.2406, 51)
#
# 100) Jordan Gown XS / BURGUNDY [6310354] (3.2386, 31)

# %%
# args.candidates_file = f'Results/Joint-XRL/{args.dataset}/candidates.npz'
# DIR = f'Results/Joint-XRL/Amazon-670K/treenetv3-leaf100-beam20-py_joint_tf-bert-base-uncased_xc-lr-0.001_enc-lr-5e-06_bsz-48/'
DIR = f'Results/Joint-XRL/LF-AmazonTitles-131K/treenetv3-leaf100-beam20-2-py_joint_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-3e-05_bsz-420'
device = 'cuda:1'
args.__dict__ = json.load(open(f'{DIR}/args.json'))
args.device = device
# args.cluster_nnz = 10
# args.max_shorty = 2000

# %%
net = TreeNetV3(args)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading candidates matrix file: Results/Joint-XRL/LF-AmazonTitles-131K/treenetv3-leaf100-beam20-2-py_joint_tf-distilbert-base-uncased_xc-lr-0.02_enc-lr-0.0001_bsz-448/candidates.npz

# %%
# DIR = 'Results/Joint-XRL/wiki-500k/treenetv3-leaf100-beam20-py_joint_tf-distilbert-base-uncased_xc-lr-0.001_enc-lr-5e-06_bsz-64'
# DIR = OUT_DIR

net.load_state_dict(torch.load(f'{DIR}/model.pt', map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
net.to(args.device)
net.update()

# %%
new_cmat = sp.csr_matrix((net.normalized_C.detach().cpu().numpy().ravel(), 
                         net.candidates.cpu().numpy().ravel(),
                         range(0, net.candidates.shape[0]*net.candidates.shape[1]+1, net.candidates.shape[1])),
                         cmat.shape)

# %%
net.to(args.device)
with torch.no_grad():
    net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %%
net.retain_topk(200)

# %%
score_mat1 = sp.load_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/treenetv3-leaf100-beam20-py_joint_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-3e-05_bsz-420/score_mat.npz')
score_mat2 = sp.load_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/treenetv3-leaf100-beam20-1-py_joint_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-3e-05_bsz-420/score_mat.npz')
score_mat3 = sp.load_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/treenetv3-leaf100-beam20-2-py_joint_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-3e-05_bsz-420/score_mat.npz')

# %%
XCMetrics(score_mat3+score_mat2, tst_X_Y, inv_prop, disp=True);
# Out:
# P@1	P@5	nDCG@1	nDCG@5	PSP@1	PSP@5	R@10	R@20	R@100	MRR@10
# 38.7	18.88	38.7	41.71	29.56	40.58	51.4	56.14	64.6	45.41
#
# P@1 P@5 nDCG@1 nDCG@5 PSP@1 PSP@5 R@10 R@20 R@100 MRR@10
# 38.7 18.88 38.7 41.71 29.56 40.58 51.4 56.14 64.6 45.41

# %%
XCMetrics(score_mat3, tst_X_Y, inv_prop, disp=True);
# Out:
# P@1	P@5	nDCG@1	nDCG@5	PSP@1	PSP@5	R@10	R@20	R@100	MRR@10
# 37.9	18.45	37.9	40.76	29.34	39.68	50.13	54.62	62.88	44.45
#
# P@1 P@5 nDCG@1 nDCG@5 PSP@1 PSP@5 R@10 R@20 R@100 MRR@10
# 37.9 18.45 37.9 40.76 29.34 39.68 50.13 54.62 62.88 44.45

# %%
XCMetrics(score_mat1, tst_X_Y, inv_prop, disp=True);
# Out:
# P@1	P@5	nDCG@1	nDCG@5	PSP@1	PSP@5	R@10	R@20	R@100	MRR@10
# 37.72	18.36	37.72	40.55	29.07	39.41	49.85	54.26	62.29	44.24
#
# P@1 P@5 nDCG@1 nDCG@5 PSP@1 PSP@5 R@10 R@20 R@100 MRR@10
# 37.72 18.36 37.72 40.55 29.07 39.41 49.85 54.26 62.29 44.24

# %%
score_mat = net.predict(tst_loader)
if tst_filter_mat is not None: _filter(score_mat, tst_filter_mat, copy=False)
metrics = XCMetrics(score_mat, tst_X_Y, inv_prop, method=args.expname, disp=True)
# Out:
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 151/151 [00:17<00:00,  8.77it/s]
# P@1	P@5	nDCG@1	nDCG@5	PSP@1	PSP@5	R@10	R@20	R@100	MRR@10
# 37.9	18.45	37.9	40.76	29.34	39.68	50.13	54.62	62.88	44.45
#
# P@1 P@5 nDCG@1 nDCG@5 PSP@1 PSP@5 R@10 R@20 R@100 MRR@10
# 37.9 18.45 37.9 40.76 29.34 39.68 50.13 54.62 62.88 44.45

# %%
trn_X_Xf = read_sparse_mat(f'{DATA_DIR}/trn_X_Xf.txt', use_xclib=False)
tst_X_Xf = read_sparse_mat(f'{DATA_DIR}/tst_X_Xf.txt', use_xclib=False)

from sklearn.preprocessing import normalize

normalize(trn_X_Xf, copy=False)
normalize(tst_X_Xf, copy=False)

# %%
cluster_chain = Indexer.gen(trn_X_Xf.astype(np.float32), indexer_type="hierarchicalkmeans", nr_splits=2048, max_leaf_size=100)
trnx_clusters = cluster_chain.chain[-1].T.tocsr()

# %%
# DIR = 'Results/Joint-XRL/LF-AmazonTitles-131K/XRL-cluster-learning-init/'
DIR = 'Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-5e-05_bsz-1024/'
trn_embs = np.load(f'{DIR}/trn_embs.npy')
tst_embs = np.load(f'{DIR}/tst_embs.npy')

# %%
c = np.random.randint(trnx_clusters.shape[0])
print(get_text(c, trnX, trnx_clusters, sep='\n'))

# %%
# normalize(trn_embs, copy=False);
# normalize(tst_embs, copy=False);

# %%
import seaborn as sns
sns.distplot(np.linalg.norm(trn_embs, axis=-1))

# %%
temp = torch.load('Results/Joint-XRL/LF-AmazonTitles-131K/XRL-cluster-learning-init/model-save.pt', map_location='cpu')

# %%
lbl_embs = F.normalize(temp['w.weight']).numpy()

# %%
cluster_chain = Indexer.gen(lbl_embs, indexer_type="hierarchicalkmeans", nr_splits=2048, max_leaf_size=100)
lbl_clusters = cluster_chain.chain[-1].T.tocsr()

# %%
sp.save_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/XRL-cluster-learning-init/cmat.npz', lbl_clusters)

# %%
es = exact_search({'data': lbl_embs, 'query': lbl_embs, 'K': 10, 'device': 'cuda:1'})
nns = es.getnns_gpu()

# %%
# l = np.random.randint(len(Y))
l = 2708
print(Y[l])
print(get_text(l, Y, nns, sep='\n'))

# %%
c = np.random.randint(lbl_clusters.shape[0])
print(get_text(c, Y, lbl_clusters, sep='\n'))

# %%
from sklearn.preprocessing import normalize

cluster_centroids = lbl_clusters.dot(lbl_embs)
normalize(cluster_centroids, copy=False);

# %%
c = np.random.randint(trnx_clusters.shape[0])
# c = 0
print(get_text(c, trnX, trnx_clusters, sep='\n'))

# %%
w = cluster_centroids
# w = cluster_clf_w

sim = np.dot(w[c], lbl_embs.T)
pos_inds = lbl_clusters[c].indices

# %%
import seaborn as sns

# %%
neg_inds = np.setdiff1d(np.arange(lbl_clusters.shape[1]), pos_inds)
neg_inds = neg_inds[np.argsort(sim[neg_inds])][-100:]

pos_sim = sim[pos_inds]
neg_sim = sim[neg_inds]

sns.distplot(pos_sim)
sns.distplot(neg_sim)

# %%
print(get_text(1, trnX, trnx_clusters, sep='\n'))

# %%
ova = XLinearModel.train(trn_embs, trnx_clusters.T.tocsr(), threshold=0)

# %%
cluster_clf_w = ova.model.model_chain[-1].pW.buf.toarray()[:-1].T
cluster_clf_b = ova.model.model_chain[-1].pW.buf.toarray()[-1].T

# %%
net.to(args.device);

net.retain_topk(120)
net.update_parent()

# %%
net.max_shorty = 2000

# %%
topk_score_mat = net.predict(tst_loader, K=2000)
_filter(topk_score_mat, tst_filter_mat, copy=False)
from xclib.utils.sparse import rank as sp_rank
from resources import Recall

rank_mat = sp_rank(topk_score_mat)
intrsxn_mat = rank_mat.multiply(tst_X_Y)

Recall(intrsxn_mat, tst_X_Y, K=[100, 200, 500, 1000, 1200, 2000])

# %%
net.to('cpu');

# %%
net.tau = 0.1
net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %%
net.normalized_C.topk(101)

# %%
net.C.topk(100)

# %%
args.device

# %%
net.load_state_dict(torch.load(f'{OUT_DIR}/model.pt', map_location=args.device))

# %%
net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %%
net.to(args.device)

# %%
net.normalized_C.topk(101)

# %%
net.cluster_update()

# %%
XCMetrics(_filter(top1k_score_mat, tst_filter_mat, copy=False), tst_X_Y, inv_prop)

# %%
net.cluster_update()

# %%
sort_inds = net.normalized_C.argsort(descending=True)

# %%
net.normalized_C.scatter_(1, sort_inds[:, net.max_leaf:], 0)

# %%
net.to(args.device)
with torch.no_grad():
    net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %%
# topk_score_mat = net.predict(tst_loader, K=5000)
# _filter(topk_score_mat, tst_filter_mat, copy=False)
# from xclib.utils.sparse import rank as sp_rank
# from resources import Recall

# rank_mat = sp_rank(topk_score_mat)
# intrsxn_mat = rank_mat.multiply(tst_X_Y)

Recall(intrsxn_mat, tst_X_Y, K=[100, 200, 500, 1000, 1200, 2000, 5000])

# %% [markdown]
# learnt Recall: {2000: 73.43186116364446,
#  1200: 68.15101173038651,
#  1000: 66.20384173248785,
#  500: 58.6652698977763,
#  200: 47.00033374123929,
#  100: 36.948270107909664}
#
# original Recall:  {2000: 64.82898851682921,
#  1200: 64.82898851682921,
#  1000: 63.05501786133668,
#  500: 56.21819260577743,
#  200: 45.67402133471774,
#  100: 33.16018343407373}
#
#  {2000: 68.5913153113064,
#  1200: 64.5524282765355,
#  1000: 62.865255064832326,
#  500: 56.187154670523235,
#  200: 45.64221703069184,
#  100: 33.191864130233256}

# %%
temp = torch.load('Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_ova-bce_tf-none_XRL-batch-bce_xc-lr-1.0_enc-lr-5e-05_bsz-512/model.pt', map_location='cpu')

# %%
w = torch.hstack([temp['w.weight'], temp['w.bias'].reshape(-1, 1)]).numpy()

# %%
bias_tst_embs = np.hstack((tst_embs, np.ones((tst_embs.shape[0], 1))))

# %%
es = exact_search({'data': w, 'query': bias_tst_embs, 'K': 5000, 'metric': 'ip', 'device': args.device})
clf_score_mat = es.getnns_gpu()

_filter(clf_score_mat, tst_filter_mat, False);

# %%
rank_mat = sp_rank(clf_score_mat)
intrsxn_mat = rank_mat.multiply(tst_X_Y)

Recall(intrsxn_mat, tst_X_Y, K=[100, 200, 500, 1000, 1200, 2000, 5000])

# %%
XCMetrics(score_mat, tst_X_Y, inv_prop)

# %%
with torch.no_grad():
    inds = net.C.argsort(descending=True)
    net.C.requires_grad = False
    net.C.scatter_(1, inds[:, net.max_leaf:], -1000)
    net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %%
torch.save(net.state_dict(), f'{OUT_DIR}/model-intermediate.pt')

# %%
net.C.min(dim=1)

# %%
res = inds[:, :100].unique(return_counts=True)

# %%
res[1].topk(10)

# %%
res[0][res[1].topk(10).indices]

# %%
nnz[res[0][res[1].topk(10).indices]]

# %%
net.train()

# %%
inds = net.C.argsort(descending=True)
net.C.requires_grad = False
net.C.scatter_(1, inds[:, 100:], -1000)
net.normalized_C = torch.clamp(net.max_leaf*F.softmax(net.C/net.tau, dim=-1), min=0, max=1)

# %% [markdown]
# ## Label disentanglement

# %%
args.OUT_DIR = OUT_DIR
args.cluster_nnz = 10
args.hidden_dim = args.embs_dim

# %%
net2 = TreeNetV2(args)

# %%
# DIR = 'Results/Joint-XRL/LF-AmazonTitles-131K/treenet-leaf100-beam20-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-0.0001_bsz-256'
DIR = 'Results/Joint-XRL/LF-AmazonTitles-131K/treenetv2-leaf100-beam20-py_beam-bce_tf-distilbert-base-uncased_xc-lr-0.015_enc-lr-0.0001_bsz-256/'
# DIR = 'Results/Joint-XRL/EURLex-4K/treenetv2-leaf100-beam20-py_beam-bce_tf-distilbert-base-uncased_xc-lr-0.005_enc-lr-5e-05_bsz-128/'
# DIR = 'Results/Joint-XRL/wiki-500k/treenetv2-leaf100-beam20-py_beam-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-2e-05_bsz-64/'
net2.load_state_dict(torch.load(f'{DIR}/model.pt', map_location='cpu'), strict=False)

# %%
trn_embs = net.get_embs(trn_dataset)
tst_embs = net.get_embs(tst_dataset)
# np.save(f'{DIR}/trn_embs.npy', trn_embs)
# np.save(f'{DIR}/tst_embs.npy', tst_embs)

# DIR = 'Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-5e-05_bsz-1024/'
# trn_embs = np.load(f'{DIR}/trn_embs.npy')
# tst_embs = np.load(f'{DIR}/tst_embs.npy')
# Out:
# Encoding: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1152/1152 [00:26<00:00, 44.03it/s]
# Encoding: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 527/527 [00:11<00:00, 44.67it/s]

# %%
# net2.to(args.device); net2.cluster_update()

# score_mat = net2.predict(tst_loader)
# if tst_filter_mat is not None: _filter(score_mat, tst_filter_mat, copy=False)
# metrics = XCMetrics(score_mat, tst_X_Y, inv_prop, method=args.expname, disp=True)

# %%
import seaborn as sns
sns.histplot(np.linalg.norm(trn_embs, axis=1))

# %%
M_indices = None; M_values = None;
trn_Y_X = trn_X_Y.T.tocsr()
def gen_candidates(net, trn_embs, trn_Y_X, max_candidate, device='cpu', bsz=100000):
    global M_values, M_indices
    trn_tensor_embs = torch.tensor(trn_embs).to(device)
    M_indices = []; M_values = []
    with torch.no_grad():
        for ctr in tqdm(range(0, trn_tensor_embs.shape[0], bsz)):
            res = torch.mm(trn_tensor_embs[ctr:ctr+bsz], net.w1.weight.T.to(device)) + net.w1.bias.reshape(1, -1).to(device)
            res = torch.clamp(net.cluster_nnz*F.softmax(res, dim=1), min=0, max=1)
            temp = res.topk(net.beam, dim=1)
            M_indices.append(temp.indices)
            M_values.append(temp.values)

    M_indices = torch.vstack(M_indices)
    M_values = torch.vstack(M_values)

    numx = M_indices.shape[0]
    K = M_indices.shape[1]
    data_bin = np.ones(numx * K) 
    data_val = M_values.reshape(-1).cpu().numpy()
    inds = M_indices.reshape(-1).cpu().numpy()
    indptr = np.arange(0, numx*K + 1, K)
    shape = (trn_embs.shape[0], net.w1.weight.shape[0])
    
    M_bin = sp.csr_matrix((data_bin, inds, indptr), shape)
    M_val = sp.csr_matrix((data_val, inds, indptr), shape)
    C_bin = trn_Y_X.dot(M_bin)
    C_val = trn_Y_X.dot(M_val)

    CT_bin = C_bin.T.tocsr()
    CT_val = C_val.T.tocsr()
    CT_bin_topk = retain_topk(CT_bin, k=max_candidate)
    CT_val_topk = retain_topk(CT_val, k=max_candidate)
    candidates = CT_bin_topk + CT_val_topk
    candidates.sum_duplicates()
#     candidates = retain_topk(candidates, k=max_candidate)

    return candidates

# %%
candidates = gen_candidates(net, trn_embs, trn_X_Y.T.tocsr(), 1000, args.device, 10000)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
numx = M_indices.shape[0]
K = M_indices.shape[1]
data_bin = np.ones(numx * K) 
data_val = M_values.reshape(-1).cpu().numpy()
inds = M_indices.reshape(-1).cpu().numpy()
indptr = np.arange(0, numx*K + 1, K)
shape = (trn_embs.shape[0], net.w1.weight.shape[0])

M_bin = sp.csr_matrix((data_bin, inds, indptr), shape)
M_val = sp.csr_matrix((data_val, inds, indptr), shape)
C_bin = trn_Y_X.dot(M_bin)
C_val = trn_Y_X.dot(M_val)

CT_bin = C_bin.T.tocsr()
CT_val = C_val.T.tocsr()
# CT_bin_topk = retain_topk(CT_bin, k=max_candidate)
# CT_val_topk = retain_topk(CT_val, k=max_candidate)
# candidates = CT_bin_topk + CT_val_topk
# candidates.sum_duplicates()

# %%
nnz = trn_X_Y.getnnz(0)

# %%
from heapq import heapify, heappush, heappop
from sklearn.preprocessing import normalize
h = [(-nnz[y], y) for y in range(len(Y))]
heapify(h)

# %%
Y_M = [M_val[trn_Y_X[y].indices] for y in tqdm(range(args.numy))]

# %%
new_cmat = sp.lil_matrix((args.nr_splits+1, args.numy))
i = 0; TH = 0.5
while len(h) > 0:
    y_priority, y = heappop(h)
    temp = normalize(Y_M[y], norm='max') 
    temp.data[temp.data < TH] = 0
    
    c_y_score = np.array(temp.sum(axis=0)).ravel()
    c = c_y_score.argmax()
    delta_numx = c_y_score.max()
    
    temp_T = temp.T.tocsr()
    new_x = np.setdiff1d(np.arange(temp.shape[0]), temp_T[c].indices[temp_T[c].data > 0])
    Y_M[y] = Y_M[y][new_x]
    new_y_priority = -Y_M[y].shape[0]
    
    if new_y_priority < -0.5:
        heappush(h, (new_y_priority, y))
    new_cmat[c, y] = delta_numx
    i += 1 
    if i%1000 == 0: 
        print(f'{i} done, {len(h)} remaining')

# %%
temp.shape

# %%
TH = 0.1
temp = M_val.copy()
temp.data[temp.data < TH] = 0
temp.eliminate_zeros()
TH_candidates = temp.T.tocsr().dot(trn_X_Y)

# %%
_filter(TH_candidates, new_cmat, copy=False)

# %%
new_cmat.resize((args.nr_splits+1, args.numy))

# %%
candidates = new_cmat*10 + normalize(TH_candidates, norm='max')

# %%
retain_topk(candidates, k=1000, copy=False)

# %%
new_cmat.data.max()

# %%
TH_candidates.data.max()

# %%
th_nnz = TH_candidates.getnnz(1)

# %%
th_nnz.mean()

# %%
sorted_inds = np.argsort(th_nnz)

# %%
orig_candidates = sp.load_npz(f'{OUT_DIR}/../candidates.npz')

# %%
th_nnz[sorted_inds][:100]

# %%
new_cmat[1747]

# %%
new_cmat = new_cmat.tocsr()

# %%
sp.save_npz(f'{OUT_DIR}/candidates-v2.npz', candidates)

# %%
new_cmat.getnnz(0).argmax()

# %%
print(get_text(127750, range(2048), new_cmat.T.tocsr()))

# %%
trn_embs = net.get_embs(trn_dataset)
tst_embs = net.get_embs(tst_dataset)

# %%
# net.to('cpu')
tau = 1
trn_Y_X = trn_X_Y.T.tocsr()
tst_tensor_embs = torch.tensor(tst_embs)
trn_tensor_embs = torch.tensor(trn_embs)

w = net.w1.weight.T.cpu()
b = net.w1.bias.cpu()
# w = torch.tensor(cluster_clf_w.T)
# b = torch.tensor(cluster_clf_b)
# w = torch.tensor(cluster_centroids.T)
# b = torch.zeros(w.shape[1])

with torch.no_grad():
    res = torch.mm(trn_tensor_embs, w) + b.reshape(1, -1)
    res = torch.clamp(net.cluster_nnz*F.softmax(res/tau, dim=1), min=0, max=1)

M = res.topk(20, dim=1)

numx = M.indices.shape[0]
K = M.indices.shape[1]
data_bin = np.ones(numx * K) 
data_val = M.values.reshape(-1).cpu().numpy()
inds = M.indices.reshape(-1).numpy()
indptr = np.arange(0, numx*K + 1, K)

M_bin = sp.csr_matrix((data_bin, inds, indptr), res.shape)
M_val = sp.csr_matrix((data_val, inds, indptr), res.shape)
C_bin = trn_Y_X.dot(M_bin)
C_val = trn_Y_X.dot(M_val)

# %%
CT = C_bin.T.tocsr()
CT_val = C_val.T.tocsr()

CT_topk = retain_topk(CT, k=1000)
CT_val_topk = retain_topk(CT_val, k=1000)

candidates = CT_topk + CT_val_topk

candidates.sum_duplicates()

# %%
print(get_text(4735, Y, candidates, K=2000, sep='\n'))

# %%
nnz = trn_X_Y.getnnz(0)
trnx_nnz = trn_X_Y.getnnz(1)
trn_Y_X = trn_X_Y.T.tocsr()

# %%
np.where(candidates.getnnz(0)[:-1] == 0)[0].shape[0], nnz[np.where(candidates.getnnz(0)[:-1] == 0)[0]].mean()

# %%
cmat_nnz = candidates.getnnz(0)

# %%
Y[281042]

# %%
cmat_nnz.argmax()

# %%
candidates.getcol(281042).T.indices

# %%
cmat[4735, 281042]

# %%
print(get_text(281042, range(candidates.shape[0]), candidates.T.tocsr(), sep='\n'))

# %%
sp.save_npz(f'{DIR}/candidates.npz', candidates)
# sp.save_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-5e-05_bsz-1024/candidates.npz', candidates)
# sp.save_npz(f'Results/Joint-XRL/LF-AmazonTitles-131K/XRL-cluster-learning-init/candidates.npz', candidates)

# %%
np.save(f'Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-5e-05_bsz-1024/cluster_clf_w.npy', cluster_clf_w)
np.save(f'Results/Joint-XRL/LF-AmazonTitles-131K/fcnet-py_batch-bce_tf-distilbert-base-uncased_xc-lr-0.0025_enc-lr-5e-05_bsz-1024/cluster_clf_b.npy', cluster_clf_b)

# %% [markdown]
# ## Visualize

# %%
def vispoint(x, spmat, X, Y, stats, true_mat=None, sep='', K=-1, expand=False, trnx_nnz=None):
    if K == -1: K = spmat[x].nnz
    if true_mat is None: true_mat = tst_X_Y
        
    sorted_inds = spmat[x].indices[np.argsort(-spmat[x].data)][:K]
    print(f'x[{x}]: {_c(X[x], attr="bold")}\n')
    for i, ind in enumerate(sorted_inds):
        myattr = ""
        if true_mat[x, ind] > 0.1: myattr="yellow"
        print(f'{i+1}) {_c(Y[ind], attr=myattr)} [{ind}] ({"%.4f"%spmat[x, ind]}, {stats[ind]})')
        if expand:
            for j, trn_ind in enumerate(trn_Y_X[ind].indices[:10]):
                print(f'\t{j+1}) {_c(trnX[trn_ind], attr="green")} [{trn_ind}] ({trnx_nnz[trn_ind]})')
        print(sep)

# %%
candidates = sp.load_npz(args.candidates_file)

# %%
retain_topk(new_cmat, copy=False, k=200)
# Out:
# <2049x131074 sparse matrix of type '<class 'numpy.float32'>'
# 	with 409800 stored elements in Compressed Sparse Row format>

# %%
nnz = trn_X_Y.getnnz(0)
trnx_nnz = trn_X_Y.getnnz(1)
trn_Y_X = trn_X_Y.T.tocsr()

# %%
np.where(candidates.getnnz(0)[:-1] == 0)[0].shape[0], nnz[np.where(candidates.getnnz(0)[:-1] == 0)[0]].mean()
# Out:
# (8, 1.0)

# %%
cmat_nnz = new_cmat.getnnz(0)
# topk_new_cmat = retain_topk(new_cmat, k=100)
th_new_cmat = new_cmat.copy()
th_new_cmat.data[th_new_cmat.data < 0.3] = 0
th_new_cmat.eliminate_zeros()
th_cmat_nnz = th_new_cmat.getnnz(0)

# %%
stats = list(zip(nnz, th_cmat_nnz))
stats.append((0, 0))

# %%
temp = retain_topk(candidates, k=2000)
temp.resize(*new_cmat.shape)
new_cmat.multiply(temp).getnnz(1).mean()*100/new_cmat.getnnz(1).mean()
# Out:
# 94.4787701317716

# %%
c = np.random.randint(new_cmat.shape[0])
vispoint(c, new_cmat, Y, Y, stats, cmat, K=2000, expand=False, trnx_nnz=trnx_nnz)
# Out:
# x[1638]: Digital Communications: Fundamentals and Applications (2nd Edition)
#
# 1) Toll of the Sea (1922) / Shifting Sand (1918) (Silent) (1918) [129176] (1.0000, (4, 2))
#
# 2) Sources of Chinese Tradition, Vol. 1 [3506] (1.0000, (23, 4))
#
# 3) The Invention of World Religions: Or, How European Universalism Was Preserved in the Language of Pluralism [3396] (1.0000, (6, 3))
#
# 4) Everybody Loves You [68103] (1.0000, (1, 1))
#
# 5) The Rights of Nature: A History of Environmental Ethics (History of American Thought and Culture) [3814] (1.0000, (2, 2))
#
# 6) Creating Bonsai Landscapes: 18 Miniature Garden Projects [30412] (1.0000, (3, 2))
#
# 7) The Analects of Confucius: A Philosophical Translation (Classics of Ancient China) [5467] (1.0000, (14, 3))
#
# 8) Outlines of Chinese Symbolism and Art Motives (Dover Fine Art, History of Art) [9474] (1.0000, (1, 1))
#
# 9) A History of Scotland (2010) [126315] (1.0000, (14, 3))
#
# 10) Reading Chinese Newspapers: Tactics and Skills: Student Workbook (Far Eastern Publications Series) [23418] (1.0000, (1, 1))
#
# 11) Learning to Be A Sage: Selections from the Conversations of Master Chu, Arranged Topically [10088] (1.0000, (3, 1))
#
# 12) Japanese Erotic Fantasies: Sexual Imagery of the Edo Period [35623] (1.0000, (2, 2))
#
# 13) Life along the Silk Road [10204] (1.0000, (9, 3))
#
# 14) Smile of the Buddha: Eastern Philosophy and Western Art from Monet to Today [10242] (1.0000, (2, 2))
#
# 15) Buddhist Scriptures (Penguin Classics) [2110] (1.0000, (4, 3))
#
# 16) unknown title [30328] (1.0000, (1, 1))
#
# 17) Education in Contemporary Japan: Inequality and Diversity (Contemporary Japanese Society) [10440] (1.0000, (2, 2))
#
# 18) The I Ching or Book of Changes [14201] (1.0000, (19, 5))
#
# 19) Japanese Buddhism: A Cultural History [34387] (1.0000, (1, 1))
#
# 20) Engaged Buddhism: Buddhist Liberation Movements in Asia [17700] (1.0000, (1, 1))
#
# 21) Daoism and Chinese Culture [34061] (1.0000, (5, 2))
#
# 22) Ethnic Dress : A Comprehensive Guide to the Folk Costume of the World [20320] (1.0000, (1, 1))
#
# 23) 1,001 Symbols: An Illustrated Guide to Imagery and Its Meaning [19844] (1.0000, (2, 2))
#
# 24) The Private Life of a Masterpiece: The Complete Seasons 1-5 (2008) [121496] (1.0000, (5, 2))
#
# 25) Sources of Indian Tradition, Vol. 2: Modern India and Pakistan (Introduction to Oriental Civilizations) [3483] (1.0000, (7, 3))
#
# 26) Encountering the Dharma: Daisaku Ikeda, Soka Gakkai, and the Globalization of Buddhist Humanism [10257] (0.9973, (3, 3))
#
# 27) The Art and Culture of Japan (Abrams Discoveries) [19590] (0.9764, (2, 2))
#
# 28) Standing for Something: 10 Neglected Virtues That Will Heal Our Hearts and Homes [11689] (0.9656, (3, 3))
#
# 29) Confucius Analects (Hackett Classics Series) [22254] (0.9073, (8, 6))
#
# 30) The Cultural Politics of Food and Eating (Blackwell Readers in Anthroplogy, No. 8) [11947] (0.8288, (1, 1))
#
# 31) The Knight in Rusty Armor [23034] (0.6950, (3, 2))
#
# 32) The Yellow Emperor's Classic of Medicine: A New Translation of the Neijing Suwen with Commentary [29100] (0.5875, (12, 2))
#
# 33) East Asian Medicine in Urban Japan: Varieties of Medical Experience (Comparative Studies of Health Systems and Medical Care) [10073] (0.5870, (1, 2))
#
# 34) How Societies Remember (Themes in the Social Sciences) [10287] (0.5631, (3, 3))
#
# 35) Warrior Rule in Japan [10367] (0.5252, (4, 2))
#
# 36) Buddhist Scriptures (Penguin Classics) [2177] (0.5227, (6, 2))
#
# 37) The Art of Warfare (Classics of Ancient China) [5352] (0.4737, (3, 2))
#
# 38) Sources of Indian Tradition, Vol. 1: From the Beginning to 1800 (Introduction to Oriental Civilizations) [3484] (0.4162, (5, 4))
#
# 39) Chinese Religions [23290] (0.3828, (1, 2))
#
# 40) On Beauty and Being Just. [14192] (0.3340, (7, 5))
#
# 41) The Home and the World (Penguin Classics) [2199] (0.2816, (11, 4))
#
# 42) The Buddha: The Story of an Awakened Life [33052] (0.2284, (2, 1))
#
# 43) The Narrow Road to Oku (Illustrated Japanese Classics) [34399] (0.1944, (8, 3))
#
# 44) The Hungarians: A Thousand Years of Victory in Defeat [14228] (0.1849, (5, 3))
#
# 45) Simon Schama's Power of Art (2007) [116846] (0.1669, (5, 1))
#
# 46) Changing Seasons Macrobiotic Cookbook [30832] (0.1606, (7, 1))
#
# 47) The Study of Ethnomusicology: Thirty-one Issues and Concepts, 2nd Edition [3562] (0.1599, (5, 3))
#
# 48) Xunzi (Translations from the Asian Classics) [3527] (0.1589, (3, 1))
#
# 49) Finland: Cultural Lone Wolf [34143] (0.1570, (1, 0))
#
# 50) Sources of Korean Tradition, Vol. 2: From the Sixteenth to the Twentieth Centuries [3516] (0.1560, (3, 1))
#
# 51) Art of Colonial Latin America A&I (Art and Ideas) [14375] (0.1559, (2, 1))
#
# 52) Chushingura (The Treasury of Loyal Retainers): A Puppet Play [3471] (0.1549, (13, 4))
#
# 53) Japanese Today: Change and Continuity, Enlarged Edition [12842] (0.1531, (1, 1))
#
# 54) Zen Action: Zen Person [20891] (0.1522, (9, 1))
#
# 55) Signs and Symbols in Christian Art: With Illustrations from Paintings from the Renaissance (Galaxy Books) [2698] (0.1516, (5, 1))
#
# 56) Let's Learn Kanji: An Introduction to Radicals, Components and 250 Very Basic Kanji (Kodansha's Children's Classics) [34402] (0.1453, (2, 1))
#
# 57) The Two Koreas: A Contemporary History (Revised and Updated Edition) [9060] (0.1445, (11, 2))
#
# 58) Flash of the Spirit: African & Afro-American Art & Philosophy [7088] (0.1438, (12, 4))
#
# 59) Keywords: A Vocabulary of Culture and Society [2926] (0.1422, (10, 5))
#
# 60) To Sail Beyond The Sunset [7350] (0.1381, (4, 1))
#
# 61) The Tao of Healthy Eating: Dietary Wisdom According to Traditional Chinese Medicine [24968] (0.1377, (12, 1))
#
# 62) Bushido: The Way of the Samurai (Square One Classics) [15603] (0.1372, (9, 1))
#
# 63) Classical Bujutsu (Martial Arts and Ways of Japan, V. 1.) [21357] (0.1360, (6, 1))
#
# 64) Complete Sinawali: Filipino Double-Weapon Fighting (Complete Martial Arts) [18849] (0.1338, (9, 3))
#
# 65) The Essence of T'ai Chi Ch'uan: The Literary Tradition [24372] (0.1335, (17, 2))
#
# 66) Feminism and Art History: Questioning the Litany [971] (0.1334, (4, 3))
#
# 67) Creating Sacred Space With Feng Shui: Learn the Art of Space Clearing and Bring New Energy into Your Life [10652] (0.1334, (5, 1))
#
# 68) Judo Unleashed: Essential Throwing & Grappling Techniques for Intermediate to Advanced Martial Artists [1409] (0.1312, (10, 1))
#
# 69) The Art of Setting Stones: And Other Writings from the Japanese Garden [32843] (0.1304, (2, 1))
#
# 70) Sun Pin: Military Methods (History & Warfare) [20129] (0.1296, (4, 2))
#
# 71) Chinese Houses: The Architectural Heritage of a Nation [18872] (0.1271, (4, 1))
#
# 72) Living Color: Master Lin Yuns Guide to Feng Shui and the Art of Color [28850] (0.1265, (4, 1))
#
# 73) Masks [7086] (0.1262, (14, 7))
#
# 74) Feng Shui: Harmony by Design [7440] (0.1243, (1, 1))
#
# 75) The Guerrilla Girls' Bedside Companion to the History of Western Art [1996] (0.1241, (15, 4))
#
# 76) Six Records of a Floating Life (Penguin Classics) [2145] (0.1225, (9, 2))
#
# 77) Mauve: How One Man Invented a Color That Changed the World [6873] (0.1220, (5, 3))
#
# 78) Sun Yat-sen [18809] (0.1220, (2, 2))
#
# 79) The Snow Lion and the Dragon: China, Tibet, and the Dalai Lama [10174] (0.1220, (1, 1))
#
# 80) English with an Accent: Language, Ideology and Discrimination in the United States [7486] (0.1206, (5, 3))
#
# 81) Precolonial Black Africa [27373] (0.1206, (7, 1))
#
# 82) Zhuangzi Speaks: The Music of Nature [14098] (0.1198, (8, 1))
#
# 83) Chinese in a Flash Volume 3 (Tuttle Flash Cards) [18885] (0.1198, (3, 1))
#
# 84) The Heart of Dogen's Shobogenzo [17703] (0.1187, (5, 1))
#
# 85) Makers of Modern Strategy from Machiavelli to the Nuclear Age [14149] (0.1185, (21, 4))
#
# 86) Wing Chun - The Science of In-Fighting [67006] (0.1185, (30, 3))
#
# 87) Discourse on Colonialism [30840] (0.1178, (23, 10))
#
# 88) T'ai Chi Ch'uan Ta Wen: Questions and Answers on T'ai Chi Ch'uan [25076] (0.1177, (6, 1))
#
# 89) Seven Types of Ambiguity [19655] (0.1169, (12, 4))
#
# 90) Outline of Classical Chinese Grammar [16714] (0.1165, (4, 2))
#
# 91) Son of the Revolution [7087] (0.1163, (16, 2))
#
# 92) Songs of the Frontier Warriors: Kenge Kreshnikesh--Albanian Epic Verse in a Bilingual English-Albanian Edition [21950] (0.1160, (4, 1))
#
# 93) How to Read Classical Tibetan, Volume One: Summary of the General Path [27809] (0.1153, (6, 1))
#
# 94) LIFE: Our Century in Pictures for Young People [5092] (0.1147, (4, 2))
#
# 95) Color: A Natural History of the Palette [20054] (0.1146, (7, 2))
#
# 96) Art Theory: A Very Short Introduction [2607] (0.1142, (6, 2))
#
# 97) The Tools of Empire: Technology and European Imperialism in the Nineteenth Century [2706] (0.1141, (6, 1))
#
# 98) The Eater's Guide to Chinese Characters [3406] (0.1132, (1, 1))
#
# 99) Indonesian Fighting Fundamentals: The Brutal Arts Of The Archipelago [22387] (0.1128, (5, 1))
#
# 100) The Polish Way: A Thousand-Year History of the Poles and Their Culture [16779] (0.1123, (4, 2))
#
# 101) Grundrisse: Foundations of the Critique of Political Economy (Penguin Classics) [2159] (0.1121, (11, 1))
#
# 102) Chinese Herbal Medicine: Materia Medica, Third Edition [25118] (0.1111, (15, 2))
#
# 103) Why Art Cannot Be Taught: A Handbook for Art Students [3557] (0.1108, (5, 3))
#
# 104) Intuition: Knowing Beyond Logic [4659] (0.1103, (11, 4))
#
# 105) World Religions: Western Traditions [2944] (0.1103, (1, 1))
#
# 106) The Hidden Roots of Aikido: Aiki Jujutsu Daitoryu - Secret Techniques of an Ancient Martial Art [34408] (0.1100, (3, 1))
#
# 107) Distinction: A Social Critique of the Judgement of Taste [12815] (0.1100, (19, 5))
#
# 108) The Shaolin Workout: 28 Days to Transforming Your Body and Soul the Warrior's Way [31986] (0.1098, (15, 2))
#
# 109) Words in Context: A Japanese Perspective on Language and Culture (Japanese Characters) [34417] (0.1094, (2, 1))
#
# 110) Simple Taoism: A Guide to Living in Balance [18850] (0.1090, (7, 1))
#
# 111) Religions of China in Practice [14138] (0.1090, (7, 1))
#
# 112) The Colouring, Bronzing and Patination of Metals [20756] (0.1087, (3, 1))
#
# 113) Taiwan: A Political History [18157] (0.1086, (4, 1))
#
# 114) The Anatomy Coloring Book [19033] (0.1082, (27, 10))
#
# 115) Music in Latin American Culture: Regional Traditions [9753] (0.1077, (3, 2))
#
# 116) Complete Wing Chun: The Definitive Guide to Wing Chun's History and Traditions (Complete Martial Arts) [18848] (0.1072, (3, 2))
#
# 117) From Reliable Sources: An Introduction to Historical Methods [18151] (0.1069, (16, 3))
#
# 118) Theories and Documents of Contemporary Art: A Sourcebook of Artists' Writings (California Studies in the History of Art) [10124] (0.1064, (5, 1))
#
# 119) Herbs for Hepatitis C and the Liver (A Storey Medicinal Herb Guide) [30382] (0.1063, (7, 1))
#
# 120) Korea's Place in the Sun: A Modern History, Updated Edition [6893] (0.1062, (12, 1))
#
# 121) The Ancient Kingdoms of Peru [1959] (0.1060, (2, 2))
#
# 122) Zen: The Path of Paradox [4768] (0.1054, (5, 2))
#
# 123) Thinking in Java (4th Edition) [1755] (0.1052, (7, 1))
#
# 124) The Tao of Health, Sex, and Longevity: A Modern Practical Guide to the Ancient Way (Fireside Books (Fireside)) [12475] (0.1044, (6, 2))
#
# 125) Tantra: Path of Ecstasy [29113] (0.1042, (7, 2))
#
# 126) Japan Style: Architecture Interiors Design [18875] (0.1034, (6, 1))
#
# 127) Standard Albanian: A Reference Grammar for Students [18772] (0.1034, (2, 2))
#
# 128) Taoism: Growth of a Religion [18790] (0.1030, (4, 1))
#
# 129) Columbus's Outpost among the Taínos: Spain and America at La Isabela, 1493-1498 [3915] (0.1029, (3, 2))
#
# 130) Korean Cuisine (English and Mandarin Chinese Edition) [25251] (0.1029, (4, 1))
#
# 131) Tai Chi Melody [44538] (0.1027, (12, 3))
#
# 132) Alabi's World (Johns Hopkins Studies in Atlantic History and Culture) [18201] (0.1023, (2, 1))
#
# 133) The Sacred Art of Dying: How the World Religions Understand Death [19451] (0.1009, (4, 4))
#
# 134) Albert Einstein and the Theory of Relativity (Solutions) [19878] (0.1008, (8, 5))
#
# 135) Discipline & Punish: The Birth of the Prison [13183] (0.1006, (58, 16))
#
# 136) Chinese Link: Zhongwen Tiandi, Intermediate Chinese, Level 2 Part 1 [1765] (0.1006, (3, 1))
#
# 137) Reading the Body: Ohashi's Book of Oriental Diagnosis [1944] (0.0998, (4, 3))
#
# 138) Art of War (2009) [124617] (0.0994, (10, 3))
#
# 139) Designing Social Inquiry: Scientific Inference in Qualitative Research [14159] (0.0989, (17, 2))
#
# 140) Taipei People [35644] (0.0986, (2, 2))
#
# 141) Thai Cooking Made Easy (English and Chinese Edition) [25247] (0.0986, (6, 1))
#
# 142) The Web That Has No Weaver : Understanding Chinese Medicine [19520] (0.0984, (23, 2))
#
# 143) The Taming of the Samurai: Honorific Individualism and the Making of Modern Japan [12895] (0.0981, (9, 3))
#
# 144) Amazon.com: Imperial 100s Tab Collar French Cuff Dress Shirt: Clothing [67677] (0.0980, (270, 1))
#
# 145) The Civilizations of Africa: A History to 1800 [20172] (0.0979, (5, 2))
#
# 146) The Quick and Natural Macrobiotic Cookbook [19539] (0.0978, (3, 1))
#
# 147) Language Myths [1998] (0.0978, (15, 1))
#
# 148) A Dictionary of Japanese Particles (A Kodansha Dictionary) (English and Japanese Edition) [34409] (0.0976, (15, 1))
#
# 149) Advanced Origami: An Artist's Guide to Performances in Paper [18881] (0.0972, (5, 1))
#
# 150) Emperor of China: Self-Portrait of K'ang-Hsi [13033] (0.0966, (4, 2))
#
# 151) A History of Christianity in Asia: Beginnings to 1500 [29201] (0.0962, (3, 2))
#
# 152) The Macrobiotic Path to Total Health: A Complete Guide to Naturally Preventing and Relieving More Than 200 Chronic Conditions and Disorders [5485] (0.0962, (11, 1))
#
# 153) The I Ching Workbook [6366] (0.0947, (11, 2))
#
# 154) Medical Firsts: From Hippocrates to the Human Genome [9278] (0.0945, (3, 1))
#
# 155) Zhan-Zhuang Gong Music [53992] (0.0944, (9, 3))
#
# 156) The Scarlet Gang of Asakusa [10239] (0.0942, (4, 3))
#
# 157) The Second Shift [2296] (0.0941, (13, 4))
#
# 158) Zen Macrobiotics for Americans [33095] (0.0936, (3, 3))
#
# 159) Living the Cross Centered Life: Keeping the Gospel the Main Thing [31398] (0.0936, (6, 3))
#
# 160) The Cancer Prevention Diet: Michio Kushi's Macrobiotic Blueprint for the Prevention and Relief of Disease [4472] (0.0934, (2, 1))
#
# 161) The Self-Healing Cookbook: Whole Foods To Balance Body, Mind and Moods [25415] (0.0933, (3, 2))
#
# 162) The Nuts and Bolts of College Writing [22248] (0.0930, (13, 5))
#
# 163) The Sounds of the World's Languages [11912] (0.0928, (3, 1))
#
# 164) Food and Healing [5320] (0.0926, (4, 2))
#
# 165) A History of Modern Indonesia [10386] (0.0925, (7, 3))
#
# 166) The Clouds Should Know Me By Now: Buddhist Poet Monks of China [21896] (0.0925, (6, 3))
#
# 167) What Makes Us Catholic: Eight Gifts for Life [477] (0.0913, (2, 2))
#
# 168) Records of the Grand Historian: Qin Dynasty [3491] (0.0913, (7, 1))
#
# 169) Becoming a Chef [9151] (0.0909, (7, 2))
#
# 170) Manual Of Standard Tibetan: Language And Civilization [27811] (0.0906, (7, 1))
#
# 171) Chinese Medical Characters Volume 1 Basic Vocabulary [24351] (0.0902, (5, 1))
#
# 172) Unclaimed Experience: Trauma, Narrative and History [18216] (0.0900, (3, 3))
#
# 173) Myth, Literature and the African World (Canto) [10331] (0.0897, (4, 1))
#
# 174) The Machu Picchu Guidebook: A Self-Guided Tour [27217] (0.0896, (16, 2))
#
# 175) Music in Ireland: Experiencing Music, Expressing Culture (Global Music) [2866] (0.0894, (4, 3))
#
# 176) Many Ways to Be Deaf: International Variation in Deaf Communities [28259] (0.0892, (1, 1))
#
# 177) The Buddhist Tradition: In India, China and Japan [7080] (0.0890, (5, 1))
#
# 178) The Classic Tradition of Haiku: An Anthology (Dover Thrift Editions) [9624] (0.0887, (10, 1))
#
# 179) Transforming Matter: A History of Chemistry from Alchemy to the Buckyball (Johns Hopkins Introductory Studies in the History of Science) [18247] (0.0882, (6, 3))
#
# 180) Islamic Arts (Art & Ideas) [14359] (0.0881, (4, 2))
#
# 181) Chinese Characters: A Genealogy and Dictionary (English and Mandarin Chinese Edition) [25853] (0.0878, (12, 2))
#
# 182) The Mystery of Samba : Popular Music and National Identity in Brazil [19382] (0.0877, (7, 3))
#
# 183) Move Your Stuff, Change Your Life: How to Use Feng Shui to Get Love, Money, Respect, and Happiness [13567] (0.0876, (19, 1))
#
# 184) Willem de Kooning 1904-1997: Content as a Glimpse (Basic Art) [34356] (0.0857, (1, 1))
#
# 185) The Shorter Columbia Anthology of Traditional Chinese Literature [3515] (0.0855, (1, 1))
#
# 186) Deogratias, A Tale of Rwanda [32018] (0.0852, (3, 2))
#
# 187) The DC Comics Guide to Inking Comics [20761] (0.0843, (4, 2))
#
# 188) Tsukiji: The Fish Market at the Center of the World (California Studies in Food and Culture) [10180] (0.0843, (8, 4))
#
# 189) The Emperor's Mirror: Understanding Cultures through Primary Sources [20343] (0.0841, (1, 1))
#
# 190) Lao Tzu: Te-Tao Ching - A New Translation Based on the Recently Discovered Ma-wang-tui Texts (Classics of Ancient China) [5364] (0.0840, (7, 2))
#
# 191) Indian Art (Oxford History of Art) [2621] (0.0840, (4, 2))
#
# 192) Exhibit Labels: An Interpretive Approach [15990] (0.0838, (6, 3))
#
# 193) Patinas for Silicon Bronze [25738] (0.0833, (2, 1))
#
# 194) Finnish Dictionary & Phrasebook: Finnish-English/English-Finnish (Hippocrene Dictionary & Phrasebooks) [16814] (0.0826, (5, 2))
#
# 195) Chinese One Dish Meals [25244] (0.0823, (7, 1))
#
# 196) Berklee Practice Method: Keyboard [11968] (0.0821, (5, 2))
#
# 197) Black Art: A Cultural History (Second Edition) (World of Art) [9774] (0.0818, (10, 4))
#
# 198) Chi Gong-One finger ch'an melody [44539] (0.0805, (9, 1))
#
# 199) Patina Basics [126949] (0.0802, (5, 2))
#
# 200) Chuang Tzu: Basic Writings [3504] (0.0802, (16, 1))

# %%
xrtf_score_mat = sp.load_npz(f'../pecos/examples/xr-transformer/models/lf-amazontitles-131k/distilbert/Pt.npz')

# %%
trnX_full = trnX
trnX = [x.split(' /SEP/')[0] for x in trnX_full]

# %%
XCMetrics(xrtf_score_mat, tst_X_Y, inv_prop)

# %%
xrtf_intsxn = retain_topk(xrtf_score_mat, k=5).multiply(tst_X_Y)
xrl_intsxn = retain_topk(score_mat, k=5).multiply(tst_X_Y)

# %%
targets = np.where(xrtf_intsxn.getnnz(1) > xrl_intsxn.getnnz(1)+1)[0]

# %%
x = np.random.randint(len(tstX))
# x = np.random.choice(targets)
vispoint(x, tst_X_Y, tstX, Y, nnz, tst_X_Y, K=100, expand=True, trnx_nnz=trnx_nnz)

# %%
vispoint(x, candidates, tstX, Y, nnz, None, K=100, expand=True, trnx_nnz=trnx_nnz)

# %%
vispoint(x, xrtf_score_mat, tstX, Y, nnz, tst_X_Y, K=100, expand=True, trnx_nnz=trnx_nnz)

# %%
candidates[1, 66580]

# %%
new_cmat[1, 66580]

# %%
vispoint(0, candidates, tstX, Y, nnz, None, K=1000, expand=False, trnx_nnz=trnx_nnz)

# %%
np.array(CT.argmax(0)).ravel().shape

# %%
CT_parent = sp.csr_matrix((np.ones(args.numy), np.array(CT.argmax(0)).ravel(), range(args.numy+1)), C.shape).T.tocsr()

# %%
temp = CT_topk + CT_parent

# %%
temp.getnnz(1).max()

# %%
temp = candidates.getnnz(1)
sorted_inds = temp.argsort()

# %%
temp[sorted_inds[:100]], sorted_inds[:100]

# %%
np.where(CT_val_topk.getnnz(0) > 0)[0]

# %%
cmat_intrsxn = CT_topk.multiply(cmat[:, :-1])

# %%
CT_parent.getnnz(1).mean()

# %%
CT_normalized = CT.copy()
CT_normalized.data = CT_normalized.data / nnz[CT_normalized.indices]

CT_normalized_topk = retain_topk(CT_normalized, k=1000)

# %%
vispoint(0, CT, tstX, Y, nnz, cmat, K=100, expand=True, trnx_nnz=trnx_nnz)

# %%
print(get_text(0, Y, CT, K=10))

# %%
# from xclib.utils.sparse import retain_topk

# top100_CT = retain_topk(C.T.tocsr(), k=100)

# %%
from numba.core import types
from numba.typed import Dict

def construct_new_C_and_Y(
    counts_rows,
    counts_cols,
    counts,
    row_ids,
    row_ranges,
    C_rows,
    sort_idx,
    nr_labels,
    max_cluster_size,
    n_copies,
):
    """Determine the new clustering matrix and the new label matrix given the couting matrix.
    This function implements Eq.(10) in our paper. I.e. given the couting matrix C = Y^T * M, 
    we select the correct cluster id for each label one by one, in descending order of C entries,
    possibly assign a label multiple times (`n_copies`) to different clusters. Finally, the new 
    cluster and new label matrix is returned. Notice that Numba is used here, this prevents us 
    from passing scipy sparse matrix directly.
    
    Args:
        counts_rows, counts_cols, counts: The counting matrix in COO format.
        row_ids, row_ranges: The indices and indptr of original Y matrix in CSC format.
        C_rows: Clustering matrix C in LIL format, converted to list of numpy arrays.
        sort_idx: Index of counts_{rows,cols} to sort them in decending order.
        nr_labels: Number of original labels.
        max_cluster_size: (Unused for now) Hard constraints to limit the number of labels 
            in each cluster (to balance cluster size).
        n_copies: Max number of copies for each label (\lambda in our paper).
    Returns:
        New cluster matrix (`new_C_*`), new label matrix (`new_Y_*`), the replicated label
        assignment (`C_overlap_*`), number of duplicated labels (`nr_copied_labels`), a map 
        from new label id to the underlying label id (`mapper`), unused labels that never 
        show up in training (`unused_labels`), number of lightly used labels (`nr_tail_labels`).
    """
    # construct empty cluster matrix and label matrix
    nr_copied_labels = 0
    new_C_cols = []
    new_C_data = []
    new_Y_rows = []
    labels_included = set()
    mapper = Dict.empty(key_type=types.int64, value_type=types.int64,)
    cluster_size = Dict.empty(key_type=types.int64, value_type=types.int64,)
    pseudo_label_count = Dict.empty(key_type=types.int64, value_type=types.int64,)
    # results
    C_overlap_rows, C_overlap_cols = [], []
    max_count = n_copies
    # adding labels to clusters one by one in descending frequency
    for idx in tqdm(sort_idx):
        label_id = counts_rows[idx]
        leaf_id = counts_cols[idx]
        if label_id in pseudo_label_count and pseudo_label_count[label_id] >= max_count:
            continue
        
        if leaf_id not in cluster_size:
            cluster_size[leaf_id] = 1
        else:
            # If you need to constrain the max cluster size, then
            # uncomment following two lines
            if cluster_size[leaf_id] >= max_cluster_size:
                continue
            cluster_size[leaf_id] += 1

        if label_id not in pseudo_label_count:
            pseudo_label_count[label_id] = 1
        else:
            pseudo_label_count[label_id] += 1

        if label_id in labels_included:
            # add a pseudo label that duplicates label_id
            pseudo_label_id = nr_copied_labels + nr_labels
            mapper[pseudo_label_id] = label_id
            # add one more row to C (in lil format)
            new_C_cols.append([leaf_id])
            new_C_data.append([1])
            # add one more column to Yt
            examples = row_ids[row_ranges[label_id] : row_ranges[label_id + 1]]
            new_Y_rows.append(examples)
            nr_copied_labels += 1
        else:
            # add a new label
            labels_included.add(label_id)
            C_overlap_rows.append(label_id)
            C_overlap_cols.append(leaf_id)

        # exit early if we have too many effective labels
        if len(mapper) >= max_count * nr_labels:
            break
    # add missing labels back to clusters
    nr_tail_labels = 0
    for label_id in range(nr_labels):
        if label_id not in labels_included:
            original_leaf_id = C_rows[label_id][0]
            C_overlap_rows.append(label_id)
            C_overlap_cols.append(original_leaf_id)
            labels_included.add(label_id)
            nr_tail_labels += 1

    unused_labels = set()
    for label_id in range(nr_labels):
        if label_id not in labels_included:
            unused_labels.add(label_id)

    # new_Y elements
    new_Y_indptr = [0]
    new_Y_indices = []
    for rows in new_Y_rows:
        new_Y_indptr.append(new_Y_indptr[-1] + len(rows))
        new_Y_indices.extend(rows)
    new_Y_data = np.ones(len(new_Y_indices), dtype=np.int32)
    return (
        new_C_cols,
        new_C_data,
        new_Y_data,
        new_Y_indices,
        new_Y_indptr,
        C_overlap_cols,
        C_overlap_rows,
        nr_copied_labels,
        mapper,
        unused_labels,
        nr_tail_labels,
    )

# %%
coo_C = C.tocoo()

sort_idx = np.argsort(coo_C.data)[::-1]

# %%
(new_C_cols,
new_C_data,
new_Y_data,
new_Y_indices,
new_Y_indptr,
C_overlap_cols,
C_overlap_rows,
out_labels,
mapper,
unused_labels,
nr_tail_labels) = construct_new_C_and_Y(
                            coo_C.row, 
                            coo_C.col, 
                            coo_C.data, 
                            trn_X_Y.tocsc().indices, 
                            trn_X_Y.tocsc().indptr, 
                            np.array(cmat.T.tolil().rows), 
                            sort_idx, 
                            args.numy, 
                            1000, 
                            2)

# %%
C = cmat.T.tocsr()
Yt = trn_Y_X

# %%
C_overlap = sp.coo_matrix(
    (np.ones_like(C_overlap_cols), (C_overlap_rows, C_overlap_cols)),
    shape=C.shape,
    dtype=C.dtype,
).tocsr()
print(f"#copied labels: {out_labels}, #tail labels: {nr_tail_labels}")

new_C = sp.lil_matrix((out_labels, C.shape[1]), dtype=C.dtype)
new_C.data = new_C_data
new_C.rows = new_C_cols
C = sp.vstack((C_overlap, new_C.tocsc()), format="csc")

new_Y = sp.csc_matrix(
    (new_Y_data, new_Y_indices, new_Y_indptr),
    shape=(Yt.shape[0], len(new_Y_indptr) - 1),
    dtype=Yt.dtype,
)
Yt = sp.hstack((Yt, new_Y), format="csr")

# %%
C.getnnz(0).min()

# %%
inds = net.C.argsort(dim=1, descending=True)

# %%
inds[:, :100].unique().size()

# %%
net.eval()

# %%
net.C.requires_grad = False

# %%
net.C.scatter_(1, inds[:, 100:], 0)

# %%
net.C.gather(1, inds[:, :200])

# %%
net.C.max(dim=1)

# %%
print(get_text(0, Y, score_mat, K=10))

# %%
net.w1.weight

# %%
net.C

# %%
out = net(b)

# %%
out.max(dim=1)

# %%
from torchviz import make_dot

# %%
loss = criterion(net, b)

# %%
make_dot(loss, params=dict(net.named_parameters()))

# %%
import seaborn as sns

# %%
net.to(args.device)
net.parent = net.parent.to(args.device)
net.cmat = net.cmat.to(args.device)

# %%
# net.beam = 80
score_mat = net.predict(tst_loader)
# if tst_filter_mat is not None: _filter(score_mat, tst_filter_mat, copy=False)
# metrics = XCMetrics(score_mat, tst_X_Y, inv_prop, method=args.expname, disp=True)

# %%
trn_score_mat = net.predict(trn_loader)

XCMetrics(trn_score_mat, trn_X_Y, inv_prop)

# %%
net.load_state_dict(torch.load('Results/Joint-XRL-ipynb/LF-AmazonTitles-131K/treenet-64x100-ipynb_ova-bce_tf-None-norm_xc-lr-0.0005_enc-lr-5e-05_bsz-512_ep-25/model.pt'))

# %%
import time
from torchviz import make_dot

# %%
net.ova = True

# %%
net.train()
start = time.time()
for b in tqdm(trn_loader):
    b = net.ToD(b)
    out = net(b)
#     out1, out, shorty = net(b)

    yfull = torch.zeros((out.shape[0], net.numy+1), device=out.device).scatter_(1, b['y']['inds'], 1)
    yfull[:, -1] = 0.0
#     cluster_targets = torch.zeros((out.shape[0], net.cmat.shape[0]), device=out.device).scatter_(1, net.parent[b['y']['inds']], 1)
#     cluster_targets[:, -1] = 0.0

#     targets  = torch.gather(yfull, 1, shorty)
# #     loss = criterion.criterion(out, targets) + criterion.alpha*criterion.criterion(out1, cluster_targets)
    loss = criterion.criterion(out, yfull)
    loss.backward()
#     del b, out, out1, yfull, targets, cluster_targets
end = time.time()
print(f'Time: {"%.2f"%(end-start)}s')

# %%
out1, out, shorty = net(b)

yfull = torch.zeros((out.shape[0], net.numy+1), device=out.device).scatter_(1, b['y']['inds'], 1)
yfull[:, -1] = 0.0
cluster_targets = torch.zeros((out.shape[0], net.cmat.shape[0]), device=out.device).scatter_(1, net.parent[b['y']['inds']], 1)
cluster_targets[:, -1] = 0.0

targets  = torch.gather(yfull, 1, shorty)
loss = criterion.criterion(out, targets) + criterion.alpha*criterion.criterion(out1, cluster_targets)

# %%
# %timeit out1, out, shorty = net(b)

# %%
make_dot(loss, params=dict(net.named_parameters()))

# %%
make_dot(loss, params=dict(net.named_parameters()))

# %%
net.train()
K = 0
start = time.time()
with torch.no_grad():
    for b in tqdm(trn_loader):
        b = net.ToD(b)
        embs = net.encode(b)
        K = max(net.beam, K)

        if net.ova:
            out1 = net.w1(embs) if net.loss_with_logits else torch.sigmoid(net.w1(embs))
            out2 = net.w2(embs) if net.loss_with_logits else torch.sigmoid(net.w2(embs))
            out1_expand = torch.zeros_like(out2)
            out1_expand[:, net.cmat_col] = out1[:, net.cmat_row]
            out = out1_expand * out2
            continue

        out1 = net.w1(embs) if net.loss_with_logits else torch.sigmoid(net.w1(embs))
        _, out1_topk_inds = torch.topk(out1, K, dim=1)
        shorty = net.cmat[out1_topk_inds.reshape(-1)].reshape(embs.shape[0], -1)
        if net.training:
            shorty = torch.hstack((shorty, b['y']['inds']))
            shorty = dedup_tensor(shorty, replace_val=net.numy)
#             shorty = torch.nn.utils.rnn.pad_sequence([s.unique() for s in shorty], padding_value=net.numy, batch_first=True)

#         w2_weight_reshaped = net.w2.weight[shorty.reshape(-1)].reshape(embs.shape[0], -1, embs.shape[1]).permute(0, 2, 1)
        w2_weight_reshaped = F.embedding(shorty, net.w2.weight, sparse=True).permute(0, 2, 1)
        w2_bias_reshaped = net.w2.bias[shorty]
        out2_shorty = torch.bmm(embs.unsqueeze(1), w2_weight_reshaped).squeeze() + w2_bias_reshaped
        del w2_weight_reshaped, w2_bias_reshaped

        out2_shorty = out2_shorty if net.loss_with_logits else torch.sigmoid(out2_shorty)

        out1_shorty = out1.gather(1, net.parent[shorty])
        out = (out2_shorty + out1_shorty) if net.loss_with_logits else (out2_shorty * out1_shorty)
        del out1_topk_inds, out2_shorty, out1_shorty

    #     return (out1, out, shorty) if net.training else (out, shorty)
end = time.time()
print(f'Time: {"%.2f"%(end-start)}s')

# %%
F.embedding(shorty, net.w2.weight, sparse=True)

# %%
A = F.normalize(embs[0], dim=1)
B = F.normalize(tf_output['last_hidden_state'][0], dim=1)

# %%
torch.mm(B, B.T)

# %%
F.normalize(logits[0], dim=1)

# %%
A = tf_output['last_hidden_state'][0].shape

# %%
logits[0]

# %%
net.encoder.transformer.embeddings.word_embeddings.weight[[101, -4, -3, -2, -1]]

# %% [markdown]
# ### Scratch
